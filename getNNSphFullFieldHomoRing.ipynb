# %%
# script for computing NN for any layered model for different cavity geometries
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
from scipy.integrate import quad, tplquad, dblquad
import scipy.constants as const

from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from modules import createDB
from modules import NNGeometryN
from modules import NNGeometryNN
from modules import gfLoader
from modules import simDisp
from modules import NNCompute
from modules import NNPP
from modules import plotUtils

def main():

    # load the config file
    configFile="/home/koley/CavityResults/SphFullRunConfig/configParseFullFieldHomoRing.ini"
    config = configLoader.load_config(configFile)
    # load all cavities
    allCavities = configLoader.loadCavities('/home/koley/CavityResults/SphFullRunConfig/SingleSphCavity.ini')
    validateInputs.validateInputs(config)
    
    splitAll = createDB.createFinalInputs(config)

    #print(f"Prepared {splitAll.shape[0]} total runs")
    #print(f"Cores available: {config.cpuCoresQseis}")

    results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    
    print("Database generation complete")
    
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay

    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody

    # flag for wavefield simulation
    ifFullField = config.ifFullField

    saveHV = config.saveHV

    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    rhoAir = config.rhoAir # density of air
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    lambdaFrac = config.lambdaFrac # fraction
    lambdaRes = config.lambdaRes; #must be greater than 4
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used
    maxRec = config.maxRec # same value of number of receivers that qseis can handle in one go check qsglobal.h
    xCenter = config.xCenter; yCenter = config.yCenter
    xMin = xCenter-config.xExtent; xMax = xCenter+config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = yCenter-config.yExtent; yMax = yCenter+config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")
        
    domXYBounds = (xMin,xMax,yMin,yMax)
    
    refineBoxes = NNGeometryNN.makeRefineBoxesFromCavities(allCavities)
    cubeTopAll = np.zeros((len(allCavities),))
    cubeBotAll = np.zeros((len(allCavities),))
    for boxNo, box in enumerate(refineBoxes):
        cubeTopAll[boxNo] = box.zMin
        cubeBotAll[boxNo] = box.zMax
    cubeTop = min(cubeTopAll)
    cubeBot = max(cubeBotAll)

    # new part added
    cavDepthAll = np.zeros((len(allCavities),))
    for cavNo, cav in enumerate(allCavities):    
        if(cav["shape"]=="cuboid"):
            cavDepthAll[cavNo] = cav["zC"]
        elif(cav["shape"] == 'sphere'):
            cavDepthAll[cavNo] = cav["zC"]
        else:
            ValueError('Unsupported cavity type')
    
    cavDepthUse = min(cavDepthAll)

    print("CubeTop = " + str(cubeTop) +  'CubeBot = ' + str(cubeBot))

    itmAC = config.itmAC; itmAB = config.itmAB; etmCA = config.etmCA; etmBA = config.etmBA

    print('itmAC = ' + str(itmAC[0]) + ', ' + str(itmAC[1]) + ', ' + str(itmAC[2]))
    # make itmAC[2] negative, because in the configfile it is positive
    itmACUse = itmAC.copy(); itmACUse[2] = -np.abs(itmACUse[2])
    itmABUse = itmAB.copy(); itmABUse[2] = -np.abs(itmABUse[2])
    etmCAUse = etmCA.copy(); etmCAUse[2] = -np.abs(etmCAUse[2])
    etmBAUse = etmBA.copy(); etmBAUse[2] = -np.abs(etmBAUse[2])
    # just add one test-mass location, rather than all
    itmAll = np.vstack((itmACUse,))
    nTM = len(itmAll[:,0])
    G = const.G
    
    # some other inputs for simDisp
    maxRec = config.maxRec; # same value of number of receivers that qseis can handle in one go check qsglobal.h
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # saves the NN and displacement values per realization
    outDispRea = config.outDispPathRea # like "/data/gravwav/koley/OutDispRea/"
    
    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations

    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH
    # flag if NN is computed directly without writing the displacemnet field
    onFlyNN = config.onFlyNN 

    # number of CPUs to be used for displacement and NN simulation
    nCPUDisp = config.cpuCoresDisp
    nCPUNN = config.cpuCoresNN
    computeStrategy = config.computeStrategy

    # frequency axis to be used by simDisp
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    splitAllNew, tVecN = gfLoader.assembleQseisRuns(splitAll, fInpPath, components, outPath=None, fIndices=idxFreq, minVel=100.0)
    #splitAllNew = np.load(os.path.join(fInpPath,'splitAllNew.npy'))
     
    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    zList = [0.0,cavDepthUse]
    
    # generate the grid size required
    gridSize = NNCompute.getGridSize(thickness,vp, vs, rho, fMin, fMax, lambdaFrac, lambdaRes)
    
    print('grid size in each layer before partitioning = ' + str(gridSize))
    
    # create the layers and partition
    layers, vp2, vs2, rho2, gridSize2 = NNGeometryNN.createAllLayers(xMin, xMax, yMin, yMax, thickness,
                                                                     zMax,vp,vs,rho,gridSize,cubeTop,cubeBot)
    print('New gridSize after partioning = '+ str(gridSize2))

    print('Total number of layers = ' + str(len(layers)))
    nLayers = len(layers)
    
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq, eP = 1/3, eS = 2/3)
            
        else:
            metaBody=None
        
        # create and save the displacement field on surface and depth for scaling afterwards
        if(ifRay):
            # uses ambient Rayleigh wavefield in homogeneous half space
            phiSrc = srcMeta["phiV"]; ampSrc = srcMeta["ampV"]
            simDisp.getSurfDeepRayDispPerRea(zList, azSrc, phiSrc, ampSrc, outDispRea, reaNo, vR,
                                             vp2[0], vs2[0], freqOut=freqOut)
        elif(ifBody):
            # uses Plane P and S wave in homogeneous half space
            simDisp.getSurfDeepBodyDispPerRea(zList, metaBody, outDispRea, reaNo, vp2[0], vs2[0], freqOut=freqOut)
        
        else:
            # uses QSEIS full wavefield simulation instead
            simDisp.getSurfDeepDispPerRea(zList, xSrc, ySrc, azSrc, srcMeta, xMaxGF, splitAll, fMin, fMax, outDispRea,
                    fInpPath, components, reaNo, idxFreq = idxFreq, freqOut=freqOut)
        
        # preallocate per realization
        IBlockTot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        IVertFaceTot  = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        IHorFaceTot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        ITot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        
        for layerNo, layer in enumerate(layers):
            layer = layers[layerNo]

            # need to redefine cubeTop and cubeBot for multiple cavities
            layer.updateCubeInteraction(cubeTop, cubeBot)
            #layer.generateBlocks(xMin, xMax, yMin, yMax, cubeC, ax, ay, az, domXYBounds)
            layer.generateBlocksNew(refineBoxes=refineBoxes,domXYBounds=domXYBounds,
                                    domainZBounds=(zMin, zMax))
            
            print(layer)
            blkNo = 1
            for blk in layer.blocks:
                print(blk);
                print('Block = '+str(blkNo))
                print('Integrating volume  NN block in layer' + str(layerNo))

                # new version signature
                IBlock = NNCompute.runVolNNComputeBlock(blk, gridSize2[layerNo], freqOut, allCavities, itmAll,
                                                        xSrc, ySrc, azSrc,srcMeta, idxFreq, fMin, fMax, outDispPath, splitAll, xMaxGF,
                                                        fInpPath, components, vR, useSimDisp=ifFullField, ifRay = ifRay, ifBody = ifBody,
                                                        nCPUDisp=nCPUDisp, nCPUNN=nCPUNN, nChunk=20000,metaBody=metaBody,
                                                        computeStrategy=computeStrategy,saveHV=saveHV)
                # new version
                IBlockTot = IBlockTot + IBlock

                # now compute the surface NN from the vertical faces of the block which form the outer boundary
                for f in blk.verticalFaces:
                    if(f.isBoundary):
                        print('Integrating vertical surface NN block in layer' + str(layerNo))
                        print('vertical boundary face found')
                        # is an outer boundary
                        IVertFace = NNCompute.runVertSurfNNCompute(f, gridSize2[layerNo], freqOut, itmAll, xSrc, ySrc, azSrc,
                                                         srcMeta, idxFreq, fMin, fMax, outDispPath, splitAllNew,
                                                         xMaxGF, fInpPath, components, vR, nCPUDisp=1, nChunk = 20000, 
                                                         useSimDisp=ifFullField, ifRay = ifRay, ifBody = ifBody, vP_for_test=blk.vP,
                                                         vS_for_test=blk.vS, metaBody=metaBody,
                                                         computeStrategy=computeStrategy,saveHV=saveHV, reduceNN=onFlyNN)
                        
                        IVertFaceTot = IVertFaceTot + IVertFace
        
                
                # now compute the surface NN from the horizontal interfaces at the very end of layers
                print('Integrating horizontal surface NN block in layer' + str(layerNo))
                IHorFace = NNCompute.handleHorSurfNN(layer, layers, blk, gridSize2[layerNo], nLayers, layerNo, rhoAir, freqOut, 
                                           allCavities, itmAll, xSrc, ySrc, azSrc, srcMeta, idxFreq, fMin, fMax, outDispPath,
                                           splitAllNew, xMaxGF, fInpPath, components, vR, nCPUDisp=nCPUDisp,
                                           nCPUNN=nCPUNN, useSimDisp = ifFullField, ifRay = ifRay, ifBody = ifBody,
                                           vP_for_test=blk.vP, vS_for_test = blk.vS, metaBody = metaBody, chunk_size=20000,
                                           computeStrategy=computeStrategy, saveHV=saveHV, reduceNN=onFlyNN)
                                
                IHorFaceTot = IHorFaceTot + IHorFace
                
                blkNo = blkNo+1
    
        IVertFaceTot = IVertFaceTot*G
        IHorFaceTot = IHorFaceTot*G
        IBlockTot = IBlockTot*G
        ITot = (IBlockTot-IVertFaceTot-IHorFaceTot)
        # save the NN per realization
        nnFName = 'NNFullRea' + str(reaNo) + '.npz'
        np.savez(os.path.join(outDispRea, nnFName), IVertFaceTot = IVertFaceTot, IHorFaceTot = IHorFaceTot,
                 IBlockTot = IBlockTot, ITot = ITot, freqOut=freqOut)

    dispPointAllRea, attnAllRea, freqDisp = simDisp.assembleSurfDeepDispAllRea(outDispRea, zList, freqOut, nRea)
    nnAllRea, nnVolAllRea, nnSurfAllRea, fNN = NNCompute.assembleNNAllReaAllTM(outDispRea,freqOut, nRea,nTM)

    # preparing for output visualization
    plotUtils.set_plot_style(style='medium')
    
    ################################################################################################
    # scaling the surface and deep displacements
    scaledSimDisp, asdSurfX, asdSurfY, asdSurfZ, asdBHX, asdBHY, asdBHZ = NNPP.scaleDisp(
        dispPointAllRea, freqOut, config, scaleComp='E', scaleDepth = 'depth', scaleToTrue=True)
    # make plot
    figDisp, axDisp = plotUtils.plotPSDDeepSurfMulti(freqOut, scaledSimDisp[:,:,0], '0 m deep', 'b', fig=None, axs=None, 
                                         quantity="ASD displacement")
    figDisp, axDisp = plotUtils.plotPSDDeepSurfMulti(freqOut, scaledSimDisp[:,:,1], '250 m deep', 'r', fig=figDisp, axs=axDisp, 
                                         quantity="ASD displacement")
    # compare the scaled simulated displacements to those observed at site
    figSh, axSh = plotUtils.plotScaledVsSiteASD(freqOut, scaledSimDisp, asdSurfX, asdSurfY, asdSurfZ,
                                                asdBHX, asdBHY, asdBHZ)
    ################################################################################################

    # compare simulated and site based attenuation between surface and depth
    attnSim, attnX, attnY, attnZ = NNPP.getAttn(dispPointAllRea,freqOut,config)
    figAttn, axAttn = plotUtils.plotAttn(freqOut, attnSim, attnX, attnY, attnZ)
    
    ################################################################################################
    # scale the simulated Newtonian acceleration such that displacement is set to 1
    scaledNN = np.zeros((nFreq,3,nTM))
    for i in range(0,nTM):
        scaledNN[:,:,i], *__ = NNPP.scaleNN(nnAllRea[:,:,i], dispPointAllRea, freqOut, config, scaleComp="E", scaleDepth="depth",
                                 scaleToTrue=False)
    # plot the scaleNN
    colTM = ['b','g','r','y']
    for i in range(0,nTM):
        if(i==0):
            figNN, axNN = plotUtils.plotPSDDeepSurfMulti(fNN, scaledNN[:,:,i], 'NNFull', colTM[i], fig=None, axs=None,
                                                         quantity="NN acceleration")
        else:
            figNN, axNN = plotUtils.plotPSDDeepSurfMulti(fNN, scaledNN[:,:,i], 'NNFull', colTM[i], fig=figNN, axs=axNN, 
                                                                      quantity="NN acceleration")
    
    NNRay,freqNNRay = NNCompute.getAnalyticRayNN(config, cavDepthUse)
    figRay, axRay = plt.subplots()
    axRay.plot(freqNNRay,NNRay)
    
    NNBody, minNN, freqNNBody = NNCompute.getAnalyticBodyNN(config,p=1/3)

    axNN[0].plot(freqNNRay, NNRay,'m',label='Analytical Rayleigh NN')
    axNN[1].plot(freqNNRay, NNRay,'m',label='Analytical Rayleigh NN')
    axNN[2].plot(freqNNRay, NNRay,'m',label='Analytical Rayleigh NN')

    axNN[0].plot(freqNNBody, NNBody,'c',label='Analytical Body NN')
    axNN[1].plot(freqNNBody, NNBody,'c',label='Analytical Body NN')
    axNN[2].plot(freqNNBody, NNBody,'c',label='Analytical Body NN')

    axNN[0].plot(freqNNBody, minNN,'g',label=r'$\frac{4\pi}{3} G \rho$')
    axNN[1].plot(freqNNBody, minNN,'g',label=r'$\frac{4\pi}{3} G \rho$')
    axNN[2].plot(freqNNBody, minNN,'g',label=r'$\frac{4\pi}{3} G \rho$')

    #axNN[0].legend()
    #axNN[1].legend()
    axNN[2].legend()

    axNN[0].set_ylim(10**-7,2*10**-6)
    axNN[1].set_ylim(10**-8,10**-5)
    axNN[2].set_ylim(10**-8,10**-5)

    ################################################################################################
    # compute scaleNN when the simulated displacement is scaled to match site ASD
    scaledNNToTrue = np.zeros((nFreq,3,nTM))
    nnProj = np.zeros((nFreq,3,nTM))
    for i in range(0,nTM):
        scaledNNToTrue[:,:,i], *__ = NNPP.scaleNN(nnAllRea[:,:,i], dispPointAllRea, freqOut, config, scaleComp="E",
                                       scaleDepth="depth", scaleToTrue=True)
        nnProj[:,:,i], ETD = NNPP.NNProjectToET(scaledNNToTrue[:,:,i], fNN, config)

    for i in range(0,nTM):
        if(i==0):
            figSens, axSens = plotUtils.plotNNStrainET(fNN, nnProj[:,:,i], ETD, title="Projected NN strain ASD", xlim=(1, 8), xscale="log",
                        yscale="log", comp_labels=("X", "Y", "Z"), sim_label="SimulatedTM"+str(i), etd_label="ET-D",
                        legend_once=True, fig=None,axs=None)
        else:
            figSens, axSens = plotUtils.plotNNStrainET(fNN, nnProj[:,:,i], ETD, title="Projected NN strain ASD", xlim=(1, 8), xscale="log",
                        yscale="log", comp_labels=("X", "Y", "Z"), sim_label="SimulatedTM" + str(i), etd_label="ET-D",
                        legend_once=True, fig=figSens,axs=axSens)

if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0. 5000.]
# Number of points per layer along Z = [125]
# Spacing in each layer in meters = [39.85153559 42.19409283]
# Qseis Inputs cleaned, parent folder intact.
# Creating all input files ...
# All input files created!
# Preparing to run 889 QSEIS jobs with 64 worker(s)...
# /home/koley/.conda/envs/pySeis1DNN/lib/python3.11/site-packages/pysurf96/wrapper.py:99: RuntimeWarning: overflow encountered in cast
#   error = surfdisp96(
# [Worker 3084537] Starting job Layer0Run0 at 17:36:42[Worker 3084544] Starting job Layer1Run0 at 17:36:42
# [Worker 3084538] Starting job Layer0Run1 at 17:36:42[Worker 3084540] Starting job Layer0Run3 at 17:36:42[Worker 3084539] Starting job Layer0Run2 at 17:36:42[Worker 3084541] Starting job Layer0Run4 at 17:36:42[Worker 3084543] Starting job Layer0Run6 at 17:36:42[Worker 3084542] Starting job Layer0Run5 at 17:36:42[Worker 3084545] Starting job Layer1Run1 at 17:36:42[Worker 3084546] Starting job Layer1Run2 at 17:36:42[Worker 3084547] Starting job Layer1Run3 at 17:36:42[Worker 3084549] Starting job Layer1Run5 at 17:36:42[Worker 3084548] Starting job Layer1Run4 at 17:36:42[Worker 3084552] Starting job Layer2Run1 at 17:36:42[Worker 3084551] Starting job Layer2Run0 at 17:36:42[Worker 3084550] Starting job Layer1Run6 at 17:36:42[Worker 3084553] Starting job Layer2Run2 at 17:36:42[Worker 3084556] Starting job Layer2Run5 at 17:36:42[Worker 3084554] Starting job Layer2Run3 at 17:36:42[Worker 3084555] Starting job Layer2Run4 at 17:36:42
#
# [Worker 3084557] Starting job Layer2Run6 at 17:36:42
# [Worker 3084558] Starting job Layer3Run0 at 17:36:42
# [Worker 3084564] Starting job Layer3Run6 at 17:36:42[Worker 3084563] Starting job Layer3Run5 at 17:36:42
#
#
#
#
#
# [Worker 3084565] Starting job Layer4Run0 at 17:36:42[Worker 3084562] Starting job Layer3Run4 at 17:36:42
#
#
#
#
# [Worker 3084559] Starting job Layer3Run1 at 17:36:42[Worker 3084568] Starting job Layer4Run3 at 17:36:42[Worker 3084566] Starting job Layer4Run1 at 17:36:42[Worker 3084567] Starting job Layer4Run2 at 17:36:42
#
# [Worker 3084571] Starting job Layer4Run6 at 17:36:42
#
# [Worker 3084569] Starting job Layer4Run4 at 17:36:42
#
# [Worker 3084570] Starting job Layer4Run5 at 17:36:42[Worker 3084572] Starting job Layer5Run0 at 17:36:42[Worker 3084574] Starting job Layer5Run2 at 17:36:42[Worker 3084573] Starting job Layer5Run1 at 17:36:42
# [Worker 3084575] Starting job Layer5Run3 at 17:36:42[Worker 3084577] Starting job Layer5Run5 at 17:36:42[Worker 3084576] Starting job Layer5Run4 at 17:36:42
# [Worker 3084578] Starting job Layer5Run6 at 17:36:42[Worker 3084579] Starting job Layer6Run0 at 17:36:42[Worker 3084580] Starting job Layer6Run1 at 17:36:42
# [Worker 3084581] Starting job Layer6Run2 at 17:36:42[Worker 3084582] Starting job Layer6Run3 at 17:36:42[Worker 3084583] Starting job Layer6Run4 at 17:36:42[Worker 3084584] Starting job Layer6Run5 at 17:36:42[Worker 3084585] Starting job Layer6Run6 at 17:36:42[Worker 3084587] Starting job Layer7Run1 at 17:36:42
#
#
# [Worker 3084589] Starting job Layer7Run3 at 17:36:42[Worker 3084588] Starting job Layer7Run2 at 17:36:42[Worker 3084590] Starting job Layer7Run4 at 17:36:42[Worker 3084586] Starting job Layer7Run0 at 17:36:42[Worker 3084591] Starting job Layer7Run5 at 17:36:42[Worker 3084593] Starting job Layer8Run0 at 17:36:42[Worker 3084592] Starting job Layer7Run6 at 17:36:42
#
#
# [Worker 3084594] Starting job Layer8Run1 at 17:36:42
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [Worker 3084561] Starting job Layer3Run3 at 17:36:42[Worker 3084560] Starting job Layer3Run2 at 17:36:42
#
# [Worker 3084599] Starting job Layer8Run6 at 17:36:42[Worker 3084598] Starting job Layer8Run5 at 17:36:42[Worker 3084597] Starting job Layer8Run4 at 17:36:42[Worker 3084596] Starting job Layer8Run3 at 17:36:42[Worker 3084595] Starting job Layer8Run2 at 17:36:42[Worker 3084600] Starting job Layer9Run0 at 17:36:42
#
#
#
#
#
# [Worker 3084600] Finished job Layer9Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084600] Starting job Layer9Run1 at 17:36:48
# [Worker 3084593] Finished job Layer8Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084593] Starting job Layer9Run2 at 17:36:48
# [Worker 3084579] Finished job Layer6Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084579] Starting job Layer9Run3 at 17:36:48
# Completed Layer9Run0
# Completed Layer8Run0
# Completed Layer6Run0
# [Worker 3084572] Finished job Layer5Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084572] Starting job Layer9Run4 at 17:36:48
# [Worker 3084586] Finished job Layer7Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084586] Starting job Layer9Run5 at 17:36:48
# Completed Layer5Run0
# Completed Layer7Run0
# [Worker 3084565] Finished job Layer4Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084565] Starting job Layer9Run6 at 17:36:48
# [Worker 3084537] Finished job Layer0Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084537] Starting job Layer10Run0 at 17:36:48
# [Worker 3084558] Finished job Layer3Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084558] Starting job Layer10Run1 at 17:36:48
# [Worker 3084551] Finished job Layer2Run0 at 17:36:48 (0.1 min, rc=0)
# Completed Layer4Run0
# Completed Layer0Run0
# Completed Layer3Run0
# Completed Layer2Run0
# [Worker 3084551] Starting job Layer10Run2 at 17:36:48
# [Worker 3084544] Finished job Layer1Run0 at 17:36:48 (0.1 min, rc=0)
# [Worker 3084544] Starting job Layer10Run3 at 17:36:48
# Completed Layer1Run0
# [Worker 3084594] Finished job Layer8Run1 at 17:36:52 (0.2 min, rc=0)
# [Worker 3084594] Starting job Layer10Run4 at 17:36:52
# Completed Layer8Run1
# [Worker 3084566] Finished job Layer4Run1 at 17:36:52 (0.2 min, rc=0)
# [Worker 3084566] Starting job Layer10Run5 at 17:36:52
# [Worker 3084580] Finished job Layer6Run1 at 17:36:52 (0.2 min, rc=0)
# [Worker 3084580] Starting job Layer10Run6 at 17:36:52
# [Worker 3084587] Finished job Layer7Run1 at 17:36:52 (0.2 min, rc=0)
# [Worker 3084587] Starting job Layer11Run0 at 17:36:52
# [Worker 3084573] Finished job Layer5Run1 at 17:36:52 (0.2 min, rc=0)
# [Worker 3084573] Starting job Layer11Run1 at 17:36:52
# Completed Layer4Run1
# Completed Layer6Run1
# Completed Layer7Run1
# Completed Layer5Run1
# [Worker 3084559] Finished job Layer3Run1 at 17:36:53 (0.2 min, rc=0)
# [Worker 3084559] Starting job Layer11Run2 at 17:36:53
# [Worker 3084552] Finished job Layer2Run1 at 17:36:53 (0.2 min, rc=0)
# [Worker 3084552] Starting job Layer11Run3 at 17:36:53
# [Worker 3084538] Finished job Layer0Run1 at 17:36:53 (0.2 min, rc=0)
# [Worker 3084538] Starting job Layer11Run4 at 17:36:53[Worker 3084545] Finished job Layer1Run1 at 17:36:53 (0.2 min, rc=0)
#
# [Worker 3084545] Starting job Layer11Run5 at 17:36:53
# Completed Layer3Run1
# Completed Layer2Run1
# Completed Layer0Run1
# Completed Layer1Run1
# [Worker 3084537] Finished job Layer10Run0 at 17:36:54 (0.1 min, rc=0)
# [Worker 3084537] Starting job Layer11Run6 at 17:36:54
# Completed Layer10Run0
# [Worker 3084595] Finished job Layer8Run2 at 17:36:56 (0.2 min, rc=0)
# [Worker 3084595] Starting job Layer12Run0 at 17:36:56
# Completed Layer8Run2
# [Worker 3084581] Finished job Layer6Run2 at 17:36:57 (0.2 min, rc=0)
# [Worker 3084581] Starting job Layer12Run1 at 17:36:57
# [Worker 3084600] Finished job Layer9Run1 at 17:36:57 (0.2 min, rc=0)
# [Worker 3084600] Starting job Layer12Run2 at 17:36:57
# Completed Layer6Run2
# Completed Layer9Run1
# [Worker 3084588] Finished job Layer7Run2 at 17:36:57 (0.3 min, rc=0)
# [Worker 3084588] Starting job Layer12Run3 at 17:36:57
# Completed Layer7Run2
# [Worker 3084567] Finished job Layer4Run2 at 17:36:58 (0.3 min, rc=0)
# [Worker 3084567] Starting job Layer12Run4 at 17:36:58
# [Worker 3084574] Finished job Layer5Run2 at 17:36:58 (0.3 min, rc=0)
# [Worker 3084574] Starting job Layer12Run5 at 17:36:58
# Completed Layer4Run2
# Completed Layer5Run2
# [Worker 3084587] Finished job Layer11Run0 at 17:36:58 (0.1 min, rc=0)
# [Worker 3084587] Starting job Layer12Run6 at 17:36:58
# [Worker 3084558] Finished job Layer10Run1 at 17:36:58 (0.2 min, rc=0)
# [Worker 3084558] Starting job Layer13Run0 at 17:36:58
# Completed Layer11Run0
# Completed Layer10Run1
# [Worker 3084560] Finished job Layer3Run2 at 17:36:58 (0.3 min, rc=0)
# [Worker 3084560] Starting job Layer13Run1 at 17:36:58
# Completed Layer3Run2
# [Worker 3084539] Finished job Layer0Run2 at 17:36:58 (0.3 min, rc=0)
# [Worker 3084539] Starting job Layer13Run2 at 17:36:58
# [Worker 3084546] Finished job Layer1Run2 at 17:36:59 (0.3 min, rc=0)
# [Worker 3084546] Starting job Layer13Run3 at 17:36:59
# [Worker 3084553] Finished job Layer2Run2 at 17:36:59 (0.3 min, rc=0)
# [Worker 3084553] Starting job Layer13Run4 at 17:36:59
# Completed Layer0Run2
# Completed Layer1Run2
# Completed Layer2Run2
# [Worker 3084596] Finished job Layer8Run3 at 17:37:02 (0.3 min, rc=0)
# [Worker 3084596] Starting job Layer13Run5 at 17:37:02
# Completed Layer8Run3
# [Worker 3084589] Finished job Layer7Run3 at 17:37:02 (0.3 min, rc=0)
# [Worker 3084589] Starting job Layer13Run6 at 17:37:02
# Completed Layer7Run3
# [Worker 3084593] Finished job Layer9Run2 at 17:37:02 (0.2 min, rc=0)
# [Worker 3084595] Finished job Layer12Run0 at 17:37:02 (0.1 min, rc=0)
# [Worker 3084573] Finished job Layer11Run1 at 17:37:02 (0.2 min, rc=0)[Worker 3084593] Starting job Layer14Run0 at 17:37:02[Worker 3084595] Starting job Layer14Run1 at 17:37:02
#
#
# [Worker 3084573] Starting job Layer14Run2 at 17:37:02
# [Worker 3084575] Finished job Layer5Run3 at 17:37:02 (0.3 min, rc=0)
# [Worker 3084575] Starting job Layer14Run3 at 17:37:02
# [Worker 3084582] Finished job Layer6Run3 at 17:37:02 (0.3 min, rc=0)
# [Worker 3084582] Starting job Layer14Run4 at 17:37:02
# Completed Layer9Run2
# Completed Layer12Run0
# Completed Layer11Run1
# Completed Layer5Run3
# Completed Layer6Run3
# [Worker 3084568] Finished job Layer4Run3 at 17:37:03 (0.3 min, rc=0)
# [Worker 3084568] Starting job Layer14Run5 at 17:37:03
# [Worker 3084551] Finished job Layer10Run2 at 17:37:03 (0.2 min, rc=0)
# [Worker 3084551] Starting job Layer14Run6 at 17:37:03
# Completed Layer4Run3
# Completed Layer10Run2
# [Worker 3084558] Finished job Layer13Run0 at 17:37:04 (0.1 min, rc=0)
# [Worker 3084558] Starting job Layer15Run0 at 17:37:04
# [Worker 3084540] Finished job Layer0Run3 at 17:37:04 (0.4 min, rc=0)
# [Worker 3084540] Starting job Layer15Run1 at 17:37:04
# Completed Layer13Run0
# Completed Layer0Run3
# [Worker 3084554] Finished job Layer2Run3 at 17:37:04 (0.4 min, rc=0)
# [Worker 3084554] Starting job Layer15Run2 at 17:37:04
# Completed Layer2Run3
# [Worker 3084561] Finished job Layer3Run3 at 17:37:04 (0.4 min, rc=0)
# [Worker 3084561] Starting job Layer15Run3 at 17:37:04
# Completed Layer3Run3
# [Worker 3084547] Finished job Layer1Run3 at 17:37:04 (0.4 min, rc=0)
# [Worker 3084547] Starting job Layer15Run4 at 17:37:04
# Completed Layer1Run3
# [Worker 3084597] Finished job Layer8Run4 at 17:37:06 (0.4 min, rc=0)
# [Worker 3084597] Starting job Layer15Run5 at 17:37:06
# Completed Layer8Run4
# [Worker 3084581] Finished job Layer12Run1 at 17:37:07 (0.2 min, rc=0)
# [Worker 3084581] Starting job Layer15Run6 at 17:37:07
# Completed Layer12Run1
# [Worker 3084579] Finished job Layer9Run3 at 17:37:07 (0.3 min, rc=0)
# [Worker 3084579] Starting job Layer16Run0 at 17:37:07
# [Worker 3084590] Finished job Layer7Run4 at 17:37:07 (0.4 min, rc=0)
# [Worker 3084590] Starting job Layer16Run1 at 17:37:07
# [Worker 3084583] Finished job Layer6Run4 at 17:37:07 (0.4 min, rc=0)
# [Worker 3084583] Starting job Layer16Run2 at 17:37:07
# Completed Layer9Run3
# Completed Layer7Run4
# Completed Layer6Run4
# [Worker 3084576] Finished job Layer5Run4 at 17:37:07 (0.4 min, rc=0)
# [Worker 3084576] Starting job Layer16Run3 at 17:37:07
# [Worker 3084569] Finished job Layer4Run4 at 17:37:08 (0.4 min, rc=0)
# [Worker 3084569] Starting job Layer16Run4 at 17:37:08
# Completed Layer5Run4
# Completed Layer4Run4
# [Worker 3084559] Finished job Layer11Run2 at 17:37:08 (0.2 min, rc=0)
# [Worker 3084559] Starting job Layer16Run5 at 17:37:08
# [Worker 3084593] Finished job Layer14Run0 at 17:37:08 (0.1 min, rc=0)
# [Worker 3084593] Starting job Layer16Run6 at 17:37:08
# [Worker 3084544] Finished job Layer10Run3 at 17:37:08 (0.3 min, rc=0)
# [Worker 3084544] Starting job Layer17Run0 at 17:37:08
# [Worker 3084560] Finished job Layer13Run1 at 17:37:08 (0.2 min, rc=0)
# [Worker 3084560] Starting job Layer17Run1 at 17:37:08
# Completed Layer11Run2
# Completed Layer14Run0
# Completed Layer10Run3
# Completed Layer13Run1
# [Worker 3084555] Finished job Layer2Run4 at 17:37:09 (0.4 min, rc=0)
# [Worker 3084555] Starting job Layer17Run2 at 17:37:09
# [Worker 3084541] Finished job Layer0Run4 at 17:37:09 (0.4 min, rc=0)
# [Worker 3084541] Starting job Layer17Run3 at 17:37:09
# Completed Layer2Run4
# Completed Layer0Run4
# [Worker 3084558] Finished job Layer15Run0 at 17:37:09 (0.1 min, rc=0)
# [Worker 3084558] Starting job Layer17Run4 at 17:37:09
# [Worker 3084562] Finished job Layer3Run4 at 17:37:09 (0.5 min, rc=0)
# [Worker 3084562] Starting job Layer17Run5 at 17:37:09
# Completed Layer15Run0
# Completed Layer3Run4
# [Worker 3084548] Finished job Layer1Run4 at 17:37:10 (0.5 min, rc=0)
# [Worker 3084548] Starting job Layer17Run6 at 17:37:10
# Completed Layer1Run4
# [Worker 3084598] Finished job Layer8Run5 at 17:37:11 (0.5 min, rc=0)
# [Worker 3084598] Starting job Layer18Run0 at 17:37:11
# [Worker 3084591] Finished job Layer7Run5 at 17:37:12 (0.5 min, rc=0)
# [Worker 3084591] Starting job Layer18Run1 at 17:37:12
# Completed Layer8Run5
# Completed Layer7Run5
# [Worker 3084600] Finished job Layer12Run2 at 17:37:12 (0.2 min, rc=0)
# [Worker 3084600] Starting job Layer18Run2 at 17:37:12
# [Worker 3084572] Finished job Layer9Run4 at 17:37:12 (0.4 min, rc=0)
# [Worker 3084572] Starting job Layer18Run3 at 17:37:12
# Completed Layer12Run2
# Completed Layer9Run4
# [Worker 3084552] Finished job Layer11Run3 at 17:37:12 (0.3 min, rc=0)
# [Worker 3084552] Starting job Layer18Run4 at 17:37:12
# Completed Layer11Run3
# [Worker 3084577] Finished job Layer5Run5 at 17:37:12 (0.5 min, rc=0)
# [Worker 3084577] Starting job Layer18Run5 at 17:37:12
# Completed Layer5Run5
# [Worker 3084584] Finished job Layer6Run5 at 17:37:13 (0.5 min, rc=0)
# [Worker 3084584] Starting job Layer18Run6 at 17:37:13
# [Worker 3084595] Finished job Layer14Run1 at 17:37:13 (0.2 min, rc=0)
# [Worker 3084595] Starting job Layer19Run0 at 17:37:13
# Completed Layer6Run5
# Completed Layer14Run1
# [Worker 3084579] Finished job Layer16Run0 at 17:37:13 (0.1 min, rc=0)
# [Worker 3084579] Starting job Layer19Run1 at 17:37:13
# Completed Layer16Run0
# [Worker 3084563] Finished job Layer3Run5 at 17:37:13 (0.5 min, rc=0)
# [Worker 3084563] Starting job Layer19Run2 at 17:37:13
# [Worker 3084539] Finished job Layer13Run2 at 17:37:13 (0.2 min, rc=0)
# [Worker 3084539] Starting job Layer19Run3 at 17:37:13
# [Worker 3084544] Finished job Layer17Run0 at 17:37:14 (0.1 min, rc=0)
# [Worker 3084544] Starting job Layer19Run4 at 17:37:14
# Completed Layer3Run5
# Completed Layer13Run2
# Completed Layer17Run0
# [Worker 3084540] Finished job Layer15Run1 at 17:37:14 (0.2 min, rc=0)
# [Worker 3084540] Starting job Layer19Run5 at 17:37:14
# [Worker 3084570] Finished job Layer4Run5 at 17:37:14 (0.5 min, rc=0)
# [Worker 3084570] Starting job Layer19Run6 at 17:37:14
# Completed Layer15Run1
# Completed Layer4Run5
# [Worker 3084556] Finished job Layer2Run5 at 17:37:15 (0.5 min, rc=0)
# [Worker 3084556] Starting job Layer20Run0 at 17:37:15
# [Worker 3084542] Finished job Layer0Run5 at 17:37:15 (0.5 min, rc=0)
# [Worker 3084542] Starting job Layer20Run1 at 17:37:15
# Completed Layer2Run5
# Completed Layer0Run5
# [Worker 3084549] Finished job Layer1Run5 at 17:37:16 (0.6 min, rc=0)
# [Worker 3084549] Starting job Layer20Run2 at 17:37:16
# Completed Layer1Run5
# [Worker 3084594] Finished job Layer10Run4 at 17:37:16 (0.4 min, rc=0)
# [Worker 3084594] Starting job Layer20Run3 at 17:37:16
# Completed Layer10Run4
# [Worker 3084588] Finished job Layer12Run3 at 17:37:16 (0.3 min, rc=0)
# [Worker 3084588] Starting job Layer20Run4 at 17:37:16
# [Worker 3084599] Finished job Layer8Run6 at 17:37:17 (0.6 min, rc=0)
# [Worker 3084599] Starting job Layer20Run5 at 17:37:17
# Completed Layer12Run3
# Completed Layer8Run6
# [Worker 3084592] Finished job Layer7Run6 at 17:37:17 (0.6 min, rc=0)
# [Worker 3084592] Starting job Layer20Run6 at 17:37:17
# Completed Layer7Run6
# [Worker 3084573] Finished job Layer14Run2 at 17:37:17 (0.2 min, rc=0)
# [Worker 3084573] Starting job Layer21Run0 at 17:37:17
# [Worker 3084586] Finished job Layer9Run5 at 17:37:17 (0.5 min, rc=0)
# [Worker 3084586] Starting job Layer21Run1 at 17:37:17
# [Worker 3084590] Finished job Layer16Run1 at 17:37:17 (0.2 min, rc=0)
# [Worker 3084590] Starting job Layer21Run2 at 17:37:17
# Completed Layer14Run2
# Completed Layer9Run5
# Completed Layer16Run1
# [Worker 3084585] Finished job Layer6Run6 at 17:37:17 (0.6 min, rc=0)
# [Worker 3084585] Starting job Layer21Run3 at 17:37:17
# [Worker 3084598] Finished job Layer18Run0 at 17:37:17 (0.1 min, rc=0)
# [Worker 3084598] Starting job Layer21Run4 at 17:37:17
# Completed Layer6Run6
# Completed Layer18Run0
# [Worker 3084538] Finished job Layer11Run4 at 17:37:18 (0.4 min, rc=0)
# [Worker 3084538] Starting job Layer21Run5 at 17:37:18
# [Worker 3084546] Finished job Layer13Run3 at 17:37:18 (0.3 min, rc=0)
# [Worker 3084546] Starting job Layer21Run6 at 17:37:18
# [Worker 3084560] Finished job Layer17Run1 at 17:37:18 (0.2 min, rc=0)
# [Worker 3084560] Starting job Layer22Run0 at 17:37:18
# Completed Layer11Run4
# Completed Layer13Run3
# Completed Layer17Run1
# [Worker 3084595] Finished job Layer19Run0 at 17:37:18 (0.1 min, rc=0)
# [Worker 3084595] Starting job Layer22Run1 at 17:37:18
# [Worker 3084554] Finished job Layer15Run2 at 17:37:18 (0.2 min, rc=0)
# [Worker 3084554] Starting job Layer22Run2 at 17:37:18
# [Worker 3084571] Finished job Layer4Run6 at 17:37:18 (0.6 min, rc=0)
# [Worker 3084571] Starting job Layer22Run3 at 17:37:18
# [Worker 3084578] Finished job Layer5Run6 at 17:37:18 (0.6 min, rc=0)
# [Worker 3084578] Starting job Layer22Run4 at 17:37:18
# Completed Layer19Run0
# Completed Layer15Run2
# Completed Layer4Run6
# Completed Layer5Run6
# [Worker 3084564] Finished job Layer3Run6 at 17:37:19 (0.6 min, rc=0)
# [Worker 3084564] Starting job Layer22Run5 at 17:37:19
# Completed Layer3Run6
# [Worker 3084543] Finished job Layer0Run6 at 17:37:20 (0.6 min, rc=0)
# [Worker 3084543] Starting job Layer22Run6 at 17:37:20
# Completed Layer0Run6
# [Worker 3084556] Finished job Layer20Run0 at 17:37:20 (0.1 min, rc=0)
# [Worker 3084556] Starting job Layer23Run0 at 17:37:20
# Completed Layer20Run0
# [Worker 3084557] Finished job Layer2Run6 at 17:37:21 (0.6 min, rc=0)
# [Worker 3084557] Starting job Layer23Run1 at 17:37:21
# Completed Layer2Run6
# [Worker 3084567] Finished job Layer12Run4 at 17:37:21 (0.4 min, rc=0)
# [Worker 3084567] Starting job Layer23Run2 at 17:37:21
# [Worker 3084575] Finished job Layer14Run3 at 17:37:21 (0.3 min, rc=0)
# [Worker 3084575] Starting job Layer23Run3 at 17:37:21
# Completed Layer12Run4
# Completed Layer14Run3
# [Worker 3084591] Finished job Layer18Run1 at 17:37:21 (0.2 min, rc=0)
# [Worker 3084591] Starting job Layer23Run4 at 17:37:21
# Completed Layer18Run1
# [Worker 3084566] Finished job Layer10Run5 at 17:37:21 (0.5 min, rc=0)
# [Worker 3084566] Starting job Layer23Run5 at 17:37:21
# [Worker 3084550] Finished job Layer1Run6 at 17:37:22 (0.7 min, rc=0)
# [Worker 3084550] Starting job Layer23Run6 at 17:37:22
# Completed Layer10Run5
# Completed Layer1Run6
# [Worker 3084565] Finished job Layer9Run6 at 17:37:22 (0.6 min, rc=0)
# [Worker 3084565] Starting job Layer24Run0 at 17:37:22
# [Worker 3084583] Finished job Layer16Run2 at 17:37:22 (0.2 min, rc=0)
# [Worker 3084583] Starting job Layer24Run1 at 17:37:22
# Completed Layer9Run6
# Completed Layer16Run2
# [Worker 3084545] Finished job Layer11Run5 at 17:37:22 (0.5 min, rc=0)
# [Worker 3084545] Starting job Layer24Run2 at 17:37:22
# [Worker 3084573] Finished job Layer21Run0 at 17:37:22 (0.1 min, rc=0)
# [Worker 3084573] Starting job Layer24Run3 at 17:37:22
# Completed Layer11Run5
# Completed Layer21Run0
# [Worker 3084579] Finished job Layer19Run1 at 17:37:23 (0.2 min, rc=0)
# [Worker 3084579] Starting job Layer24Run4 at 17:37:23
# [Worker 3084553] Finished job Layer13Run4 at 17:37:23 (0.4 min, rc=0)
# [Worker 3084553] Starting job Layer24Run5 at 17:37:23
# Completed Layer19Run1
# Completed Layer13Run4
# [Worker 3084561] Finished job Layer15Run3 at 17:37:23 (0.3 min, rc=0)
# [Worker 3084561] Starting job Layer24Run6 at 17:37:23
# [Worker 3084560] Finished job Layer22Run0 at 17:37:23 (0.1 min, rc=0)
# [Worker 3084560] Starting job Layer25Run0 at 17:37:23
# [Worker 3084555] Finished job Layer17Run2 at 17:37:23 (0.2 min, rc=0)
# [Worker 3084555] Starting job Layer25Run1 at 17:37:23
# Completed Layer15Run3
# Completed Layer22Run0
# Completed Layer17Run2
# [Worker 3084542] Finished job Layer20Run1 at 17:37:25 (0.2 min, rc=0)
# [Worker 3084542] Starting job Layer25Run2 at 17:37:25
# Completed Layer20Run1
# [Worker 3084582] Finished job Layer14Run4 at 17:37:26 (0.4 min, rc=0)
# [Worker 3084582] Starting job Layer25Run3 at 17:37:26
# [Worker 3084556] Finished job Layer23Run0 at 17:37:26 (0.1 min, rc=0)
# [Worker 3084556] Starting job Layer25Run4 at 17:37:26
# [Worker 3084600] Finished job Layer18Run2 at 17:37:26 (0.2 min, rc=0)
# [Worker 3084600] Starting job Layer25Run5 at 17:37:26
# Completed Layer14Run4
# Completed Layer23Run0
# Completed Layer18Run2
# [Worker 3084580] Finished job Layer10Run6 at 17:37:26 (0.6 min, rc=0)
# [Worker 3084580] Starting job Layer25Run6 at 17:37:26
# [Worker 3084574] Finished job Layer12Run5 at 17:37:26 (0.5 min, rc=0)
# [Worker 3084574] Starting job Layer26Run0 at 17:37:26
# [Worker 3084576] Finished job Layer16Run3 at 17:37:26 (0.3 min, rc=0)
# [Worker 3084576] Starting job Layer26Run1 at 17:37:26
# Completed Layer10Run6
# Completed Layer12Run5
# Completed Layer16Run3
# [Worker 3084586] Finished job Layer21Run1 at 17:37:27 (0.2 min, rc=0)
# [Worker 3084586] Starting job Layer26Run2 at 17:37:27
# Completed Layer21Run1
# [Worker 3084563] Finished job Layer19Run2 at 17:37:27 (0.2 min, rc=0)
# [Worker 3084563] Starting job Layer26Run3 at 17:37:27
# Completed Layer19Run2
# [Worker 3084565] Finished job Layer24Run0 at 17:37:27 (0.1 min, rc=0)
# [Worker 3084565] Starting job Layer26Run4 at 17:37:27
# [Worker 3084537] Finished job Layer11Run6 at 17:37:27 (0.6 min, rc=0)
# [Worker 3084537] Starting job Layer26Run5 at 17:37:27
# Completed Layer24Run0
# Completed Layer11Run6
# [Worker 3084541] Finished job Layer17Run3 at 17:37:28 (0.3 min, rc=0)
# [Worker 3084541] Starting job Layer26Run6 at 17:37:28
# [Worker 3084595] Finished job Layer22Run1 at 17:37:28 (0.2 min, rc=0)
# [Worker 3084595] Starting job Layer27Run0 at 17:37:28
# Completed Layer17Run3
# Completed Layer22Run1
# [Worker 3084560] Finished job Layer25Run0 at 17:37:29 (0.1 min, rc=0)
# [Worker 3084560] Starting job Layer27Run1 at 17:37:29
# Completed Layer25Run0
# [Worker 3084547] Finished job Layer15Run4 at 17:37:29 (0.4 min, rc=0)
# [Worker 3084547] Starting job Layer27Run2 at 17:37:29
# Completed Layer15Run4
# [Worker 3084549] Finished job Layer20Run2 at 17:37:30 (0.2 min, rc=0)
# [Worker 3084549] Starting job Layer27Run3 at 17:37:30
# Completed Layer20Run2
# [Worker 3084557] Finished job Layer23Run1 at 17:37:30 (0.2 min, rc=0)
# [Worker 3084557] Starting job Layer27Run4 at 17:37:30
# Completed Layer23Run1
# [Worker 3084590] Finished job Layer21Run2 at 17:37:31 (0.2 min, rc=0)
# [Worker 3084590] Starting job Layer27Run5 at 17:37:31
# [Worker 3084568] Finished job Layer14Run5 at 17:37:31 (0.5 min, rc=0)
# [Worker 3084568] Starting job Layer27Run6 at 17:37:31
# [Worker 3084596] Finished job Layer13Run5 at 17:37:31 (0.5 min, rc=0)
# [Worker 3084596] Starting job Layer28Run0 at 17:37:31
# Completed Layer21Run2
# Completed Layer14Run5
# Completed Layer13Run5
# [Worker 3084569] Finished job Layer16Run4 at 17:37:31 (0.4 min, rc=0)
# [Worker 3084569] Starting job Layer28Run1 at 17:37:31
# Completed Layer16Run4
# [Worker 3084587] Finished job Layer12Run6 at 17:37:31 (0.6 min, rc=0)
# [Worker 3084587] Starting job Layer28Run2 at 17:37:31
# [Worker 3084574] Finished job Layer26Run0 at 17:37:32 (0.1 min, rc=0)
# [Worker 3084574] Starting job Layer28Run3 at 17:37:32
# [Worker 3084539] Finished job Layer19Run3 at 17:37:32 (0.3 min, rc=0)
# [Worker 3084539] Starting job Layer28Run4 at 17:37:32
# Completed Layer12Run6
# Completed Layer26Run0
# Completed Layer19Run3
# [Worker 3084583] Finished job Layer24Run1 at 17:37:32 (0.2 min, rc=0)
# [Worker 3084583] Starting job Layer28Run5 at 17:37:32
# [Worker 3084572] Finished job Layer18Run3 at 17:37:32 (0.3 min, rc=0)
# [Worker 3084572] Starting job Layer28Run6 at 17:37:32
# Completed Layer24Run1
# Completed Layer18Run3
# [Worker 3084554] Finished job Layer22Run2 at 17:37:33 (0.2 min, rc=0)
# [Worker 3084554] Starting job Layer29Run0 at 17:37:33
# Completed Layer22Run2
# [Worker 3084555] Finished job Layer25Run1 at 17:37:33 (0.2 min, rc=0)
# [Worker 3084555] Starting job Layer29Run1 at 17:37:33
# Completed Layer25Run1
# [Worker 3084558] Finished job Layer17Run4 at 17:37:33 (0.4 min, rc=0)
# [Worker 3084558] Starting job Layer29Run2 at 17:37:33
# [Worker 3084595] Finished job Layer27Run0 at 17:37:34 (0.1 min, rc=0)
# [Worker 3084595] Starting job Layer29Run3 at 17:37:34
# Completed Layer17Run4
# Completed Layer27Run0
# [Worker 3084594] Finished job Layer20Run3 at 17:37:35 (0.3 min, rc=0)
# [Worker 3084594] Starting job Layer29Run4 at 17:37:35
# Completed Layer20Run3
# [Worker 3084552] Finished job Layer18Run4 at 17:37:35 (0.4 min, rc=0)
# [Worker 3084552] Starting job Layer29Run5 at 17:37:35
# [Worker 3084597] Finished job Layer15Run5 at 17:37:35 (0.5 min, rc=0)
# [Worker 3084597] Starting job Layer29Run6 at 17:37:35
# [Worker 3084589] Finished job Layer13Run6 at 17:37:35 (0.6 min, rc=0)
# [Worker 3084589] Starting job Layer30Run0 at 17:37:35
# Completed Layer18Run4
# Completed Layer15Run5
# Completed Layer13Run6
# [Worker 3084559] Finished job Layer16Run5 at 17:37:36 (0.5 min, rc=0)
# [Worker 3084559] Starting job Layer30Run1 at 17:37:36
# [Worker 3084585] Finished job Layer21Run3 at 17:37:36 (0.3 min, rc=0)
# [Worker 3084585] Starting job Layer30Run2 at 17:37:36
# [Worker 3084567] Finished job Layer23Run2 at 17:37:36 (0.2 min, rc=0)
# [Worker 3084567] Starting job Layer30Run3 at 17:37:36
# [Worker 3084576] Finished job Layer26Run1 at 17:37:36 (0.2 min, rc=0)
# [Worker 3084576] Starting job Layer30Run4 at 17:37:36
# [Worker 3084551] Finished job Layer14Run6 at 17:37:36 (0.5 min, rc=0)
# [Worker 3084551] Starting job Layer30Run5 at 17:37:36
# Completed Layer16Run5
# Completed Layer21Run3
# Completed Layer23Run2
# Completed Layer26Run1
# Completed Layer14Run6
# [Worker 3084545] Finished job Layer24Run2 at 17:37:36 (0.2 min, rc=0)
# [Worker 3084545] Starting job Layer30Run6 at 17:37:36
# Completed Layer24Run2
# [Worker 3084571] Finished job Layer22Run3 at 17:37:37 (0.3 min, rc=0)
# [Worker 3084571] Starting job Layer31Run0 at 17:37:37
# [Worker 3084596] Finished job Layer28Run0 at 17:37:37 (0.1 min, rc=0)
# [Worker 3084596] Starting job Layer31Run1 at 17:37:37
# Completed Layer22Run3
# Completed Layer28Run0
# [Worker 3084562] Finished job Layer17Run5 at 17:37:37 (0.5 min, rc=0)
# [Worker 3084562] Starting job Layer31Run2 at 17:37:37
# [Worker 3084544] Finished job Layer19Run4 at 17:37:37 (0.4 min, rc=0)
# [Worker 3084544] Starting job Layer31Run3 at 17:37:37
# Completed Layer17Run5
# Completed Layer19Run4
# [Worker 3084554] Finished job Layer29Run0 at 17:37:38 (0.1 min, rc=0)
# [Worker 3084554] Starting job Layer31Run4 at 17:37:38
# Completed Layer29Run0
# [Worker 3084560] Finished job Layer27Run1 at 17:37:39 (0.2 min, rc=0)
# [Worker 3084560] Starting job Layer31Run5 at 17:37:39
# Completed Layer27Run1
# [Worker 3084581] Finished job Layer15Run6 at 17:37:39 (0.5 min, rc=0)
# [Worker 3084581] Starting job Layer31Run6 at 17:37:39
# [Worker 3084575] Finished job Layer23Run3 at 17:37:39 (0.3 min, rc=0)
# [Worker 3084575] Starting job Layer32Run0 at 17:37:39
# Completed Layer15Run6
# Completed Layer23Run3
# [Worker 3084542] Finished job Layer25Run2 at 17:37:40 (0.2 min, rc=0)
# [Worker 3084542] Starting job Layer32Run1 at 17:37:40
# Completed Layer25Run2
# [Worker 3084589] Finished job Layer30Run0 at 17:37:40 (0.1 min, rc=0)
# [Worker 3084589] Starting job Layer32Run2 at 17:37:40
# [Worker 3084577] Finished job Layer18Run5 at 17:37:40 (0.5 min, rc=0)
# [Worker 3084577] Starting job Layer32Run3 at 17:37:40
# [Worker 3084569] Finished job Layer28Run1 at 17:37:41 (0.2 min, rc=0)
# [Worker 3084569] Starting job Layer32Run4 at 17:37:41
# Completed Layer30Run0
# Completed Layer18Run5
# Completed Layer28Run1
# [Worker 3084593] Finished job Layer16Run6 at 17:37:41 (0.6 min, rc=0)
# [Worker 3084593] Starting job Layer32Run5 at 17:37:41
# [Worker 3084598] Finished job Layer21Run4 at 17:37:41 (0.4 min, rc=0)
# [Worker 3084598] Starting job Layer32Run6 at 17:37:41
# [Worker 3084588] Finished job Layer20Run4 at 17:37:41 (0.4 min, rc=0)
# [Worker 3084588] Starting job Layer33Run0 at 17:37:41
# [Worker 3084578] Finished job Layer22Run4 at 17:37:41 (0.4 min, rc=0)
# [Worker 3084578] Starting job Layer33Run1 at 17:37:41
# Completed Layer16Run6
# Completed Layer21Run4
# Completed Layer20Run4
# Completed Layer22Run4
# [Worker 3084573] Finished job Layer24Run3 at 17:37:41 (0.3 min, rc=0)
# [Worker 3084573] Starting job Layer33Run2 at 17:37:41
# [Worker 3084586] Finished job Layer26Run2 at 17:37:41 (0.2 min, rc=0)
# [Worker 3084586] Starting job Layer33Run3 at 17:37:41
# Completed Layer24Run3
# Completed Layer26Run2
# [Worker 3084571] Finished job Layer31Run0 at 17:37:42 (0.1 min, rc=0)
# [Worker 3084571] Starting job Layer33Run4 at 17:37:42
# Completed Layer31Run0
# [Worker 3084548] Finished job Layer17Run6 at 17:37:42 (0.5 min, rc=0)
# [Worker 3084548] Starting job Layer33Run5 at 17:37:42
# Completed Layer17Run6
# [Worker 3084555] Finished job Layer29Run1 at 17:37:43 (0.2 min, rc=0)
# [Worker 3084555] Starting job Layer33Run6 at 17:37:43
# [Worker 3084540] Finished job Layer19Run5 at 17:37:43 (0.5 min, rc=0)
# [Worker 3084540] Starting job Layer34Run0 at 17:37:43
# Completed Layer29Run1
# Completed Layer19Run5
# [Worker 3084547] Finished job Layer27Run2 at 17:37:43 (0.2 min, rc=0)
# [Worker 3084547] Starting job Layer34Run1 at 17:37:43
# Completed Layer27Run2
# [Worker 3084591] Finished job Layer23Run4 at 17:37:44 (0.4 min, rc=0)
# [Worker 3084591] Starting job Layer34Run2 at 17:37:44
# Completed Layer23Run4
# [Worker 3084599] Finished job Layer20Run5 at 17:37:44 (0.5 min, rc=0)
# [Worker 3084599] Starting job Layer34Run3 at 17:37:44
# [Worker 3084575] Finished job Layer32Run0 at 17:37:45 (0.1 min, rc=0)
# [Worker 3084575] Starting job Layer34Run4 at 17:37:45
# Completed Layer20Run5
# Completed Layer32Run0
# [Worker 3084559] Finished job Layer30Run1 at 17:37:45 (0.2 min, rc=0)
# [Worker 3084559] Starting job Layer34Run5 at 17:37:45
# [Worker 3084538] Finished job Layer21Run5 at 17:37:45 (0.5 min, rc=0)
# [Worker 3084538] Starting job Layer34Run6 at 17:37:45
# Completed Layer30Run1
# Completed Layer21Run5
# [Worker 3084584] Finished job Layer18Run6 at 17:37:45 (0.5 min, rc=0)
# [Worker 3084584] Starting job Layer35Run0 at 17:37:45
# Completed Layer18Run6
# [Worker 3084570] Finished job Layer19Run6 at 17:37:45 (0.5 min, rc=0)
# [Worker 3084570] Starting job Layer35Run1 at 17:37:45
# [Worker 3084587] Finished job Layer28Run2 at 17:37:46 (0.2 min, rc=0)
# [Worker 3084587] Starting job Layer35Run2 at 17:37:46
# Completed Layer19Run6
# Completed Layer28Run2
# [Worker 3084563] Finished job Layer26Run3 at 17:37:46 (0.3 min, rc=0)
# [Worker 3084563] Starting job Layer35Run3 at 17:37:46
# Completed Layer26Run3
# [Worker 3084582] Finished job Layer25Run3 at 17:37:46 (0.3 min, rc=0)
# [Worker 3084582] Starting job Layer35Run4 at 17:37:46
# Completed Layer25Run3
# [Worker 3084596] Finished job Layer31Run1 at 17:37:46 (0.2 min, rc=0)
# [Worker 3084596] Starting job Layer35Run5 at 17:37:46
# [Worker 3084588] Finished job Layer33Run0 at 17:37:46 (0.1 min, rc=0)
# [Worker 3084588] Starting job Layer35Run6 at 17:37:46
# Completed Layer31Run1
# Completed Layer33Run0
# [Worker 3084564] Finished job Layer22Run5 at 17:37:47 (0.5 min, rc=0)
# [Worker 3084564] Starting job Layer36Run0 at 17:37:47
# Completed Layer22Run5
# [Worker 3084558] Finished job Layer29Run2 at 17:37:47 (0.2 min, rc=0)
# [Worker 3084558] Starting job Layer36Run1 at 17:37:47
# Completed Layer29Run2
# [Worker 3084579] Finished job Layer24Run4 at 17:37:48 (0.4 min, rc=0)
# [Worker 3084579] Starting job Layer36Run2 at 17:37:48
# [Worker 3084540] Finished job Layer34Run0 at 17:37:48 (0.1 min, rc=0)
# [Worker 3084540] Starting job Layer36Run3 at 17:37:48
# [Worker 3084549] Finished job Layer27Run3 at 17:37:48 (0.3 min, rc=0)
# [Worker 3084549] Starting job Layer36Run4 at 17:37:48
# Completed Layer24Run4
# Completed Layer34Run0
# Completed Layer27Run3
# [Worker 3084556] Finished job Layer25Run4 at 17:37:48 (0.4 min, rc=0)
# [Worker 3084556] Starting job Layer36Run5 at 17:37:48
# [Worker 3084592] Finished job Layer20Run6 at 17:37:49 (0.5 min, rc=0)
# [Worker 3084592] Starting job Layer36Run6 at 17:37:49
# Completed Layer25Run4
# Completed Layer20Run6
# [Worker 3084542] Finished job Layer32Run1 at 17:37:49 (0.2 min, rc=0)
# [Worker 3084542] Starting job Layer37Run0 at 17:37:49
# [Worker 3084566] Finished job Layer23Run5 at 17:37:49 (0.5 min, rc=0)
# [Worker 3084566] Starting job Layer37Run1 at 17:37:49
# Completed Layer32Run1
# Completed Layer23Run5
# [Worker 3084546] Finished job Layer21Run6 at 17:37:50 (0.5 min, rc=0)
# [Worker 3084546] Starting job Layer37Run2 at 17:37:50
# [Worker 3084578] Finished job Layer33Run1 at 17:37:50 (0.1 min, rc=0)
# [Worker 3084578] Starting job Layer37Run3 at 17:37:50
# [Worker 3084553] Finished job Layer24Run5 at 17:37:50 (0.4 min, rc=0)
# [Worker 3084553] Starting job Layer37Run4 at 17:37:50
# [Worker 3084585] Finished job Layer30Run2 at 17:37:50 (0.2 min, rc=0)
# [Worker 3084585] Starting job Layer37Run5 at 17:37:50
# Completed Layer21Run6
# Completed Layer33Run1
# Completed Layer24Run5
# Completed Layer30Run2
# [Worker 3084543] Finished job Layer22Run6 at 17:37:50 (0.5 min, rc=0)
# [Worker 3084543] Starting job Layer37Run6 at 17:37:50
# [Worker 3084584] Finished job Layer35Run0 at 17:37:50 (0.1 min, rc=0)
# [Worker 3084584] Starting job Layer38Run0 at 17:37:50
# [Worker 3084574] Finished job Layer28Run3 at 17:37:51 (0.3 min, rc=0)
# [Worker 3084574] Starting job Layer38Run1 at 17:37:51
# Completed Layer22Run6
# Completed Layer35Run0
# Completed Layer28Run3
# [Worker 3084565] Finished job Layer26Run4 at 17:37:51 (0.4 min, rc=0)
# [Worker 3084565] Starting job Layer38Run2 at 17:37:51
# Completed Layer26Run4
# [Worker 3084564] Finished job Layer36Run0 at 17:37:52 (0.1 min, rc=0)
# [Worker 3084564] Starting job Layer38Run3 at 17:37:52
# Completed Layer36Run0
# [Worker 3084562] Finished job Layer31Run2 at 17:37:52 (0.2 min, rc=0)
# [Worker 3084562] Starting job Layer38Run4 at 17:37:52
# Completed Layer31Run2
# [Worker 3084547] Finished job Layer34Run1 at 17:37:52 (0.2 min, rc=0)
# [Worker 3084547] Starting job Layer38Run5 at 17:37:52
# [Worker 3084595] Finished job Layer29Run3 at 17:37:53 (0.3 min, rc=0)
# [Worker 3084595] Starting job Layer38Run6 at 17:37:53
# Completed Layer34Run1
# Completed Layer29Run3
# [Worker 3084550] Finished job Layer23Run6 at 17:37:53 (0.5 min, rc=0)
# [Worker 3084550] Starting job Layer39Run0 at 17:37:53
# Completed Layer23Run6
# [Worker 3084589] Finished job Layer32Run2 at 17:37:54 (0.2 min, rc=0)
# [Worker 3084589] Starting job Layer39Run1 at 17:37:54
# [Worker 3084567] Finished job Layer30Run3 at 17:37:54 (0.3 min, rc=0)
# [Worker 3084567] Starting job Layer39Run2 at 17:37:54
# Completed Layer32Run2
# Completed Layer30Run3
# [Worker 3084600] Finished job Layer25Run5 at 17:37:54 (0.5 min, rc=0)
# [Worker 3084600] Starting job Layer39Run3 at 17:37:54
# [Worker 3084542] Finished job Layer37Run0 at 17:37:54 (0.1 min, rc=0)
# [Worker 3084542] Starting job Layer39Run4 at 17:37:54
# Completed Layer25Run5
# Completed Layer37Run0
# [Worker 3084537] Finished job Layer26Run5 at 17:37:54 (0.5 min, rc=0)
# [Worker 3084537] Starting job Layer39Run5 at 17:37:54
# [Worker 3084557] Finished job Layer27Run4 at 17:37:54 (0.4 min, rc=0)
# [Worker 3084557] Starting job Layer39Run6 at 17:37:54
# Completed Layer26Run5
# Completed Layer27Run4
# [Worker 3084573] Finished job Layer33Run2 at 17:37:55 (0.2 min, rc=0)
# [Worker 3084573] Starting job Layer40Run0 at 17:37:55
# Completed Layer33Run2
# [Worker 3084570] Finished job Layer35Run1 at 17:37:55 (0.2 min, rc=0)
# [Worker 3084570] Starting job Layer40Run1 at 17:37:55
# [Worker 3084539] Finished job Layer28Run4 at 17:37:55 (0.4 min, rc=0)
# [Worker 3084539] Starting job Layer40Run2 at 17:37:55
# Completed Layer35Run1
# Completed Layer28Run4
# [Worker 3084544] Finished job Layer31Run3 at 17:37:56 (0.3 min, rc=0)
# [Worker 3084544] Starting job Layer40Run3 at 17:37:56
# Completed Layer31Run3
# [Worker 3084584] Finished job Layer38Run0 at 17:37:56 (0.1 min, rc=0)
# [Worker 3084584] Starting job Layer40Run4 at 17:37:56
# Completed Layer38Run0
# [Worker 3084558] Finished job Layer36Run1 at 17:37:57 (0.2 min, rc=0)
# [Worker 3084558] Starting job Layer40Run5 at 17:37:57
# [Worker 3084561] Finished job Layer24Run6 at 17:37:57 (0.6 min, rc=0)
# [Worker 3084561] Starting job Layer40Run6 at 17:37:57
# Completed Layer36Run1
# Completed Layer24Run6
# [Worker 3084594] Finished job Layer29Run4 at 17:37:58 (0.4 min, rc=0)
# [Worker 3084594] Starting job Layer41Run0 at 17:37:58
# Completed Layer29Run4
# [Worker 3084591] Finished job Layer34Run2 at 17:37:58 (0.2 min, rc=0)
# [Worker 3084591] Starting job Layer41Run1 at 17:37:58
# Completed Layer34Run2
# [Worker 3084577] Finished job Layer32Run3 at 17:37:59 (0.3 min, rc=0)
# [Worker 3084577] Starting job Layer41Run2 at 17:37:59
# Completed Layer32Run3
# [Worker 3084550] Finished job Layer39Run0 at 17:37:59 (0.1 min, rc=0)
# [Worker 3084550] Starting job Layer41Run3 at 17:37:59
# [Worker 3084590] Finished job Layer27Run5 at 17:37:59 (0.5 min, rc=0)
# [Worker 3084590] Starting job Layer41Run4 at 17:37:59
# Completed Layer39Run0
# Completed Layer27Run5
# [Worker 3084580] Finished job Layer25Run6 at 17:37:59 (0.6 min, rc=0)
# [Worker 3084580] Starting job Layer41Run5 at 17:37:59
# Completed Layer25Run6
# [Worker 3084587] Finished job Layer35Run2 at 17:38:00 (0.2 min, rc=0)
# [Worker 3084587] Starting job Layer41Run6 at 17:38:00
# [Worker 3084574] Finished job Layer38Run1 at 17:38:00 (0.2 min, rc=0)
# [Worker 3084574] Starting job Layer42Run0 at 17:38:00
# Completed Layer35Run2
# Completed Layer38Run1
# [Worker 3084566] Finished job Layer37Run1 at 17:38:00 (0.2 min, rc=0)
# [Worker 3084566] Starting job Layer42Run1 at 17:38:00
# Completed Layer37Run1
# [Worker 3084573] Finished job Layer40Run0 at 17:38:00 (0.1 min, rc=0)
# [Worker 3084573] Starting job Layer42Run2 at 17:38:00
# [Worker 3084586] Finished job Layer33Run3 at 17:38:00 (0.3 min, rc=0)
# [Worker 3084586] Starting job Layer42Run3 at 17:38:00
# Completed Layer40Run0
# Completed Layer33Run3
# [Worker 3084583] Finished job Layer28Run5 at 17:38:01 (0.5 min, rc=0)
# [Worker 3084583] Starting job Layer42Run4 at 17:38:01
# Completed Layer28Run5
# [Worker 3084576] Finished job Layer30Run4 at 17:38:01 (0.4 min, rc=0)
# [Worker 3084576] Starting job Layer42Run5 at 17:38:01
# [Worker 3084554] Finished job Layer31Run4 at 17:38:01 (0.4 min, rc=0)
# [Worker 3084554] Starting job Layer42Run6 at 17:38:01
# Completed Layer30Run4
# Completed Layer31Run4
# [Worker 3084541] Finished job Layer26Run6 at 17:38:02 (0.6 min, rc=0)
# [Worker 3084541] Starting job Layer43Run0 at 17:38:02
# Completed Layer26Run6
# [Worker 3084579] Finished job Layer36Run2 at 17:38:02 (0.2 min, rc=0)
# [Worker 3084579] Starting job Layer43Run1 at 17:38:02
# Completed Layer36Run2
# [Worker 3084552] Finished job Layer29Run5 at 17:38:02 (0.5 min, rc=0)
# [Worker 3084552] Starting job Layer43Run2 at 17:38:02
# Completed Layer29Run5
# [Worker 3084568] Finished job Layer27Run6 at 17:38:03 (0.5 min, rc=0)
# [Worker 3084568] Starting job Layer43Run3 at 17:38:03
# Completed Layer27Run6
# [Worker 3084589] Finished job Layer39Run1 at 17:38:03 (0.2 min, rc=0)
# [Worker 3084589] Starting job Layer43Run4 at 17:38:03
# Completed Layer39Run1
# [Worker 3084551] Finished job Layer30Run5 at 17:38:03 (0.5 min, rc=0)
# [Worker 3084551] Starting job Layer43Run5 at 17:38:03
# [Worker 3084594] Finished job Layer41Run0 at 17:38:03 (0.1 min, rc=0)
# [Worker 3084594] Starting job Layer43Run6 at 17:38:03
# [Worker 3084599] Finished job Layer34Run3 at 17:38:03 (0.3 min, rc=0)
# [Worker 3084599] Starting job Layer44Run0 at 17:38:03
# [Worker 3084569] Finished job Layer32Run4 at 17:38:04 (0.4 min, rc=0)
# [Worker 3084569] Starting job Layer44Run1 at 17:38:04
# Completed Layer30Run5
# Completed Layer41Run0
# Completed Layer34Run3
# Completed Layer32Run4
# [Worker 3084546] Finished job Layer37Run2 at 17:38:04 (0.2 min, rc=0)
# [Worker 3084546] Starting job Layer44Run2 at 17:38:04
# [Worker 3084563] Finished job Layer35Run3 at 17:38:04 (0.3 min, rc=0)
# [Worker 3084563] Starting job Layer44Run3 at 17:38:04
# Completed Layer37Run2
# Completed Layer35Run3
# [Worker 3084570] Finished job Layer40Run1 at 17:38:05 (0.2 min, rc=0)
# [Worker 3084570] Starting job Layer44Run4 at 17:38:05
# [Worker 3084572] Finished job Layer28Run6 at 17:38:05 (0.5 min, rc=0)
# [Worker 3084572] Starting job Layer44Run5 at 17:38:05
# [Worker 3084574] Finished job Layer42Run0 at 17:38:05 (0.1 min, rc=0)
# [Worker 3084574] Starting job Layer44Run6 at 17:38:05
# Completed Layer40Run1
# Completed Layer28Run6
# Completed Layer42Run0
# [Worker 3084571] Finished job Layer33Run4 at 17:38:06 (0.4 min, rc=0)
# [Worker 3084571] Starting job Layer45Run0 at 17:38:06
# Completed Layer33Run4
# [Worker 3084565] Finished job Layer38Run2 at 17:38:06 (0.2 min, rc=0)
# [Worker 3084565] Starting job Layer45Run1 at 17:38:06
# Completed Layer38Run2
# [Worker 3084541] Finished job Layer43Run0 at 17:38:07 (0.1 min, rc=0)
# [Worker 3084541] Starting job Layer45Run2 at 17:38:07
# [Worker 3084560] Finished job Layer31Run5 at 17:38:07 (0.5 min, rc=0)
# [Worker 3084560] Starting job Layer45Run3 at 17:38:07
# Completed Layer43Run0
# Completed Layer31Run5
# [Worker 3084597] Finished job Layer29Run6 at 17:38:07 (0.5 min, rc=0)
# [Worker 3084597] Starting job Layer45Run4 at 17:38:07
# Completed Layer29Run6
# [Worker 3084540] Finished job Layer36Run3 at 17:38:08 (0.3 min, rc=0)
# [Worker 3084540] Starting job Layer45Run5 at 17:38:08
# [Worker 3084575] Finished job Layer34Run4 at 17:38:08 (0.4 min, rc=0)
# [Worker 3084575] Starting job Layer45Run6 at 17:38:08
# Completed Layer36Run3
# Completed Layer34Run4
# [Worker 3084591] Finished job Layer41Run1 at 17:38:08 (0.2 min, rc=0)
# [Worker 3084591] Starting job Layer46Run0 at 17:38:08
# Completed Layer41Run1
# [Worker 3084545] Finished job Layer30Run6 at 17:38:09 (0.5 min, rc=0)
# [Worker 3084545] Starting job Layer46Run1 at 17:38:09
# [Worker 3084578] Finished job Layer37Run3 at 17:38:09 (0.3 min, rc=0)
# [Worker 3084578] Starting job Layer46Run2 at 17:38:09
# [Worker 3084567] Finished job Layer39Run2 at 17:38:09 (0.3 min, rc=0)
# [Worker 3084567] Starting job Layer46Run3 at 17:38:09
# Completed Layer30Run6
# Completed Layer37Run3
# Completed Layer39Run2
# [Worker 3084599] Finished job Layer44Run0 at 17:38:09 (0.1 min, rc=0)
# [Worker 3084599] Starting job Layer46Run4 at 17:38:09
# Completed Layer44Run0
# [Worker 3084593] Finished job Layer32Run5 at 17:38:10 (0.5 min, rc=0)
# [Worker 3084593] Starting job Layer46Run5 at 17:38:10
# Completed Layer32Run5
# [Worker 3084539] Finished job Layer40Run2 at 17:38:10 (0.2 min, rc=0)
# [Worker 3084539] Starting job Layer46Run6 at 17:38:10
# [Worker 3084548] Finished job Layer33Run5 at 17:38:10 (0.5 min, rc=0)
# [Worker 3084548] Starting job Layer47Run0 at 17:38:10
# [Worker 3084566] Finished job Layer42Run1 at 17:38:10 (0.2 min, rc=0)
# [Worker 3084566] Starting job Layer47Run1 at 17:38:10
# Completed Layer40Run2
# Completed Layer33Run5
# Completed Layer42Run1
# [Worker 3084564] Finished job Layer38Run3 at 17:38:11 (0.3 min, rc=0)
# [Worker 3084564] Starting job Layer47Run2 at 17:38:11
# Completed Layer38Run3
# [Worker 3084579] Finished job Layer43Run1 at 17:38:11 (0.2 min, rc=0)
# [Worker 3084579] Starting job Layer47Run3 at 17:38:11
# [Worker 3084549] Finished job Layer36Run4 at 17:38:11 (0.4 min, rc=0)
# [Worker 3084549] Starting job Layer47Run4 at 17:38:11
# Completed Layer43Run1
# Completed Layer36Run4
# [Worker 3084571] Finished job Layer45Run0 at 17:38:12 (0.1 min, rc=0)
# [Worker 3084571] Starting job Layer47Run5 at 17:38:12
# Completed Layer45Run0
# [Worker 3084581] Finished job Layer31Run6 at 17:38:12 (0.5 min, rc=0)
# [Worker 3084581] Starting job Layer47Run6 at 17:38:12
# [Worker 3084582] Finished job Layer35Run4 at 17:38:12 (0.4 min, rc=0)
# [Worker 3084582] Starting job Layer48Run0 at 17:38:12
# Completed Layer31Run6
# Completed Layer35Run4
# [Worker 3084577] Finished job Layer41Run2 at 17:38:12 (0.2 min, rc=0)
# [Worker 3084577] Starting job Layer48Run1 at 17:38:12
# Completed Layer41Run2
# [Worker 3084600] Finished job Layer39Run3 at 17:38:13 (0.3 min, rc=0)
# [Worker 3084600] Starting job Layer48Run2 at 17:38:13
# [Worker 3084569] Finished job Layer44Run1 at 17:38:13 (0.2 min, rc=0)
# [Worker 3084569] Starting job Layer48Run3 at 17:38:13
# Completed Layer39Run3
# Completed Layer44Run1
# [Worker 3084553] Finished job Layer37Run4 at 17:38:13 (0.4 min, rc=0)
# [Worker 3084553] Starting job Layer48Run4 at 17:38:13
# Completed Layer37Run4
# [Worker 3084598] Finished job Layer32Run6 at 17:38:13 (0.5 min, rc=0)
# [Worker 3084598] Starting job Layer48Run5 at 17:38:13
# Completed Layer32Run6
# [Worker 3084591] Finished job Layer46Run0 at 17:38:14 (0.1 min, rc=0)
# [Worker 3084591] Starting job Layer48Run6 at 17:38:14
# Completed Layer46Run0
# [Worker 3084559] Finished job Layer34Run5 at 17:38:14 (0.5 min, rc=0)
# [Worker 3084559] Starting job Layer49Run0 at 17:38:14
# Completed Layer34Run5
# [Worker 3084573] Finished job Layer42Run2 at 17:38:15 (0.2 min, rc=0)
# [Worker 3084573] Starting job Layer49Run1 at 17:38:15
# [Worker 3084596] Finished job Layer35Run5 at 17:38:15 (0.5 min, rc=0)
# [Worker 3084596] Starting job Layer49Run2 at 17:38:15
# [Worker 3084544] Finished job Layer40Run3 at 17:38:15 (0.3 min, rc=0)
# [Worker 3084544] Starting job Layer49Run3 at 17:38:15
# Completed Layer42Run2
# Completed Layer35Run5
# Completed Layer40Run3
# [Worker 3084548] Finished job Layer47Run0 at 17:38:15 (0.1 min, rc=0)
# [Worker 3084548] Starting job Layer49Run4 at 17:38:15
# Completed Layer47Run0
# [Worker 3084555] Finished job Layer33Run6 at 17:38:16 (0.6 min, rc=0)
# [Worker 3084555] Starting job Layer49Run5 at 17:38:16
# [Worker 3084565] Finished job Layer45Run1 at 17:38:16 (0.2 min, rc=0)
# [Worker 3084565] Starting job Layer49Run6 at 17:38:16
# [Worker 3084552] Finished job Layer43Run2 at 17:38:16 (0.2 min, rc=0)
# [Worker 3084552] Starting job Layer50Run0 at 17:38:16
# [Worker 3084562] Finished job Layer38Run4 at 17:38:16 (0.4 min, rc=0)
# [Worker 3084562] Starting job Layer50Run1 at 17:38:16
# Completed Layer33Run6
# Completed Layer45Run1
# Completed Layer43Run2
# Completed Layer38Run4
# [Worker 3084556] Finished job Layer36Run5 at 17:38:17 (0.5 min, rc=0)
# [Worker 3084556] Starting job Layer50Run2 at 17:38:17
# Completed Layer36Run5
# [Worker 3084538] Finished job Layer34Run6 at 17:38:17 (0.5 min, rc=0)
# [Worker 3084538] Starting job Layer50Run3 at 17:38:17
# Completed Layer34Run6
# [Worker 3084582] Finished job Layer48Run0 at 17:38:18 (0.1 min, rc=0)
# [Worker 3084582] Starting job Layer50Run4 at 17:38:18
# Completed Layer48Run0
# [Worker 3084542] Finished job Layer39Run4 at 17:38:18 (0.4 min, rc=0)
# [Worker 3084542] Starting job Layer50Run5 at 17:38:18
# [Worker 3084546] Finished job Layer44Run2 at 17:38:18 (0.2 min, rc=0)
# [Worker 3084546] Starting job Layer50Run6 at 17:38:18
# [Worker 3084545] Finished job Layer46Run1 at 17:38:18 (0.2 min, rc=0)
# [Worker 3084545] Starting job Layer51Run0 at 17:38:18
# Completed Layer39Run4
# Completed Layer44Run2
# Completed Layer46Run1
# [Worker 3084550] Finished job Layer41Run3 at 17:38:18 (0.3 min, rc=0)
# [Worker 3084550] Starting job Layer51Run1 at 17:38:18
# Completed Layer41Run3
# [Worker 3084584] Finished job Layer40Run4 at 17:38:18 (0.4 min, rc=0)
# [Worker 3084584] Starting job Layer51Run2 at 17:38:18
# Completed Layer40Run4
# [Worker 3084586] Finished job Layer42Run3 at 17:38:19 (0.3 min, rc=0)
# [Worker 3084586] Starting job Layer51Run3 at 17:38:19
# Completed Layer42Run3
# [Worker 3084566] Finished job Layer47Run1 at 17:38:19 (0.1 min, rc=0)
# [Worker 3084566] Starting job Layer51Run4 at 17:38:19
# Completed Layer47Run1
# [Worker 3084559] Finished job Layer49Run0 at 17:38:19 (0.1 min, rc=0)
# [Worker 3084559] Starting job Layer51Run5 at 17:38:19
# [Worker 3084585] Finished job Layer37Run5 at 17:38:20 (0.5 min, rc=0)
# [Worker 3084585] Starting job Layer51Run6 at 17:38:20
# Completed Layer49Run0
# Completed Layer37Run5
# [Worker 3084588] Finished job Layer35Run6 at 17:38:20 (0.6 min, rc=0)
# [Worker 3084588] Starting job Layer52Run0 at 17:38:20
# [Worker 3084547] Finished job Layer38Run5 at 17:38:20 (0.5 min, rc=0)
# [Worker 3084547] Starting job Layer52Run1 at 17:38:20
# Completed Layer35Run6
# Completed Layer38Run5
# [Worker 3084568] Finished job Layer43Run3 at 17:38:21 (0.3 min, rc=0)
# [Worker 3084568] Starting job Layer52Run2 at 17:38:21
# Completed Layer43Run3
# ...
# [Worker 3084593] Finished job Layer116Run4 at 17:40:53 (0.4 min, rc=0)
# Completed Layer125Run0
# Completed Layer116Run4
# [Worker 3084548] Finished job Layer112Run6 at 17:40:54 (0.5 min, rc=0)
# Completed Layer112Run6
# [Worker 3084551] Finished job Layer121Run2 at 17:40:54 (0.2 min, rc=0)
# Completed Layer121Run2
# [Worker 3084579] Finished job Layer119Run3 at 17:40:54 (0.3 min, rc=0)
# [Worker 3084595] Finished job Layer114Run5 at 17:40:54 (0.5 min, rc=0)
# Completed Layer119Run3
# Completed Layer114Run5
# [Worker 3084567] Finished job Layer126Run0 at 17:40:55 (0.1 min, rc=0)
# Completed Layer126Run0
# [Worker 3084542] Finished job Layer117Run4 at 17:40:55 (0.4 min, rc=0)
# Completed Layer117Run4
# [Worker 3084589] Finished job Layer124Run1 at 17:40:55 (0.2 min, rc=0)
# [Worker 3084544] Finished job Layer115Run5 at 17:40:55 (0.4 min, rc=0)
# Completed Layer124Run1
# Completed Layer115Run5
# [Worker 3084550] Finished job Layer122Run2 at 17:40:55 (0.2 min, rc=0)
# Completed Layer122Run2
# [Worker 3084564] Finished job Layer120Run3 at 17:40:56 (0.3 min, rc=0)
# Completed Layer120Run3
# [Worker 3084594] Finished job Layer125Run1 at 17:40:56 (0.1 min, rc=0)
# [Worker 3084599] Finished job Layer113Run6 at 17:40:57 (0.5 min, rc=0)
# Completed Layer125Run1
# Completed Layer113Run6
# [Worker 3084598] Finished job Layer116Run5 at 17:40:57 (0.4 min, rc=0)
# Completed Layer116Run5
# [Worker 3084560] Finished job Layer123Run2 at 17:40:57 (0.2 min, rc=0)
# [Worker 3084572] Finished job Layer118Run4 at 17:40:57 (0.4 min, rc=0)
# Completed Layer123Run2
# Completed Layer118Run4
# [Worker 3084537] Finished job Layer119Run4 at 17:40:58 (0.4 min, rc=0)
# [Worker 3084580] Finished job Layer121Run3 at 17:40:59 (0.3 min, rc=0)
# Completed Layer119Run4
# Completed Layer121Run3
# [Worker 3084554] Finished job Layer114Run6 at 17:40:59 (0.5 min, rc=0)
# [Worker 3084570] Finished job Layer117Run5 at 17:40:59 (0.4 min, rc=0)
# Completed Layer114Run6
# Completed Layer117Run5
# [Worker 3084547] Finished job Layer126Run1 at 17:40:59 (0.2 min, rc=0)
# Completed Layer126Run1
# [Worker 3084582] Finished job Layer115Run6 at 17:40:59 (0.5 min, rc=0)
# [Worker 3084558] Finished job Layer120Run4 at 17:40:59 (0.4 min, rc=0)
# Completed Layer115Run6
# Completed Layer120Run4
# [Worker 3084556] Finished job Layer124Run2 at 17:41:00 (0.2 min, rc=0)
# Completed Layer124Run2
# [Worker 3084581] Finished job Layer118Run5 at 17:41:01 (0.4 min, rc=0)
# Completed Layer118Run5
# [Worker 3084555] Finished job Layer116Run6 at 17:41:01 (0.5 min, rc=0)
# [Worker 3084584] Finished job Layer125Run2 at 17:41:01 (0.2 min, rc=0)
# Completed Layer116Run6
# Completed Layer125Run2
# [Worker 3084574] Finished job Layer122Run3 at 17:41:02 (0.3 min, rc=0)
# Completed Layer122Run3
# [Worker 3084597] Finished job Layer126Run2 at 17:41:02 (0.2 min, rc=0)
# [Worker 3084586] Finished job Layer123Run3 at 17:41:02 (0.3 min, rc=0)
# Completed Layer126Run2
# Completed Layer123Run3
# [Worker 3084569] Finished job Layer124Run3 at 17:41:03 (0.3 min, rc=0)
# Completed Layer124Run3
# [Worker 3084576] Finished job Layer121Run4 at 17:41:03 (0.4 min, rc=0)
# Completed Layer121Run4
# [Worker 3084600] Finished job Layer122Run4 at 17:41:04 (0.3 min, rc=0)
# Completed Layer122Run4
# [Worker 3084545] Finished job Layer119Run5 at 17:41:05 (0.5 min, rc=0)
# [Worker 3084540] Finished job Layer118Run6 at 17:41:05 (0.5 min, rc=0)
# [Worker 3084590] Finished job Layer120Run5 at 17:41:05 (0.4 min, rc=0)
# Completed Layer119Run5
# Completed Layer118Run6
# Completed Layer120Run5
# [Worker 3084578] Finished job Layer123Run4 at 17:41:05 (0.3 min, rc=0)
# Completed Layer123Run4
# [Worker 3084583] Finished job Layer117Run6 at 17:41:05 (0.5 min, rc=0)
# Completed Layer117Run6
# [Worker 3084561] Finished job Layer121Run5 at 17:41:06 (0.4 min, rc=0)
# Completed Layer121Run5
# [Worker 3084562] Finished job Layer125Run3 at 17:41:06 (0.3 min, rc=0)
# [Worker 3084575] Finished job Layer119Run6 at 17:41:06 (0.5 min, rc=0)
# Completed Layer125Run3
# Completed Layer119Run6
# [Worker 3084557] Finished job Layer126Run3 at 17:41:07 (0.3 min, rc=0)
# Completed Layer126Run3
# [Worker 3084549] Finished job Layer120Run6 at 17:41:08 (0.5 min, rc=0)
# [Worker 3084546] Finished job Layer124Run4 at 17:41:08 (0.3 min, rc=0)
# [Worker 3084585] Finished job Layer122Run5 at 17:41:08 (0.4 min, rc=0)
# Completed Layer120Run6
# Completed Layer124Run4
# Completed Layer122Run5
# [Worker 3084591] Finished job Layer125Run4 at 17:41:08 (0.3 min, rc=0)
# Completed Layer125Run4
# [Worker 3084566] Finished job Layer123Run5 at 17:41:09 (0.4 min, rc=0)
# [Worker 3084543] Finished job Layer121Run6 at 17:41:09 (0.5 min, rc=0)
# Completed Layer123Run5
# Completed Layer121Run6
# [Worker 3084571] Finished job Layer126Run4 at 17:41:11 (0.3 min, rc=0)
# [Worker 3084553] Finished job Layer122Run6 at 17:41:11 (0.5 min, rc=0)
# Completed Layer126Run4
# Completed Layer122Run6
# [Worker 3084573] Finished job Layer125Run5 at 17:41:12 (0.4 min, rc=0)
# Completed Layer125Run5
# [Worker 3084568] Finished job Layer123Run6 at 17:41:13 (0.5 min, rc=0)
# Completed Layer123Run6
# [Worker 3084596] Finished job Layer124Run5 at 17:41:14 (0.4 min, rc=0)
# Completed Layer124Run5
# [Worker 3084565] Finished job Layer126Run5 at 17:41:15 (0.4 min, rc=0)
# Completed Layer126Run5
# [Worker 3084552] Finished job Layer124Run6 at 17:41:15 (0.5 min, rc=0)
# Completed Layer124Run6
# [Worker 3084538] Finished job Layer125Run6 at 17:41:17 (0.5 min, rc=0)
# Completed Layer125Run6
# [Worker 3084541] Finished job Layer126Run6 at 17:41:18 (0.4 min, rc=0)
# Completed Layer126Run6
# All QSEIS runs finished.
# Database generation complete
# CubeTop = 130.0CubeBot = 370.0
# itmAC = 0.0, 0.0, 250.0
# [0.    0.025 0.05  0.075 0.1  ]
# [assembleQseisRuns] saved | z=0.000 m |
# [assembleQseisRuns] saved | z=39.852 m |
# [assembleQseisRuns] saved | z=79.703 m |
# [assembleQseisRuns] saved | z=119.555 m |
# [assembleQseisRuns] saved | z=159.406 m |
# [assembleQseisRuns] saved | z=199.258 m |
# [assembleQseisRuns] saved | z=239.109 m |
# [assembleQseisRuns] saved | z=278.961 m |
# [assembleQseisRuns] saved | z=318.812 m |
# [assembleQseisRuns] saved | z=358.664 m |
# [assembleQseisRuns] saved | z=398.515 m |
# [assembleQseisRuns] saved | z=438.367 m |
# [assembleQseisRuns] saved | z=478.218 m |
# [assembleQseisRuns] saved | z=518.070 m |
# [assembleQseisRuns] saved | z=557.921 m |
# [assembleQseisRuns] saved | z=597.773 m |
# [assembleQseisRuns] saved | z=637.625 m |
# [assembleQseisRuns] saved | z=677.476 m |
# [assembleQseisRuns] saved | z=717.328 m |
# [assembleQseisRuns] saved | z=757.179 m |
# [assembleQseisRuns] saved | z=797.031 m |
# [assembleQseisRuns] saved | z=836.882 m |
# [assembleQseisRuns] saved | z=876.734 m |
# [assembleQseisRuns] saved | z=916.585 m |
# [assembleQseisRuns] saved | z=956.437 m |
# [assembleQseisRuns] saved | z=996.288 m |
# [assembleQseisRuns] saved | z=1036.140 m |
# [assembleQseisRuns] saved | z=1075.991 m |
# [assembleQseisRuns] saved | z=1115.843 m |
# [assembleQseisRuns] saved | z=1155.695 m |
# [assembleQseisRuns] saved | z=1195.546 m |
# [assembleQseisRuns] saved | z=1235.398 m |
# [assembleQseisRuns] saved | z=1275.249 m |
# [assembleQseisRuns] saved | z=1315.101 m |
# [assembleQseisRuns] saved | z=1354.952 m |
# [assembleQseisRuns] saved | z=1394.804 m |
# [assembleQseisRuns] saved | z=1434.655 m |
# [assembleQseisRuns] saved | z=1474.507 m |
# [assembleQseisRuns] saved | z=1514.358 m |
# [assembleQseisRuns] saved | z=1554.210 m |
# [assembleQseisRuns] saved | z=1594.061 m |
# [assembleQseisRuns] saved | z=1633.913 m |
# [assembleQseisRuns] saved | z=1673.764 m |
# [assembleQseisRuns] saved | z=1713.616 m |
# [assembleQseisRuns] saved | z=1753.468 m |
# [assembleQseisRuns] saved | z=1793.319 m |
# [assembleQseisRuns] saved | z=1833.171 m |
# [assembleQseisRuns] saved | z=1873.022 m |
# [assembleQseisRuns] saved | z=1912.874 m |
# [assembleQseisRuns] saved | z=1952.725 m |
# [assembleQseisRuns] saved | z=1992.577 m |
# [assembleQseisRuns] saved | z=2032.428 m |
# [assembleQseisRuns] saved | z=2072.280 m |
# [assembleQseisRuns] saved | z=2112.131 m |
# [assembleQseisRuns] saved | z=2151.983 m |
# [assembleQseisRuns] saved | z=2191.834 m |
# [assembleQseisRuns] saved | z=2231.686 m |
# [assembleQseisRuns] saved | z=2271.538 m |
# [assembleQseisRuns] saved | z=2311.389 m |
# [assembleQseisRuns] saved | z=2351.241 m |
# [assembleQseisRuns] saved | z=2391.092 m |
# [assembleQseisRuns] saved | z=2430.944 m |
# [assembleQseisRuns] saved | z=2470.795 m |
# [assembleQseisRuns] saved | z=2510.647 m |
# [assembleQseisRuns] saved | z=2550.498 m |
# [assembleQseisRuns] saved | z=2590.350 m |
# [assembleQseisRuns] saved | z=2630.201 m |
# [assembleQseisRuns] saved | z=2670.053 m |
# [assembleQseisRuns] saved | z=2709.904 m |
# [assembleQseisRuns] saved | z=2749.756 m |
# [assembleQseisRuns] saved | z=2789.607 m |
# [assembleQseisRuns] saved | z=2829.459 m |
# [assembleQseisRuns] saved | z=2869.311 m |
# [assembleQseisRuns] saved | z=2909.162 m |
# [assembleQseisRuns] saved | z=2949.014 m |
# [assembleQseisRuns] saved | z=2988.865 m |
# [assembleQseisRuns] saved | z=3028.717 m |
# [assembleQseisRuns] saved | z=3068.568 m |
# [assembleQseisRuns] saved | z=3108.420 m |
# [assembleQseisRuns] saved | z=3148.271 m |
# [assembleQseisRuns] saved | z=3188.123 m |
# [assembleQseisRuns] saved | z=3227.974 m |
# [assembleQseisRuns] saved | z=3267.826 m |
# [assembleQseisRuns] saved | z=3307.677 m |
# [assembleQseisRuns] saved | z=3347.529 m |
# [assembleQseisRuns] saved | z=3387.381 m |
# [assembleQseisRuns] saved | z=3427.232 m |
# [assembleQseisRuns] saved | z=3467.084 m |
# [assembleQseisRuns] saved | z=3506.935 m |
# [assembleQseisRuns] saved | z=3546.787 m |
# [assembleQseisRuns] saved | z=3586.638 m |
# [assembleQseisRuns] saved | z=3626.490 m |
# [assembleQseisRuns] saved | z=3666.341 m |
# [assembleQseisRuns] saved | z=3706.193 m |
# [assembleQseisRuns] saved | z=3746.044 m |
# [assembleQseisRuns] saved | z=3785.896 m |
# [assembleQseisRuns] saved | z=3825.747 m |
# [assembleQseisRuns] saved | z=3865.599 m |
# [assembleQseisRuns] saved | z=3905.450 m |
# [assembleQseisRuns] saved | z=3945.302 m |
# [assembleQseisRuns] saved | z=3985.154 m |
# [assembleQseisRuns] saved | z=4025.005 m |
# [assembleQseisRuns] saved | z=4064.857 m |
# [assembleQseisRuns] saved | z=4104.708 m |
# [assembleQseisRuns] saved | z=4144.560 m |
# [assembleQseisRuns] saved | z=4184.411 m |
# [assembleQseisRuns] saved | z=4224.263 m |
# [assembleQseisRuns] saved | z=4264.114 m |
# [assembleQseisRuns] saved | z=4303.966 m |
# [assembleQseisRuns] saved | z=4343.817 m |
# [assembleQseisRuns] saved | z=4383.669 m |
# [assembleQseisRuns] saved | z=4423.520 m |
# [assembleQseisRuns] saved | z=4463.372 m |
# [assembleQseisRuns] saved | z=4503.224 m |
# [assembleQseisRuns] saved | z=4543.075 m |
# [assembleQseisRuns] saved | z=4582.927 m |
# [assembleQseisRuns] saved | z=4622.778 m |
# [assembleQseisRuns] saved | z=4662.630 m |
# [assembleQseisRuns] saved | z=4702.481 m |
# [assembleQseisRuns] saved | z=4742.333 m |
# [assembleQseisRuns] saved | z=4782.184 m |
# [assembleQseisRuns] saved | z=4822.036 m |
# [assembleQseisRuns] saved | z=4861.887 m |
# [assembleQseisRuns] saved | z=4901.739 m |
# [assembleQseisRuns] saved | z=4941.590 m |
# [assembleQseisRuns] saved | z=4981.442 m |
# [assembleQseisRuns] saved | z=5000.000 m |
# grid size in each layer before partitioning = [39.85153559 42.19409283]
# Layer depths given by user before partitioning = [   0. 4000.] m
# New layer depths after partitioning for computationional speed = [   0.   50.  450. 4000.] m
# New gridSize after partioning = [39.85153559 39.85153559 39.85153559]
# Total number of layers = 3
# Doing realization = 0
# Starting parallel processing with 1 workers...
# [Worker 0] Assigned receiver indices: 0–99 (total 100)
# [Worker 0] Finished in 0.06 s
# All workers finished in 0.06 s
# Starting parallel processing with 1 workers...
# [Worker 0] Assigned receiver indices: 0–99 (total 100)
# [Worker 0] Finished in 0.06 s
# All workers finished in 0.06 s
# <Layer z: 0.0-50.0, type: no_intersection, nblocks: 1>
# <Block x:[-3000.0,3000.0], y:[-3000.0,3000.0], z:[0.0,50.0] spaceT:[lgwt] intpType:[1] >
# Block = 1
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# Actually computing NN for the horizontal surface
# <Layer z: 50.0-450.0, type: contains, nblocks: 11>
# <Block x:[-3000.0,-120.0], y:[-3000.0,-120.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 1
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-3000.0,-120.0], y:[-120.0,120.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 2
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-3000.0,-120.0], y:[120.0,3000.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 3
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-120.0,120.0], y:[-3000.0,-120.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 4
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-120.0,120.0], y:[-120.0,120.0], z:[50.0,130.0] spaceT:[lgwt] intpType:[2] >
# Block = 5
# Integrating volume  NN block in layer1
# Integrating horizontal surface NN block in layer1
# <Block x:[-120.0,120.0], y:[-120.0,120.0], z:[130.0,370.0] spaceT:[uniform] intpType:[1] >
# Block = 6
# Integrating volume  NN block in layer1
# Uniform spacing
# Total points = 10128
# Integrating horizontal surface NN block in layer1
# <Block x:[-120.0,120.0], y:[-120.0,120.0], z:[370.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 7
# Integrating volume  NN block in layer1
# Integrating horizontal surface NN block in layer1
# <Block x:[-120.0,120.0], y:[120.0,3000.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 8
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[120.0,3000.0], y:[-3000.0,-120.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 9
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[120.0,3000.0], y:[-120.0,120.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 10
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[120.0,3000.0], y:[120.0,3000.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 11
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Layer z: 450.0-4000.0, type: no_intersection, nblocks: 1>
# <Block x:[-3000.0,3000.0], y:[-3000.0,3000.0], z:[450.0,4000.0] spaceT:[lgwt] intpType:[1] >
# Block = 1
# Integrating volume  NN block in layer2
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating horizontal surface NN block in layer2
# Horizontal face found
# Actually computing NN for the horizontal surface

# %%
from modules import bodyPSNN
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy.constants as const

out_path = "/home/koley/CavityResults/CuboidGeomTest/OutDispRea/"
data = np.load(os.path.join(out_path, "NNFullRea0.npz"))

Iblock = data["IBlockTot"]
Ivert  = data["IVertFaceTot"]
Ihor   = data["IHorFaceTot"]
Itot   = data["ITot"]
freqOut = data["freqOut"]

G = const.G
rho = 2465.0
vS = 2000.0
vP = 4000.0
"""
L = 4000.0
a = 50.0
b = 20.0
c = 20.0
xi0 = 1.0
outer_bounds = (-L, L, -L, L, -L, L)
cavity_bounds = (-a, a, -b, b, L - (250-c), L - (250+c))
tm = np.array([0.0, 0.0, 0.0])
"""
L = 4000.0
# cavity half-lengths
a = 10.0
b = 10.0
c = 10.0
sphere_radius = 20
xi0 = 1.0
# depth of cavity center below the surface
cav_depth = 250.0
# cavity center in global coordinates
cav_center = np.array([0.0, 0.0, L - cav_depth])
outer_bounds = (-L, L,
                -L, L,
                -L, L)
cavity_bounds = (
    cav_center[0] - a, cav_center[0] + a,
    cav_center[1] - b, cav_center[1] + b,
    cav_center[2] - c, cav_center[2] + c,
)
# test mass at cavity center
tm = cav_center.copy()
tm_shift = np.array([0.0, 0.0, 0.0])   # example: no shift

# Example: 10 m deeper than cavity center
# Since z increases upward in this coordinate convention, deeper means negative z shift.
# tm_shift = np.array([0.0, 0.0, -10.0])

tm = cav_center + tm_shift

"""
pieces = [
    bodyPSNN.SH_y_x_sphere_all_components_shifted(
        f,
        vS,
        outer_bounds=outer_bounds,
        sphere_center=cav_center,
        sphere_radius=sphere_radius,
        tm=tm,
        n_mu=64,
        n_phi=128,
        n_r=64,
    )
    for f in freqOut
]
"""

"""
pieces = [
    bodyPSNN.SH_x_y_sphere_all_components_shifted(
        f,
        vS,
        outer_bounds=outer_bounds,
        sphere_center=cav_center,
        sphere_radius=sphere_radius,
        tm=tm,
        n_mu=64,
        n_phi=128,
        n_r=64,
    )
    for f in freqOut
]
"""
"""
pieces = [
    bodyPSNN.SV_x_z_sphere_all_components_shifted(
        f,
        vS,
        outer_bounds=outer_bounds,
        sphere_center=cav_center,
        sphere_radius=sphere_radius,
        tm=tm,
        n_mu=64,
        n_phi=128,
        n_r=64,
    )
    for f in freqOut
]

"""

pieces = [
    bodyPSNN.P_x_sphere_all_components_shifted(
        f,
        vP,
        outer_bounds=outer_bounds,
        sphere_center=cav_center,
        sphere_radius=sphere_radius,
        tm=tm,
        n_mu=64,
        n_phi=128,
        n_r=64,
    )
    for f in freqOut
]
"""
pieces = [
    bodyPSNN.P_z_sphere_all_components_shifted(
        f,
        vP,
        outer_bounds=outer_bounds,
        sphere_center=cav_center,
        sphere_radius=sphere_radius,
        tm=tm,
        n_mu=64,
        n_phi=128,
        n_r=64,
    )
    for f in freqOut
]
"""
H_bulk  = np.array([p[0] for p in pieces])   # shape (nFreq, 3)
H_vert  = np.array([p[1] for p in pieces])
H_hor   = np.array([p[2] for p in pieces])
H_total = np.array([p[3] for p in pieces])

A_bulk  = G*rho*xi0*H_bulk
A_vert  = G*rho*xi0*H_vert
A_hor = G*rho*xi0*H_hor
A_total = G*rho*xi0*H_total

plt.figure(figsize=(8,6))

plt.semilogy(freqOut, np.abs(Iblock[:,0,0]), label="code bulk x")
plt.semilogy(freqOut, np.abs(Ivert[:,0,0]),  label="code vertical surf x")
plt.semilogy(freqOut, np.abs(Ihor[:,0,0]),   label="code horizontal surf x")
plt.semilogy(freqOut, np.abs(Itot[:,0,0]),   label="code total x")

plt.semilogy(freqOut, np.abs(A_bulk[:,0]),  "--", label="analytic bulk x")
plt.semilogy(freqOut, np.abs(A_vert[:,0]),  "--", label="analytic vertical surf x")
plt.semilogy(freqOut, np.abs(A_hor[:,0]), "--", label = "analytical hor surf x")
plt.semilogy(freqOut, np.abs(A_total[:,0]), "--", label="analytic total x")

plt.xlabel("Frequency (Hz)")
plt.ylabel("NN acceleration")
plt.grid(True, which="both")
plt.legend()
#plt.ylim(5*10**-7, 10**-6)
plt.title('Semi analytical with current sphere integrals')
plt.tight_layout()

plt.show()

Tx = 8*np.arctan((b*c)/(a*np.sqrt(a*a+b*b+c*c)))
print("Tx cavity =", Tx)
print("G*rho*Tx =", G*rho*Tx)
print("First code total / (G*rho) =", np.abs(Itot[0,0])/(G*rho))
print("First analytic total / (G*rho) =", np.abs(H_total[0]))
# Out:
# Tx cavity = 4.1887902047863905
# G*rho*Tx = 6.891460267328131e-07
# First code total / (G*rho) = [2.63297968 2.63398938 2.63398938 2.63508517]
# First analytic total / (G*rho) = [2.63326918e+00 3.88125416e-17 2.67315967e+00]
