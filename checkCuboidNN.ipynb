# %%
# script for computing NN for a homogeneous half-space or full space
# for different cuboidal cavity orientations
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
from scipy.integrate import quad, tplquad, dblquad
import scipy.constants as const

from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from modules import createDB
from modules import NNGeometryNN
from modules import gfLoader
from modules import simDisp
from modules import NNCompute

def main():

    # load the config file
    configFile="/home/koley/CavityResults/CuboidTutorialConfig/configParseHalfSpaceBodyHomo.ini"
    config = configLoader.load_config(configFile)
    wType = 'SHy' # can be Px, Pz, SV, SHx, SHy
    # load all cavities
    allCavities = configLoader.loadCavities('/home/koley/CavityResults/CuboidTutorialConfig/SingleCavityHalfSpace.ini')
    validateInputs.validateInputs(config)
    
    splitAll = createDB.createFinalInputs(config)

    print(f"Prepared {splitAll.shape[0]} total runs")
    print(f"Cores available: {config.cpuCoresQseis}")

    results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    
    print("Database generation complete")
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay
    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody
    # flag for wavefield simulation
    ifFullField = config.ifFullField
    saveHV = config.saveHV
    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    rhoAir = config.rhoAir # density of air
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    lambdaFrac = config.lambdaFrac # fraction
    lambdaRes = config.lambdaRes; #must be greater than 4
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used
    maxRec = config.maxRec # same value of number of receivers that qseis can handle in one go check qsglobal.h
    xCenter = config.xCenter; yCenter = config.yCenter
    xMin = xCenter-config.xExtent; xMax = xCenter+config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = yCenter-config.yExtent; yMax = yCenter+config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")
        
    domXYBounds = (xMin,xMax,yMin,yMax)
    
    refineBoxes = NNGeometryNN.makeRefineBoxesFromCavities(allCavities)
    cubeTopAll = np.zeros((len(allCavities),))
    cubeBotAll = np.zeros((len(allCavities),))
    for boxNo, box in enumerate(refineBoxes):
        cubeTopAll[boxNo] = box.zMin
        cubeBotAll[boxNo] = box.zMax
    cubeTop = min(cubeTopAll)
    cubeBot = max(cubeBotAll)
    # new part added
    
    cavDepthAll = np.zeros((len(allCavities),))
    for cavNo, cav in enumerate(allCavities):    
        if(cav["shape"]=="cuboid"):
            cavDepthAll[cavNo] = cav["zC"]
        elif(cav["shape"] == 'sphere'):
            cavDepthAll[cavNo] = cav["zC"]
        else:
            ValueError('Unsupported cavity type')
    cavDepthUse = min(cavDepthAll)

    print("CubeTop = " + str(cubeTop) +  'CubeBot = ' + str(cubeBot))
    
    itmAC = config.itmAC; itmAB = config.itmAB; etmCA = config.etmCA; etmBA = config.etmBA

    print('itmAC = ' + str(itmAC[0]) + ', ' + str(itmAC[1]) + ', ' + str(itmAC[2]))
    # make itmAC[2] negative, because in the configfile it is positive
    itmACUse = itmAC.copy(); itmACUse[2] = -np.abs(itmACUse[2])
    itmABUse = itmAB.copy(); itmABUse[2] = -np.abs(itmABUse[2])
    etmCAUse = etmCA.copy(); etmCAUse[2] = -np.abs(etmCAUse[2])
    etmBAUse = etmBA.copy(); etmBAUse[2] = -np.abs(etmBAUse[2])

    itmAll = np.vstack((itmACUse,itmABUse, etmCAUse,etmBAUse))
    nTM = len(itmAll[:,0])
    G = const.G
    
    # some other inputs for simDisp
    maxRec = config.maxRec; # same value of number of receivers that qseis can handle in one go check qsglobal.h
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # saves the NN and displacement values per realization
    outDispRea = config.outDispPathRea # like "/data/gravwav/koley/OutDispRea/"
    
    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations

    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH
    # flag if NN is computed directly without writing the displacemnet field
    onFlyNN = config.onFlyNN 

    # number of CPUs to be used for displacement and NN simulation
    nCPUDisp = config.cpuCoresDisp
    nCPUNN = config.cpuCoresNN
    computeStrategy = config.computeStrategy

    # frequency axis to be used by simDisp
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    splitAllNew, tVecN = gfLoader.assembleQseisRuns(splitAll, fInpPath, components, outPath=None, fIndices=idxFreq, minVel=100.0)
    #splitAllNew = np.load(os.path.join(fInpPath,'splitAllNew.npy'))

    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    zList = [0.0,cavDepthUse]
    
    # generate the grid size required
    gridSize = NNCompute.getGridSize(thickness,vp, vs, rho, fMin, fMax, lambdaFrac, lambdaRes)
    
    print('grid size in each layer before partitioning = ' + str(gridSize))
    
    # create the layers and partition
    layers, vp2, vs2, rho2, gridSize2 = NNGeometryNN.createAllLayers(xMin, xMax, yMin, yMax, thickness,
                                                                     zMax,vp,vs,rho,gridSize,cubeTop,cubeBot)
    print('New gridSize after partioning = '+ str(gridSize2))

    print('Total number of layers = ' + str(len(layers)))
    nLayers = len(layers)
    
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq, eP = 0.1, eS = 0.9)
            
            if(wType == 'Px'):
                # P wave along +x
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"] = np.array([0.0])

                # Amplitude and phase for the P-wave
                metaBody["ampP"] = 1.0 * np.ones((1, nFreq))
                metaBody["phaseP"] = 0.0 * np.ones((1, nFreq))

                # Keep one dummy S-wave so your existing loops still work,
                # but set its amplitude to zero.
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"] = np.array([0.0])
                metaBody["psiS"] = np.array([0.0])
                metaBody["ampS"] = np.zeros((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
            
            elif(wType=='Pz'):
            
                # P-wave propagating along +z

                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([1.0])   # +z direction

                # Amplitude and phase for the P-wave
                metaBody["ampP"]   = np.ones((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))

                # Dummy S-wave with zero amplitude
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"]    = np.array([0.0])
                metaBody["psiS"]   = np.array([0.0])
                metaBody["ampS"]   = np.zeros((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
            elif(wType=='SHy'):
                # for SH wave propagating along +y and displacement field along +x
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([0.0])
                metaBody["ampP"]   = np.zeros((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))

                # One S/SH wave propagating along +y
                metaBody["thetaS"] = np.array([0.5*np.pi])
                metaBody["muS"]    = np.array([0.0])
                # For uS = +y, psiS = 0 gives polarization +x
                metaBody["psiS"]   = np.array([0.0])
                metaBody["ampS"]   = np.ones((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
                uS = simDisp.rand_dirs(metaBody["thetaS"], metaBody["muS"])
                polS = simDisp.s_polarizations(uS, metaBody["psiS"])
                print("uS =", uS)
                print("polS =", polS)
                print("ampS first few =", metaBody["ampS"][0, :5])
                print("phaseS first few =", metaBody["phaseS"][0, :5])
            elif(wType=='SHx'):
            
                # SH wave propagating along +x and displacement field along +y
                # No P-wave
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([0.0])
                metaBody["ampP"]   = np.zeros((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))
                # One S/SH wave propagating along +x
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"]    = np.array([0.0])
                # For uS = +x, psiS = pi gives polarization +y
                metaBody["psiS"]   = np.array([np.pi])
                metaBody["ampS"]   = np.ones((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
                uS = simDisp.rand_dirs(metaBody["thetaS"], metaBody["muS"])
                polS = simDisp.s_polarizations(uS, metaBody["psiS"])
                print("uS =", uS)
                print("polS =", polS)
                print("ampS first few =", metaBody["ampS"][0, :5])
                print("phaseS first few =", metaBody["phaseS"][0, :5])
            
            else:
                # SV wave propagating along +x and displacement field along +z
                # No P-wave
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([0.0])
                metaBody["ampP"]   = np.zeros((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))

                # One S/SV wave propagating along +x
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"]    = np.array([0.0])

                # For uS = +x, psiS = 3*pi/2 gives polarization +z
                metaBody["psiS"]   = np.array([1.5*np.pi])

                metaBody["ampS"]   = np.ones((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))

                nSrc = 1

                uS = simDisp.rand_dirs(metaBody["thetaS"], metaBody["muS"])
                polS = simDisp.s_polarizations(uS, metaBody["psiS"])

                print("uS =", uS)
                print("polS =", polS)
        else:
            metaBody=None
        
        # create and save the displacement field on surface and depth for scaling afterwards
        if(ifRay):
            # uses ambient Rayleigh wavefield in homogeneous half space
            phiSrc = srcMeta["phiV"]; ampSrc = srcMeta["ampV"]
            simDisp.getSurfDeepRayDispPerRea(zList, azSrc, phiSrc, ampSrc, outDispRea, reaNo, vR,
                                             vp2[0], vs2[0], freqOut=freqOut)
        elif(ifBody):
            # uses Plane P and S wave in homogeneous half space
            simDisp.getSurfDeepBodyDispPerRea(zList, metaBody, outDispRea, reaNo, vp2[0], vs2[0], freqOut=freqOut)
        
        else:
            # uses QSEIS full wavefield simulation instead
            simDisp.getSurfDeepDispPerRea(zList, xSrc, ySrc, azSrc, srcMeta, xMaxGF, splitAll, fMin, fMax, outDispRea,
                    fInpPath, components, reaNo, idxFreq = idxFreq, freqOut=freqOut)
        
        # preallocate per realization
        IBlockTot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        IVertFaceTot  = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        IHorFaceTot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        ITot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        
        for layerNo, layer in enumerate(layers):
            layer = layers[layerNo]

            # need to redefine cubeTop and cubeBot for multiple cavities
            layer.updateCubeInteraction(cubeTop, cubeBot)
            #layer.generateBlocks(xMin, xMax, yMin, yMax, cubeC, ax, ay, az, domXYBounds)
            layer.generateBlocksNew(refineBoxes=refineBoxes,domXYBounds=domXYBounds,
                                    domainZBounds=(zMin, zMax))
            
            print(layer)
            blkNo = 1
            for blk in layer.blocks:
                print(blk);
                print('Block = '+str(blkNo))
                print('Integrating volume  NN block in layer' + str(layerNo))

                # new version signature
                IBlock = NNCompute.runVolNNComputeBlock(blk, gridSize2[layerNo], freqOut, allCavities, itmAll,
                                                        xSrc, ySrc, azSrc,srcMeta, idxFreq, fMin, fMax, outDispPath, splitAll, xMaxGF,
                                                        fInpPath, components, vR, useSimDisp=ifFullField, ifRay = ifRay, ifBody = ifBody,
                                                        nCPUDisp=nCPUDisp, nCPUNN=nCPUNN, nChunk=20000,metaBody=metaBody,
                                                        computeStrategy=computeStrategy,saveHV=saveHV)
                # new version
                IBlockTot = IBlockTot + IBlock

                # now compute the surface NN from the vertical faces of the block which form the outer boundary
                for f in blk.verticalFaces:
                    if(f.isBoundary):
                        print('Integrating vertical surface NN block in layer' + str(layerNo))
                        print('vertical boundary face found')
                        # is an outer boundary
                        IVertFace = NNCompute.runVertSurfNNCompute(f, gridSize2[layerNo], freqOut, itmAll, xSrc, ySrc, azSrc,
                                                         srcMeta, idxFreq, fMin, fMax, outDispPath, splitAllNew,
                                                         xMaxGF, fInpPath, components, vR, nCPUDisp=1, nChunk = 20000, 
                                                         useSimDisp=ifFullField, ifRay = ifRay, ifBody = ifBody, vP_for_test=blk.vP,
                                                         vS_for_test=blk.vS, metaBody=metaBody,
                                                         computeStrategy=computeStrategy,saveHV=saveHV, reduceNN=onFlyNN)
                        
                        IVertFaceTot = IVertFaceTot + IVertFace
        
                
                # now compute the surface NN from the horizontal interfaces at the very end of layers
                print('Integrating horizontal surface NN block in layer' + str(layerNo))
                IHorFace = NNCompute.handleHorSurfNN(layer, layers, blk, gridSize2[layerNo], nLayers, layerNo, rhoAir, freqOut, 
                                           allCavities, itmAll, xSrc, ySrc, azSrc, srcMeta, idxFreq, fMin, fMax, outDispPath,
                                           splitAllNew, xMaxGF, fInpPath, components, vR, nCPUDisp=nCPUDisp,
                                           nCPUNN=nCPUNN, useSimDisp = ifFullField, ifRay = ifRay, ifBody = ifBody,
                                           vP_for_test=blk.vP, vS_for_test = blk.vS, metaBody = metaBody, chunk_size=20000,
                                           computeStrategy=computeStrategy, saveHV=saveHV, reduceNN=onFlyNN)
                                
                IHorFaceTot = IHorFaceTot + IHorFace
                
                blkNo = blkNo+1
    
        IVertFaceTot = IVertFaceTot*G
        IHorFaceTot = IHorFaceTot*G
        IBlockTot = IBlockTot*G
        ITot = (IBlockTot-IVertFaceTot-IHorFaceTot)
        # save the NN per realization
        nnFName = 'NNFullRea' + str(reaNo) + '.npz'
        np.savez(os.path.join(outDispRea, nnFName), IVertFaceTot = IVertFaceTot, IHorFaceTot = IHorFaceTot,
                 IBlockTot = IBlockTot, ITot = ITot, freqOut=freqOut)

    dispPointAllRea, attnAllRea, freqDisp = simDisp.assembleSurfDeepDispAllRea(outDispRea, zList, freqOut, nRea)
    nnAllRea, nnVolAllRea, nnSurfAllRea, fNN = NNCompute.assembleNNAllReaAllTM(outDispRea,freqOut, nRea,nTM)

if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0. 5000.]
# Number of points per layer along Z = [125]
# Spacing in each layer in meters = [39.85153559 42.19409283]
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# Qseis Inputs cleaned, parent folder intact.
# Creating all input files ...
# All input files created!
# Prepared 508 total runs
# Cores available: 64
# Preparing to run 508 QSEIS jobs with 64 worker(s)...
# [Worker 1886607] Starting job Layer0Run0 at 20:39:49[Worker 1886636] Starting job Layer7Run1 at 20:39:49[Worker 1886608] Starting job Layer0Run1 at 20:39:49
# [Worker 1886610] Starting job Layer0Run3 at 20:39:49[Worker 1886609] Starting job Layer0Run2 at 20:39:49[Worker 1886612] Starting job Layer1Run1 at 20:39:49[Worker 1886611] Starting job Layer1Run0 at 20:39:49[Worker 1886613] Starting job Layer1Run2 at 20:39:49
# [Worker 1886614] Starting job Layer1Run3 at 20:39:49[Worker 1886615] Starting job Layer2Run0 at 20:39:49[Worker 1886616] Starting job Layer2Run1 at 20:39:49[Worker 1886617] Starting job Layer2Run2 at 20:39:49[Worker 1886620] Starting job Layer3Run1 at 20:39:49[Worker 1886618] Starting job Layer2Run3 at 20:39:49[Worker 1886621] Starting job Layer3Run2 at 20:39:49[Worker 1886619] Starting job Layer3Run0 at 20:39:49[Worker 1886622] Starting job Layer3Run3 at 20:39:49[Worker 1886623] Starting job Layer4Run0 at 20:39:49[Worker 1886626] Starting job Layer4Run3 at 20:39:49[Worker 1886625] Starting job Layer4Run2 at 20:39:49[Worker 1886624] Starting job Layer4Run1 at 20:39:49[Worker 1886627] Starting job Layer5Run0 at 20:39:49[Worker 1886629] Starting job Layer5Run2 at 20:39:49[Worker 1886630] Starting job Layer5Run3 at 20:39:49[Worker 1886628] Starting job Layer5Run1 at 20:39:49
# [Worker 1886632] Starting job Layer6Run1 at 20:39:49[Worker 1886633] Starting job Layer6Run2 at 20:39:49[Worker 1886631] Starting job Layer6Run0 at 20:39:49[Worker 1886634] Starting job Layer6Run3 at 20:39:49
# [Worker 1886637] Starting job Layer7Run2 at 20:39:49
#
# [Worker 1886638] Starting job Layer7Run3 at 20:39:49
#
#
# [Worker 1886643] Starting job Layer9Run0 at 20:39:49[Worker 1886635] Starting job Layer7Run0 at 20:39:49[Worker 1886640] Starting job Layer8Run1 at 20:39:49[Worker 1886639] Starting job Layer8Run0 at 20:39:49
run0 at 20:39:54 (0.1 min, rc=0)
# [Worker 1886635] Starting job Layer18Run2 at 20:39:54
# [Worker 1886623] Finished job Layer4Run0 at 20:39:54 (0.1 min, rc=0)
# [Worker 1886623] Starting job Layer18Run3 at 20:39:54
# Completed Layer6Run0
# Completed Layer5Run0
# Completed Layer7Run0
# Completed Layer4Run0
# [Worker 1886615] Finished job Layer2Run0 at 20:39:54 (0.1 min, rc=0)
# [Worker 1886615] Starting job Layer19Run0 at 20:39:54
# [Worker 1886619] Finished job Layer3Run0 at 20:39:54 (0.1 min, rc=0)
# [Worker 1886619] Starting job Layer19Run1 at 20:39:54
# [Worker 1886607] Finished job Layer0Run0 at 20:39:55 (0.1 min, rc=0)
# [Worker 1886607] Starting job Layer19Run2 at 20:39:55
# [Worker 1886611] Finished job Layer1Run0 at 20:39:55 (0.1 min, rc=0)
# [Worker 1886611] Starting job Layer19Run3 at 20:39:55
# Completed Layer2Run0
# Completed Layer3Run0
# Completed Layer0Run0
# Completed Layer1Run0
# [Worker 1886668] Finished job Layer15Run1 at 20:39:56 (0.1 min, rc=0)
# [Worker 1886668] Starting job Layer20Run0 at 20:39:56
# [Worker 1886664] Finished job Layer14Run1 at 20:39:56 (0.1 min, rc=0)
# [Worker 1886664] Starting job Layer20Run1 at 20:39:56
# [Worker 1886652] Finished job Layer11Run1 at 20:39:56 (0.1 min, rc=0)
# [Worker 1886652] Starting job Layer20Run2 at 20:39:56
# [Worker 1886660] Finished job Layer13Run1 at 20:39:56 (0.1 min, rc=0)
# [Worker 1886660] Starting job Layer20Run3 at 20:39:56
# [Worker 1886644] Finished job Layer9Run1 at 20:39:56 (0.1 min, rc=0)
# [Worker 1886644] Starting job Layer21Run0 at 20:39:56
# [Worker 1886640] Finished job Layer8Run1 at 20:39:56 (0.1 min, rc=0)
# [Worker 1886640] Starting job Layer21Run1 at 20:39:56
# [Worker 1886656] Finished job Layer12Run1 at 20:39:56 (0.1 min, rc=0)[Worker 1886648] Finished job Layer10Run1 at 20:39:56 (0.1 min, rc=0)
#
# [Worker 1886656] Starting job Layer21Run2 at 20:39:56[Worker 1886648] Starting job Layer21Run3 at 20:39:56
#
# Completed Layer15Run1
# Completed Layer14Run1
# Completed Layer11Run1
# Completed Layer13Run1
# Completed Layer9Run1
# Completed Layer8Run1
# Completed Layer12Run1
# Completed Layer10Run1
# [Worker 1886632] Finished job Layer6Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886632] Starting job Layer22Run0 at 20:39:57
# [Worker 1886636] Finished job Layer7Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886636] Starting job Layer22Run1 at 20:39:57
# Completed Layer6Run1
# Completed Layer7Run1
# [Worker 1886624] Finished job Layer4Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886624] Starting job Layer22Run2 at 20:39:57
# [Worker 1886628] Finished job Layer5Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886628] Starting job Layer22Run3 at 20:39:57
# Completed Layer4Run1
# Completed Layer5Run1
# [Worker 1886620] Finished job Layer3Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886620] Starting job Layer23Run0 at 20:39:57
# [Worker 1886608] Finished job Layer0Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886608] Starting job Layer23Run1 at 20:39:57
# [Worker 1886616] Finished job Layer2Run1 at 20:39:57 (0.1 min, rc=0)
# [Worker 1886616] Starting job Layer23Run2 at 20:39:57
# Completed Layer3Run1
# Completed Layer0Run1
# Completed Layer2Run1
# [Worker 1886612] Finished job Layer1Run1 at 20:39:58 (0.1 min, rc=0)
# [Worker 1886612] Starting job Layer23Run3 at 20:39:58
# Completed Layer1Run1
# [Worker 1886651] Finished job Layer17Run0 at 20:39:58 (0.1 min, rc=0)
# [Worker 1886651] Starting job Layer24Run0 at 20:39:58
# [Worker 1886643] Finished job Layer16Run0 at 20:39:58 (0.1 min, rc=0)
# [Worker 1886643] Starting job Layer24Run1 at 20:39:58
# Completed Layer17Run0
# Completed Layer16Run0
# [Worker 1886631] Finished job Layer18Run0 at 20:39:58 (0.1 min, rc=0)
# [Worker 1886631] Starting job Layer24Run2 at 20:39:58
# Completed Layer18Run0
# [Worker 1886615] Finished job Layer19Run0 at 20:39:59 (0.1 min, rc=0)
# [Worker 1886615] Starting job Layer24Run3 at 20:39:59
# Completed Layer19Run0
# [Worker 1886669] Finished job Layer15Run2 at 20:39:59 (0.2 min, rc=0)
# [Worker 1886669] Starting job Layer25Run0 at 20:39:59
# Completed Layer15Run2
# [Worker 1886661] Finished job Layer13Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886661] Starting job Layer25Run1 at 20:40:00
# [Worker 1886641] Finished job Layer8Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886641] Starting job Layer25Run2 at 20:40:00
# [Worker 1886649] Finished job Layer10Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886649] Starting job Layer25Run3 at 20:40:00
# [Worker 1886657] Finished job Layer12Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886657] Starting job Layer26Run0 at 20:40:00
# Completed Layer13Run2
# Completed Layer8Run2
# Completed Layer10Run2
# Completed Layer12Run2
# [Worker 1886665] Finished job Layer14Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886665] Starting job Layer26Run1 at 20:40:00
# [Worker 1886653] Finished job Layer11Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886653] Starting job Layer26Run2 at 20:40:00
# [Worker 1886645] Finished job Layer9Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886645] Starting job Layer26Run3 at 20:40:00
# Completed Layer14Run2
# Completed Layer11Run2
# Completed Layer9Run2
# [Worker 1886637] Finished job Layer7Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886637] Starting job Layer27Run0 at 20:40:00
# Completed Layer7Run2
# [Worker 1886633] Finished job Layer6Run2 at 20:40:00 (0.2 min, rc=0)
# [Worker 1886633] Starting job Layer27Run1 at 20:40:00
# [Worker 1886655] Finished job Layer17Run1 at 20:40:01 (0.1 min, rc=0)
# Completed Layer17Run2
# Completed Layer1Run3
# [Worker 1886608] Finished job Layer23Run1 at 20:40:04 (0.1 min, rc=0)
# [Worker 1886608] Starting job Layer36Run2 at 20:40:04
# [Worker 1886663] Finished job Layer16Run2 at 20:40:04 (0.2 min, rc=0)
# [Worker 1886663] Starting job Layer36Run3 at 20:40:04
# [Worker 1886657] Finished job Layer26Run0 at 20:40:04 (0.1 min, rc=0)
# [Worker 1886657] Starting job Layer37Run0 at 20:40:04
# [Worker 1886635] Finished job Layer18Run2 at 20:40:04 (0.2 min, rc=0)
# [Worker 1886635] Starting job Layer37Run1 at 20:40:04
# Completed Layer23Run1
# Completed Layer16Run2
# Completed Layer26Run0
# Completed Layer18Run2
# [Worker 1886637] Finished job Layer27Run0 at 20:40:05 (0.1 min, rc=0)
# [Worker 1886637] Starting job Layer37Run2 at 20:40:05
# [Worker 1886607] Finished job Layer19Run2 at 20:40:05 (0.2 min, rc=0)
# [Worker 1886607] Starting job Layer37Run3 at 20:40:05
# Completed Layer27Run0
# Completed Layer19Run2
# [Worker 1886668] Finished job Layer28Run0 at 20:40:05 (0.1 min, rc=0)
# [Worker 1886643] Finished job Layer24Run1 at 20:40:05 (0.1 min, rc=0)[Worker 1886668] Starting job Layer38Run0 at 20:40:05
#
# [Worker 1886643] Starting job Layer38Run1 at 20:40:05
# [Worker 1886621] Finished job Layer29Run0 at 20:40:05 (0.1 min, rc=0)
# [Worker 1886621] Starting job Layer38Run2 at 20:40:05
# Completed Layer28Run0
# Completed Layer24Run1
# Completed Layer29Run0
# [Worker 1886609] Finished job Layer30Run0 at 20:40:06 (0.1 min, rc=0)
# [Worker 1886609] Starting job Layer38Run3 at 20:40:06
# Completed Layer30Run0
# [Worker 1886666] Finished job Layer31Run0 at 20:40:06 (0.1 min, rc=0)
# [Worker 1886666] Starting job Layer39Run0 at 20:40:06
# [Worker 1886661] Finished job Layer25Run1 at 20:40:06 (0.1 min, rc=0)
# [Worker 1886661] Starting job Layer39Run1 at 20:40:06
# [Worker 1886647] Finished job Layer17Run3 at 20:40:06 (0.2 min, rc=0)
# [Worker 1886647] Starting job Layer39Run2 at 20:40:06
# Completed Layer31Run0
# Completed Layer25Run1
# Completed Layer17Run3
# [Worker 1886652] Finished job Layer20Run2 at 20:40:06 (0.2 min, rc=0)
# [Worker 1886652] Starting job Layer39Run3 at 20:40:06
# [Worker 1886642] Finished job Layer32Run0 at 20:40:06 (0.1 min, rc=0)
# [Worker 1886642] Starting job Layer40Run0 at 20:40:06
# [Worker 1886667] Finished job Layer16Run3 at 20:40:07 (0.2 min, rc=0)
# [Worker 1886667] Starting job Layer40Run1 at 20:40:07
# Completed Layer20Run2
# Completed Layer32Run0
# Completed Layer16Run3
# [Worker 1886665] Finished job Layer26Run1 at 20:40:07 (0.1 min, rc=0)
# [Worker 1886656] Finished job Layer21Run2 at 20:40:07 (0.2 min, rc=0)[Worker 1886665] Starting job Layer40Run2 at 20:40:07
# Completed Layer29Run2
# Completed Layer41Run0
# [Worker 1886633] Finished job Layer42Run0 at 20:40:12 (0.1 min, rc=0)
# [Worker 1886633] Starting job Layer49Run3 at 20:40:12
# [Worker 1886643] Finished job Layer38Run1 at 20:40:12 (0.1 min, rc=0)
# [Worker 1886643] Starting job Layer50Run0 at 20:40:12
# Completed Layer42Run0
# Completed Layer38Run1
# [Worker 1886617] Finished job Layer30Run2 at 20:40:12 (0.2 min, rc=0)
# [Worker 1886617] Starting job Layer50Run1 at 20:40:12
# [Worker 1886658] Finished job Layer31Run2 at 20:40:12 (0.2 min, rc=0)
# [Worker 1886658] Starting job Layer50Run2 at 20:40:12
# Completed Layer30Run2
# Completed Layer31Run2
# [Worker 1886645] Finished job Layer26Run3 at 20:40:12 (0.2 min, rc=0)
# [Worker 1886645] Starting job Layer50Run3 at 20:40:12
# [Worker 1886625] Finished job Layer43Run0 at 20:40:12 (0.1 min, rc=0)
# [Worker 1886625] Starting job Layer51Run0 at 20:40:12
# [Worker 1886649] Finished job Layer25Run3 at 20:40:12 (0.2 min, rc=0)
# [Worker 1886649] Starting job Layer51Run1 at 20:40:12
# Completed Layer26Run3
# Completed Layer43Run0
# Completed Layer25Run3
# [Worker 1886650] Finished job Layer32Run2 at 20:40:12 (0.2 min, rc=0)
# [Worker 1886650] Starting job Layer51Run2 at 20:40:12
# [Worker 1886638] Finished job Layer33Run2 at 20:40:13 (0.2 min, rc=0)
# [Worker 1886638] Starting job Layer51Run3 at 20:40:13
# Completed Layer32Run2
# Completed Layer33Run2
# [Worker 1886631] Finished job Layer44Run0 at 20:40:13 (0.1 min, rc=0)
# [Worker 1886631] Starting job Layer52Run0 at 20:40:13
# [Worker 1886629] Finished job Layer27Run3 at 20:40:13 (0.2 min, rc=0)
# [Worker 1886629] Starting job Layer52Run1 at 20:40:13
# Completed Layer44Run0
# Completed Layer27Run3
# [Worker 1886661] Finished job Layer39Run1 at 20:40:13 (0.1 min, rc=0)
# ...
# [Worker 1886662] Finished job Layer109Run2 at 20:40:52 (0.2 min, rc=0)
# Completed Layer120Run0
# Completed Layer109Run2
# [Worker 1886639] Finished job Layer105Run3 at 20:40:53 (0.2 min, rc=0)
# [Worker 1886643] Finished job Layer121Run0 at 20:40:53 (0.1 min, rc=0)
# Completed Layer105Run3
# Completed Layer121Run0
# [Worker 1886641] Finished job Layer116Run1 at 20:40:53 (0.1 min, rc=0)
# Completed Layer116Run1
# [Worker 1886627] Finished job Layer110Run2 at 20:40:53 (0.2 min, rc=0)
# [Worker 1886651] Finished job Layer111Run2 at 20:40:53 (0.2 min, rc=0)
# [Worker 1886613] Finished job Layer122Run0 at 20:40:53 (0.1 min, rc=0)
# Completed Layer110Run2
# Completed Layer111Run2
# Completed Layer122Run0
# [Worker 1886646] Finished job Layer106Run3 at 20:40:53 (0.2 min, rc=0)
# [Worker 1886616] Finished job Layer117Run1 at 20:40:53 (0.1 min, rc=0)
# Completed Layer106Run3
# Completed Layer117Run1
# [Worker 1886631] Finished job Layer118Run1 at 20:40:54 (0.1 min, rc=0)
# [Worker 1886656] Finished job Layer107Run3 at 20:40:54 (0.2 min, rc=0)
# [Worker 1886618] Finished job Layer123Run0 at 20:40:54 (0.1 min, rc=0)
# Completed Layer118Run1
# Completed Layer107Run3
# Completed Layer123Run0
# [Worker 1886658] Finished job Layer112Run2 at 20:40:54 (0.2 min, rc=0)
# Completed Layer112Run2
# [Worker 1886634] Finished job Layer119Run1 at 20:40:54 (0.1 min, rc=0)
# [Worker 1886660] Finished job Layer124Run0 at 20:40:54 (0.1 min, rc=0)
# [Worker 1886617] Finished job Layer108Run3 at 20:40:54 (0.2 min, rc=0)
# Completed Layer119Run1
# Completed Layer124Run0
# Completed Layer108Run3
# [Worker 1886669] Finished job Layer120Run1 at 20:40:54 (0.1 min, rc=0)
# [Worker 1886642] Finished job Layer125Run0 at 20:40:54 (0.1 min, rc=0)
# [Worker 1886649] Finished job Layer113Run2 at 20:40:54 (0.2 min, rc=0)
# Completed Layer120Run1
# Completed Layer125Run0
# Completed Layer113Run2
# [Worker 1886640] Finished job Layer109Run3 at 20:40:55 (0.2 min, rc=0)
# [Worker 1886615] Finished job Layer114Run2 at 20:40:55 (0.2 min, rc=0)
# [Worker 1886650] Finished job Layer121Run1 at 20:40:55 (0.1 min, rc=0)
# Completed Layer109Run3
# Completed Layer114Run2
# Completed Layer121Run1
# [Worker 1886621] Finished job Layer126Run0 at 20:40:55 (0.1 min, rc=0)
# [Worker 1886622] Finished job Layer110Run3 at 20:40:55 (0.2 min, rc=0)
# [Worker 1886663] Finished job Layer115Run2 at 20:40:55 (0.2 min, rc=0)
# Completed Layer126Run0
# Completed Layer110Run3
# Completed Layer115Run2
# [Worker 1886670] Finished job Layer111Run3 at 20:40:55 (0.2 min, rc=0)
# Completed Layer111Run3
# [Worker 1886664] Finished job Layer116Run2 at 20:40:56 (0.2 min, rc=0)
# [Worker 1886607] Finished job Layer122Run1 at 20:40:56 (0.1 min, rc=0)
# Completed Layer116Run2
# Completed Layer122Run1
# [Worker 1886647] Finished job Layer123Run1 at 20:40:56 (0.1 min, rc=0)
# Completed Layer123Run1
# [Worker 1886635] Finished job Layer112Run3 at 20:40:56 (0.2 min, rc=0)
# [Worker 1886632] Finished job Layer117Run2 at 20:40:56 (0.2 min, rc=0)
# Completed Layer112Run3
# Completed Layer117Run2
# [Worker 1886653] Finished job Layer113Run3 at 20:40:57 (0.2 min, rc=0)
# [Worker 1886624] Finished job Layer124Run1 at 20:40:57 (0.1 min, rc=0)
# [Worker 1886661] Finished job Layer118Run2 at 20:40:57 (0.2 min, rc=0)
# Completed Layer113Run3
# Completed Layer124Run1
# Completed Layer118Run2
# [Worker 1886657] Finished job Layer125Run1 at 20:40:57 (0.1 min, rc=0)
# Completed Layer125Run1
# [Worker 1886637] Finished job Layer119Run2 at 20:40:57 (0.2 min, rc=0)
# [Worker 1886619] Finished job Layer114Run3 at 20:40:57 (0.2 min, rc=0)
# [Worker 1886668] Finished job Layer115Run3 at 20:40:57 (0.2 min, rc=0)
# [Worker 1886652] Finished job Layer126Run1 at 20:40:57 (0.1 min, rc=0)
# Completed Layer119Run2
# Completed Layer114Run3
# Completed Layer115Run3
# Completed Layer126Run1
# [Worker 1886655] Finished job Layer120Run2 at 20:40:58 (0.2 min, rc=0)
# [Worker 1886633] Finished job Layer116Run3 at 20:40:58 (0.2 min, rc=0)
# Completed Layer120Run2
# Completed Layer116Run3
# [Worker 1886659] Finished job Layer121Run2 at 20:40:58 (0.2 min, rc=0)
# Completed Layer121Run2
# [Worker 1886638] Finished job Layer122Run2 at 20:40:59 (0.2 min, rc=0)
# [Worker 1886609] Finished job Layer117Run3 at 20:40:59 (0.2 min, rc=0)
# Completed Layer122Run2
# Completed Layer117Run3
# [Worker 1886665] Finished job Layer118Run3 at 20:40:59 (0.2 min, rc=0)
# [Worker 1886625] Finished job Layer123Run2 at 20:40:59 (0.2 min, rc=0)
# Completed Layer118Run3
# Completed Layer123Run2
# [Worker 1886623] Finished job Layer119Run3 at 20:40:59 (0.2 min, rc=0)
# Completed Layer119Run3
# [Worker 1886629] Finished job Layer120Run3 at 20:41:00 (0.2 min, rc=0)
# [Worker 1886610] Finished job Layer124Run2 at 20:41:00 (0.2 min, rc=0)
# Completed Layer120Run3
# Completed Layer124Run2
# [Worker 1886628] Finished job Layer125Run2 at 20:41:00 (0.2 min, rc=0)
# [Worker 1886620] Finished job Layer121Run3 at 20:41:00 (0.2 min, rc=0)
# Completed Layer125Run2
# Completed Layer121Run3
# [Worker 1886645] Finished job Layer126Run2 at 20:41:00 (0.2 min, rc=0)
# Completed Layer126Run2
# [Worker 1886648] Finished job Layer122Run3 at 20:41:01 (0.2 min, rc=0)
# Completed Layer122Run3
# [Worker 1886654] Finished job Layer123Run3 at 20:41:01 (0.2 min, rc=0)
# Completed Layer123Run3
# [Worker 1886667] Finished job Layer124Run3 at 20:41:02 (0.2 min, rc=0)
# Completed Layer124Run3
# [Worker 1886636] Finished job Layer125Run3 at 20:41:02 (0.2 min, rc=0)
# Completed Layer125Run3
# [Worker 1886630] Finished job Layer126Run3 at 20:41:03 (0.2 min, rc=0)
# Completed Layer126Run3
# All QSEIS runs finished.
# Database generation complete
# CubeTop = 140.0CubeBot = 360.0
# itmAC = 0.0, 0.0, 250.0
# [0.    0.025 0.05  0.075 0.1  ]
# [assembleQseisRuns] saved | z=0.000 m |
# [assembleQseisRuns] saved | z=39.852 m |
# [assembleQseisRuns] saved | z=79.703 m |
# [assembleQseisRuns] saved | z=119.555 m |
# [assembleQseisRuns] saved | z=159.406 m |
# [assembleQseisRuns] saved | z=199.258 m |
# [assembleQseisRuns] saved | z=239.109 m |
# [assembleQseisRuns] saved | z=278.961 m |
# [assembleQseisRuns] saved | z=318.812 m |
# [assembleQseisRuns] saved | z=358.664 m |
# [assembleQseisRuns] saved | z=398.515 m |
# Total number of layers = 3
# Doing realization = 0
# uS = [[6.123234e-17 1.000000e+00 0.000000e+00]]
# polS = [[ 1.000000e+00 -6.123234e-17  0.000000e+00]]
# ampS first few = [1. 1. 1. 1. 1.]
# phaseS first few = [0. 0. 0. 0. 0.]
# <Layer z: 0.0-50.0, type: no_intersection, nblocks: 1>
# <Block x:[-2000.0,2000.0], y:[-2000.0,2000.0], z:[0.0,50.0] spaceT:[lgwt] intpType:[1] >
# Block = 1
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# Actually computing NN for the horizontal surface
# <Layer z: 50.0-450.0, type: contains, nblocks: 11>
# <Block x:[-2000.0,-150.0], y:[-2000.0,-110.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 1
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-2000.0,-150.0], y:[-110.0,110.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 2
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-2000.0,-150.0], y:[110.0,2000.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 3
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-150.0,150.0], y:[-2000.0,-110.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 4
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[-150.0,150.0], y:[-110.0,110.0], z:[50.0,140.0] spaceT:[lgwt] intpType:[2] >
# Block = 5
# Integrating volume  NN block in layer1
# Integrating horizontal surface NN block in layer1
# <Block x:[-150.0,150.0], y:[-110.0,110.0], z:[140.0,360.0] spaceT:[uniform] intpType:[1] >
# Block = 6
# Integrating volume  NN block in layer1
# Uniform spacing
# Total points = 12720
# Integrating horizontal surface NN block in layer1
# <Block x:[-150.0,150.0], y:[-110.0,110.0], z:[360.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 7
# Integrating volume  NN block in layer1
# Integrating horizontal surface NN block in layer1
# <Block x:[-150.0,150.0], y:[110.0,2000.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 8
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[150.0,2000.0], y:[-2000.0,-110.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 9
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[150.0,2000.0], y:[-110.0,110.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 10
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Block x:[150.0,2000.0], y:[110.0,2000.0], z:[50.0,450.0] spaceT:[lgwt] intpType:[2] >
# Block = 11
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# <Layer z: 450.0-4000.0, type: no_intersection, nblocks: 1>
# <Block x:[-2000.0,2000.0], y:[-2000.0,2000.0], z:[450.0,4000.0] spaceT:[lgwt] intpType:[1] >
# Block = 1
# Integrating volume  NN block in layer2
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating vertical surface NN block in layer2
# vertical boundary face found
# Integrating horizontal surface NN block in layer2
# Horizontal face found
# Actually computing NN for the horizontal surface
# /home/koley/pySeis1DNNCavity/modules/simDisp.py:311: RuntimeWarning: invalid value encountered in divide
#   attnAllRea = dispPointAllRea[:,:,0]/dispPointAllRea[:,:,1]

# %%
# run this cell immediately after the previous cell
# or adapt accordingly
import matplotlib.pyplot as plt
import scipy.constants as const
import numpy as np
import os
from modules import configLoader
from modules import bodyPSNN
from modules import plotUtils
configFile="/home/koley/CavityResults/CuboidTutorialConfig/configParseHalfSpaceBodyHomo.ini"
config = configLoader.load_config(configFile)
data = np.load(os.path.join(config.outDispPathRea, "NNFullRea0.npz"))

Iblock = data["IBlockTot"]
Ivert  = data["IVertFaceTot"]
Ihor   = data["IHorFaceTot"]
Itot   = data["ITot"]
freqOut = data["freqOut"]

G = const.G
rho = config.rho[0]
vS = config.vS[0]
vP = config.vP[0]
rho = config.rho[0]

L = 2000.0
# cavity half-lengths
a = 50.0
b = 10.0
c = 10.0
xi0 = 1.0
wType = 'SHy'
# depth of cavity center below the surface
cav_depth = 250.0
# cavity center in global coordinates
cav_center = np.array([0.0, 0.0, L - cav_depth])
outer_bounds = (-L, L,-L, L,-L, L)
cavity_bounds = (
    cav_center[0] - a, cav_center[0] + a,
    cav_center[1] - b, cav_center[1] + b,
    cav_center[2] - c, cav_center[2] + c,
)
# test mass at cavity center
tm = cav_center.copy()
tm_shift = np.array([0.0, 0.0, 0.0])   # example: no shift
tm = cav_center + tm_shift
if(wType == 'Px'):
    pieces = [bodyPSNN.P_x_all_components_shifted(f,vP,outer_bounds=outer_bounds,cavity_bounds=cavity_bounds,
                                                  tm=tm,)
                                                  for f in freqOut]
    compPlot = 0

elif(wType == 'Pz'):
    pieces = [bodyPSNN.P_z_all_components_shifted(f,vP,outer_bounds=outer_bounds,cavity_bounds=cavity_bounds,
                                                  tm=tm,)
                                                  for f in freqOut]
    compPlot = 2

elif(wType=='SHy'):
    pieces = [bodyPSNN.SH_y_x_all_components_shifted(f,vS,outer_bounds=outer_bounds,cavity_bounds=cavity_bounds,
                                                     tm=tm,)
                                                     for f in freqOut]
    compPlot = 0
elif(wType == 'SHx'):
    pieces = [bodyPSNN.SH_x_y_all_components_shifted(f,vS,outer_bounds=outer_bounds,cavity_bounds=cavity_bounds,
                                                     tm=tm,)
                                                     for f in freqOut]
    compPlot = 1

else:
    pieces = [bodyPSNN.SV_x_z_all_components_shifted(f,vS,outer_bounds=outer_bounds,cavity_bounds=cavity_bounds,
                                                     tm=tm,)
                                                     for f in freqOut]
    compPlot = 2

H_bulk  = np.array([p[0] for p in pieces])   # shape (nFreq, 3)
H_vert  = np.array([p[1] for p in pieces])
H_hor   = np.array([p[2] for p in pieces])
H_total = np.array([p[3] for p in pieces])

A_bulk  = G*rho*xi0*H_bulk
A_vert  = G*rho*xi0*H_vert
A_hor = G*rho*xi0*H_hor
A_total = G*rho*xi0*H_total

plotUtils.set_plot_style(style="large")
fig, ax = plt.subplots(1,3,figsize=(16,6), constrained_layout = True)
fig.suptitle('Cuboid at depth ' + str(cav_depth) + ' m, side lengths =' + str(2*a) + ',' + str(2*b) + ',' + str(2*c) + ' m')
# or plt.suptitle('Main title')
ax[0].semilogy(freqOut, np.abs(Iblock[:,compPlot,0]),'r*', label="pySeisNN bulk")
ax[0].semilogy(freqOut, np.abs(A_bulk[:,compPlot]),  "b-", label="semi-analytic bulk")
ax[0].semilogy(freqOut, 8*np.pi/3*G*rho*np.ones((len(freqOut),1)),'k',label = r'$\frac{8\pi}{3}G\rho$')
ax[0].set_xlabel('Frequency (Hz)')
ax[0].legend()
ax[0].set_ylabel("NN acceleration: " + r"$\xi_{\mathrm{tm}} = 1 \mathrm{m}/\sqrt{\mathrm{Hz}}$")
ax[0].grid(True, which="both")
#ax[0].set_ylim(10**-7, 3*10**-6)
ax[0].set_title('(a) Dipole bulk contribution')


if(wType == 'Px' or wType == 'SHy' or wType == 'SHx'):
    ax[1].semilogy(freqOut, np.abs(A_vert[:,compPlot]), "b-", label = "analytical vert surf")
    ax[1].semilogy(freqOut, np.abs(Ivert[:,compPlot,0]), 'r*', label="pySeisNN vert surf")
else:
    ax[1].semilogy(freqOut, np.abs(A_hor[:,compPlot]), "b-", label = "analytical hor surf")
    ax[1].semilogy(freqOut, np.abs(Ihor[:,compPlot,0]), 'r*', label="pySeisNN hor surf")
ax[1].set_xlabel('Frequency (Hz)')
ax[1].legend()
ax[1].grid(True, which="both")
#ax[1].set_ylim(10**-7, 3*10**-6)
ax[1].set_title('(b) Horizontal surface contribution')

ax[2].semilogy(freqOut, np.abs(Itot[:,compPlot,0]), 'r*', label="pySeisNN total")
ax[2].semilogy(freqOut, np.abs(A_total[:,compPlot]), "b-", label="semi-analytic total")
ax[2].semilogy(freqOut, 8*np.pi/3*G*rho*np.ones((len(freqOut),1)),'k',label = r'$\frac{8\pi}{3}G\rho$')
ax[2].set_xlabel('Frequency (Hz)')
ax[2].legend()
ax[2].grid(True, which="both")
#ax[2].set_ylim(10**-7, 3*10**-6)
ax[2].set_title('(c) Total Newtonian acceleration')

Tx = 8*np.arctan((b*c)/(a*np.sqrt(a*a+b*b+c*c)))
print("Tx cavity =", Tx)
print("G*rho*Tx =", G*rho*Tx)
print("First code total / (G*rho) =", np.abs(Itot[0,0])/(G*rho))
print("First analytic total / (G*rho) =", np.abs(H_total[0]))
# Out:
# Tx cavity = 0.3077682192586266
# G*rho*Tx = 5.063448754591703e-08
# First code total / (G*rho) = [0.30791525 0.31642623 0.31642623 0.32483533]
# First analytic total / (G*rho) = [0.30756888 0.         0.        ]
