# %%
# script for checking the attenuation between any two points at different depths but same (x,y)
# script written to test the accuracy of simpDisp module
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
import scipy.constants as const
from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from  modules import createDB
from modules import simDisp
from modules import plotUtils

def main():

    # load the config file
    configFile="configParseAttnTest.ini"
    config = configLoader.load_config(configFile)
    validateInputs.validateInputs(config)
    
    splitAll = createDB.createFinalInputs(config)

    print(f"Prepared {splitAll.shape[0]} total runs")
    print(f"Cores available: {config.cpuCoresQseis}")

    results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    print("Database generation complete")
    
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay

    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody

    # flag for wavefield simulation
    ifFullField = config.ifFullField

    saveHV = config.saveHV

    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    rhoAir = config.rhoAir # density of air
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    lambdaFrac = config.lambdaFrac # fraction
    lambdaRes = config.lambdaRes; #must be greater than 4
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used
    maxRec = config.maxRec # same value of number of receivers that qseis can handle in one go check qsglobal.h
    
    xMin = -config.xExtent; xMax = config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = -config.yExtent; yMax = config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")
        
    domXYBounds = (xMin,xMax,yMin,yMax)
    cubeC = config.cavityDepth; rCavity = config.cavityRadius
    cubeS = 2*rCavity
    cubeTop = cubeC-cubeS; cubeBot = cubeC+cubeS
    
    G = const.G
    
    # some other inputs for simDisp
    maxRec = config.maxRec; # same value of number of receivers that qseis can handle in one go check qsglobal.h
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # saves the NN and displacement values per realization
    outDispRea = config.outDispPathRea # like "/data/gravwav/koley/OutDispRea/"
    
    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations

    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH

    # number of CPUs to be used for displacement and NN simulation
    nCPUDisp = config.cpuCoresDisp
    nCPUNN = config.cpuCoresNN
    computeStrategy = config.computeStrategy

    # frequency axis to be used by simDisp
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    zTar = np.array((0.0, 250.0,))
    gridX = np.array((0.0,))
    gridY = np.array((0.0,))

    #recDistAB = np.sqrt((gridX[0]-gridX[1])**2 + (gridY[0]-gridY[1])**2 + (zTar[0]-zTar[1])**2)
    
    # nFreqx3 for the three percentiles
    attnZObs = np.zeros((nFreq,3), dtype=np.complex128)
    attnXObs = np.zeros((nFreq,3), dtype=np.complex128)
    attnYObs = np.zeros((nFreq,3), dtype=np.complex128)
    attnZSim = np.zeros((nFreq,), dtype=np.complex128)
    attnXSim = np.zeros((nFreq,), dtype=np.complex128)
    attnYSim = np.zeros((nFreq,), dtype=np.complex128)
    dispTotalAllReaSurf = np.zeros((nFreq,1,3), dtype=np.complex128)
    dispTotalAllReaDepth = np.zeros((nFreq,1,3), dtype=np.complex128)
    
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        #srcMeta["ampV"] *= 0.0
        #ySrc = np.zeros((nSrc,))

        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq)
        else:
            metaBody=None
        
        dispTotalSurf, outDir, fOut = simDisp.computeFullDispN(zTar[0], gridX, gridY, xSrc, ySrc, azSrc, srcMeta, idxFreq, freqOut, fMin, fMax,
                     outDispPath, splitAll, xMaxGF, fInpPath, components, nCPU=1, nChunk=20000, minVel=100.0,
                     computeStrategy=computeStrategy, saveHV=saveHV)
        
        dispTotalDepth, outDir, fOut = simDisp.computeFullDispN(zTar[1], gridX, gridY, xSrc, ySrc, azSrc, srcMeta, idxFreq, freqOut, fMin, fMax,
                     outDispPath, splitAll, xMaxGF, fInpPath, components, nCPU=1, nChunk=20000, minVel=100.0,
                     computeStrategy=computeStrategy, saveHV=saveHV)
        # populate the cross correlation matrices
        
        dispTotalAllReaSurf += (np.abs(dispTotalSurf))**2
        dispTotalAllReaDepth += (np.abs(dispTotalDepth))**2

    dispTotalAllReaSurf = np.sqrt(dispTotalAllReaSurf/nRea)
    dispTotalAllReaDepth = np.sqrt(dispTotalAllReaDepth/nRea)
    
          
    attnXSim += (dispTotalAllReaSurf[:,0,0]/dispTotalAllReaDepth[:,0,0])
    attnYSim += (dispTotalAllReaSurf[:,0,1]/dispTotalAllReaDepth[:,0,1])
    attnZSim += (dispTotalAllReaSurf[:,0,2]/dispTotalAllReaDepth[:,0,2])

    attnSim = np.stack((attnXSim,attnYSim,attnZSim),axis=-1)
    print(np.shape(attnSim))    
    # load Terziet Attenuation
    terzAttn = loadmat(os.path.join(config.siteASDPath,'attnModel.mat'))
    for i in range(0,3):
        attnXObs[:,i] = np.interp(freqOut,terzAttn['attnE'][:,0],terzAttn['attnE'][:,i+1])
        attnYObs[:,i] = np.interp(freqOut,terzAttn['attnN'][:,0],terzAttn['attnN'][:,i+1])
        attnZObs[:,i] = np.interp(freqOut,terzAttn['attnZ'][:,0],terzAttn['attnZ'][:,i+1])
    
    figAttn, axAttn = plotUtils.plotAttn(freqOut, attnSim, attnXObs, attnYObs, attnZObs)

if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0.      9.37   16.03   37.22   48.54   68.5   214.43 5000.  ]
# Number of points per layer along Z = [ 2  1  3  1  1  4 73]
# Spacing in each layer in meters = [ 4.34388186  5.00984617  8.3798768  15.50738397 24.50348437 39.09861048
#  65.45295359]
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# /home/koley/.conda/envs/pySeis1DNN/lib/python3.11/site-packages/pysurf96/wrapper.py:99: RuntimeWarning: overflow encountered in cast
#   error = surfdisp96(
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# Qseis Inputs cleaned, parent folder intact.
# Creating all input files ...
# All input files created!
# Prepared 382 total runs
# Cores available: 64
# Preparing to run 382 QSEIS jobs with 64 worker(s)...
# [Worker 1019142] Starting job Layer0Run0 at 03:35:21[Worker 1019154] Starting job Layer0Run12 at 03:35:21[Worker 1019143] Starting job Layer0Run1 at 03:35:21[Worker 1019145] Starting job Layer0Run3 at 03:35:21[Worker 1019144] Starting job Layer0Run2 at 03:35:21[Worker 1019146] Starting job Layer0Run4 at 03:35:21[Worker 1019148] Starting job Layer0Run6 at 03:35:21[Worker 1019149] Starting job Layer0Run7 at 03:35:21[Worker 1019147] Starting job Layer0Run5 at 03:35:21[Worker 1019150] Starting job Layer0Run8 at 03:35:21
# [Worker 1019151] Starting job Layer0Run9 at 03:35:21[Worker 1019152] Starting job Layer0Run10 at 03:35:21[Worker 1019153] Starting job Layer0Run11 at 03:35:21[Worker 1019155] Starting job Layer0Run13 at 03:35:21[Worker 1019157] Starting job Layer0Run15 at 03:35:21[Worker 1019158] Starting job Layer0Run16 at 03:35:21[Worker 1019156] Starting job Layer0Run14 at 03:35:21[Worker 1019159] Starting job Layer0Run17 at 03:35:21[Worker 1019160] Starting job Layer0Run18 at 03:35:21
#
# [Worker 1019163] Starting job Layer0Run21 at 03:35:21[Worker 1019162] Starting job Layer0Run20 at 03:35:21[Worker 1019161] Starting job Layer0Run19 at 03:35:21[Worker 1019164] Starting job Layer0Run22 at 03:35:21[Worker 1019168] Starting job Layer0Run26 at 03:35:21
# [Worker 1019171] Starting job Layer2Run12 at 03:35:35
# Completed Layer1Run1
# [Worker 1019143] Finished job Layer0Run1 at 03:35:37 (0.3 min, rc=0)
# [Worker 1019143] Starting job Layer2Run13 at 03:35:37
# Completed Layer0Run1
# [Worker 1019200] Finished job Layer2Run2 at 03:35:40 (0.3 min, rc=0)
# [Worker 1019200] Starting job Layer2Run14 at 03:35:40
# Completed Layer2Run2
# [Worker 1019172] Finished job Layer1Run2 at 03:35:42 (0.4 min, rc=0)
# [Worker 1019172] Starting job Layer2Run15 at 03:35:42
# Completed Layer1Run2
# [Worker 1019144] Finished job Layer0Run2 at 03:35:44 (0.4 min, rc=0)
# [Worker 1019144] Starting job Layer2Run16 at 03:35:44
# Completed Layer0Run2
# [Worker 1019201] Finished job Layer2Run3 at 03:35:46 (0.4 min, rc=0)
# [Worker 1019201] Starting job Layer2Run17 at 03:35:46
# Completed Layer2Run3
# [Worker 1019173] Finished job Layer1Run3 at 03:35:49 (0.5 min, rc=0)
# [Worker 1019173] Starting job Layer2Run18 at 03:35:49
# Completed Layer1Run3
# [Worker 1019145] Finished job Layer0Run3 at 03:35:52 (0.5 min, rc=0)
# [Worker 1019145] Starting job Layer2Run19 at 03:35:52
# Completed Layer0Run3
# [Worker 1019202] Finished job Layer2Run4 at 03:35:52 (0.5 min, rc=0)
# [Worker 1019202] Starting job Layer2Run20 at 03:35:52
# Completed Layer2Run4
# [Worker 1019174] Finished job Layer1Run4 at 03:35:56 (0.6 min, rc=0)
# [Worker 1019174] Starting job Layer2Run21 at 03:35:56
# Completed Layer1Run4
# [Worker 1019203] Finished job Layer2Run5 at 03:35:58 (0.6 min, rc=0)
# [Worker 1019203] Starting job Layer2Run22 at 03:35:58
# Completed Layer2Run5
# [Worker 1019146] Finished job Layer0Run4 at 03:35:59 (0.6 min, rc=0)
# [Worker 1019146] Starting job Layer2Run23 at 03:35:59
# Completed Layer0Run4
# [Worker 1019175] Finished job Layer1Run5 at 03:36:03 (0.7 min, rc=0)
# [Worker 1019175] Starting job Layer2Run24 at 03:36:03
# Completed Layer1Run5
# [Worker 1019204] Finished job Layer2Run6 at 03:36:05 (0.7 min, rc=0)
# [Worker 1019204] Starting job Layer2Run25 at 03:36:05
# Completed Layer2Run6
# [Worker 1019147] Finished job Layer0Run5 at 03:36:07 (0.8 min, rc=0)
# [Worker 1019147] Starting job Layer2Run26 at 03:36:07
# Completed Layer0Run5
# [Worker 1019205] Finished job Layer2Run7 at 03:36:11 (0.8 min, rc=0)
# [Worker 1019205] Starting job Layer2Run27 at 03:36:11
# [Worker 1019176] Finished job Layer1Run6 at 03:36:11 (0.8 min, rc=0)
# [Worker 1019176] Starting job Layer3Run0 at 03:36:11
# Completed Layer2Run7
# Completed Layer1Run6
# [Worker 1019148] Finished job Layer0Run6 at 03:36:13 (0.9 min, rc=0)
# [Worker 1019148] Starting job Layer3Run1 at 03:36:13
# Completed Layer0Run6
# [Worker 1019176] Finished job Layer3Run0 at 03:36:17 (0.1 min, rc=0)
# [Worker 1019176] Starting job Layer3Run2 at 03:36:17
# Completed Layer3Run0
# [Worker 1019177] Finished job Layer1Run7 at 03:36:18 (1.0 min, rc=0)
# [Worker 1019177] Starting job Layer3Run3 at 03:36:18
# Completed Layer1Run7
# [Worker 1019149] Finished job Layer0Run7 at 03:36:21 (1.0 min, rc=0)
# [Worker 1019149] Starting job Layer3Run4 at 03:36:21
# Completed Layer0Run7
# [Worker 1019178] Finished job Layer1Run8 at 03:36:23 (1.0 min, rc=0)
# [Worker 1019178] Starting job Layer3Run5 at 03:36:23
# Completed Layer1Run8
# [Worker 1019198] Finished job Layer2Run8 at 03:36:25 (1.0 min, rc=0)
# [Worker 1019198] Starting job Layer3Run6 at 03:36:25
# Completed Layer2Run8
# [Worker 1019148] Finished job Layer3Run1 at 03:36:25 (0.2 min, rc=0)
# [Worker 1019148] Starting job Layer3Run7 at 03:36:25
# Completed Layer3Run1
# [Worker 1019150] Finished job Layer0Run8 at 03:36:31 (1.2 min, rc=0)
# [Worker 1019150] Starting job Layer3Run8 at 03:36:31
# Completed Layer0Run8
# [Worker 1019170] Finished job Layer2Run9 at 03:36:31 (1.1 min, rc=0)
# [Worker 1019170] Starting job Layer3Run9 at 03:36:31
# Completed Layer2Run9
# [Worker 1019179] Finished job Layer1Run9 at 03:36:32 (1.2 min, rc=0)
# [Worker 1019179] Starting job Layer3Run10 at 03:36:32
# Completed Layer1Run9
# [Worker 1019176] Finished job Layer3Run2 at 03:36:35 (0.3 min, rc=0)
# [Worker 1019176] Starting job Layer3Run11 at 03:36:35
# Completed Layer3Run2
# [Worker 1019151] Finished job Layer0Run9 at 03:36:37 (1.3 min, rc=0)
# [Worker 1019151] Starting job Layer3Run12 at 03:36:37
# Completed Layer0Run9
# [Worker 1019180] Finished job Layer1Run10 at 03:36:38 (1.3 min, rc=0)
# [Worker 1019180] Starting job Layer3Run13 at 03:36:38
# [Worker 1019142] Finished job Layer2Run10 at 03:36:38 (1.2 min, rc=0)
# [Worker 1019142] Starting job Layer3Run14 at 03:36:38
# Completed Layer1Run10
# Completed Layer2Run10
# [Worker 1019177] Finished job Layer3Run3 at 03:36:41 (0.4 min, rc=0)
# [Worker 1019177] Starting job Layer3Run15 at 03:36:41
# Completed Layer3Run3
# [Worker 1019152] Finished job Layer0Run10 at 03:36:43 (1.4 min, rc=0)
# [Worker 1019152] Starting job Layer3Run16 at 03:36:43
# Completed Layer0Run10
# [Worker 1019181] Finished job Layer1Run11 at 03:36:45 (1.4 min, rc=0)
# [Worker 1019181] Starting job Layer3Run17 at 03:36:45
# Completed Layer1Run11
# [Worker 1019199] Finished job Layer2Run11 at 03:36:49 (1.3 min, rc=0)
# [Worker 1019199] Starting job Layer3Run18 at 03:36:49
# Completed Layer2Run11
# [Worker 1019149] Finished job Layer3Run4 at 03:36:50 (0.5 min, rc=0)
# [Worker 1019149] Starting job Layer3Run19 at 03:36:50
# Completed Layer3Run4
# [Worker 1019182] Finished job Layer1Run12 at 03:36:52 (1.5 min, rc=0)
# [Worker 1019182] Starting job Layer3Run20 at 03:36:52
# Completed Layer1Run12
# [Worker 1019153] Finished job Layer0Run11 at 03:36:52 (1.5 min, rc=0)
# [Worker 1019153] Starting job Layer3Run21 at 03:36:52
# Completed Layer0Run11
# [Worker 1019171] Finished job Layer2Run12 at 03:36:57 (1.4 min, rc=0)
# [Worker 1019171] Starting job Layer3Run22 at 03:36:57
# Completed Layer2Run12
# [Worker 1019178] Finished job Layer3Run5 at 03:36:58 (0.6 min, rc=0)
# [Worker 1019178] Starting job Layer3Run23 at 03:36:58
# [Worker 1019183] Finished job Layer1Run13 at 03:36:58 (1.6 min, rc=0)
# [Worker 1019183] Starting job Layer3Run24 at 03:36:58
# Completed Layer3Run5
# Completed Layer1Run13
# [Worker 1019154] Finished job Layer0Run12 at 03:37:00 (1.7 min, rc=0)
# [Worker 1019154] Starting job Layer3Run25 at 03:37:00
# Completed Layer0Run12
# [Worker 1019143] Finished job Layer2Run13 at 03:37:04 (1.5 min, rc=0)
# [Worker 1019143] Starting job Layer3Run26 at 03:37:04
# Completed Layer2Run13
# [Worker 1019198] Finished job Layer3Run6 at 03:37:06 (0.7 min, rc=0)
# [Worker 1019198] Starting job Layer3Run27 at 03:37:06
# Completed Layer3Run6
# [Worker 1019155] Finished job Layer0Run13 at 03:37:06 (1.8 min, rc=0)
# [Worker 1019155] Starting job Layer4Run0 at 03:37:06
# Completed Layer0Run13
# [Worker 1019184] Finished job Layer1Run14 at 03:37:07 (1.8 min, rc=0)
# [Worker 1019184] Starting job Layer4Run1 at 03:37:07
# Completed Layer1Run14
# [Worker 1019148] Finished job Layer3Run7 at 03:37:13 (0.8 min, rc=0)[Worker 1019155] Finished job Layer4Run0 at 03:37:13 (0.1 min, rc=0)
#
# [Worker 1019148] Starting job Layer4Run2 at 03:37:13
# [Worker 1019155] Starting job Layer4Run3 at 03:37:13
# Completed Layer3Run7
# Completed Layer4Run0
# [Worker 1019185] Finished job Layer1Run15 at 03:37:13 (1.9 min, rc=0)
# [Worker 1019185] Starting job Layer4Run4 at 03:37:13
# Completed Layer1Run15
# [Worker 1019156] Finished job Layer0Run14 at 03:37:14 (1.9 min, rc=0)
# [Worker 1019156] Starting job Layer4Run5 at 03:37:14
# Completed Layer0Run14
# [Worker 1019200] Finished job Layer2Run14 at 03:37:15 (1.6 min, rc=0)
# [Worker 1019200] Starting job Layer4Run6 at 03:37:15
# Completed Layer2Run14
# [Worker 1019186] Finished job Layer1Run16 at 03:37:19 (2.0 min, rc=0)
# [Worker 1019186] Starting job Layer4Run7 at 03:37:19
# Completed Layer1Run16
# [Worker 1019184] Finished job Layer4Run1 at 03:37:20 (0.2 min, rc=0)
# [Worker 1019184] Starting job Layer4Run8 at 03:37:20
# Completed Layer4Run1
# [Worker 1019172] Finished job Layer2Run15 at 03:37:21 (1.7 min, rc=0)
# [Worker 1019172] Starting job Layer4Run9 at 03:37:21
# Completed Layer2Run15
# [Worker 1019150] Finished job Layer3Run8 at 03:37:23 (0.9 min, rc=0)
# [Worker 1019150] Starting job Layer4Run10 at 03:37:23
# Completed Layer3Run8
# [Worker 1019157] Finished job Layer0Run15 at 03:37:24 (2.0 min, rc=0)
# [Worker 1019157] Starting job Layer4Run11 at 03:37:24
# Completed Layer0Run15
# [Worker 1019170] Finished job Layer3Run9 at 03:37:29 (1.0 min, rc=0)
