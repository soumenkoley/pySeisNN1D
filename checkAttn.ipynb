# %%
# script for estimnating the attenuation between two points 
# one on the surface and one underground
# can be applied to real seismic field in layered or homogeneous medium
# and pure body wave or Rayleigh wave field in homogeneous medium
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
from scipy.integrate import quad, tplquad, dblquad
import scipy.constants as const
from scipy.special import spherical_jn
from scipy.special import jv

from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from modules import createDB
from modules import NNGeometryN
from modules import NNGeometryNN
from modules import gfLoader
from modules import simDisp
from modules import NNCompute
from modules import NNPP
from modules import plotUtils

def main():

    # load the config file
    configFile="/home/koley/CavityResults/SphAttnTutorialConfig/configParseAttnRingLayered.ini"
    config = configLoader.load_config(configFile)
    # load all cavities
    allCavities = configLoader.loadCavities('/home/koley/CavityResults/SphAttnTutorialConfig/SingleSphCavity.ini')
    validateInputs.validateInputs(config)
    
    #splitAll = createDB.createFinalInputs(config)

    #print(f"Prepared {splitAll.shape[0]} total runs")
    print(f"Cores available: {config.cpuCoresQseis}")

    #results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    
    print("Database generation complete")
    
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay

    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody

    # flag for wavefield simulation
    ifFullField = config.ifFullField

    saveHV = config.saveHV

    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    rhoAir = config.rhoAir # density of air
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    lambdaFrac = config.lambdaFrac # fraction
    lambdaRes = config.lambdaRes; #must be greater than 4
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used
    maxRec = config.maxRec # same value of number of receivers that qseis can handle in one go check qsglobal.h
    xCenter = config.xCenter; yCenter = config.yCenter
    xMin = xCenter-config.xExtent; xMax = xCenter+config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = yCenter-config.yExtent; yMax = yCenter+config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")


    itmAC = config.itmAC; itmAB = config.itmAB; etmCA = config.etmCA; etmBA = config.etmBA

    print('itmAC = ' + str(itmAC[0]) + ', ' + str(itmAC[1]) + ', ' + str(itmAC[2]))
    # make itmAC[2] negative, because in the configfile it is positive
    itmACUse = itmAC.copy(); itmACUse[2] = -np.abs(itmACUse[2])
    itmABUse = itmAB.copy(); itmABUse[2] = -np.abs(itmABUse[2])
    etmCAUse = etmCA.copy(); etmCAUse[2] = -np.abs(etmCAUse[2])
    etmBAUse = etmBA.copy(); etmBAUse[2] = -np.abs(etmBAUse[2])
    # just add one test-mass location, rather than all
    itmAll = np.vstack((itmACUse,))
    nTM = len(itmAll[:,0])
    G = const.G
    
    # some other inputs for simDisp
    maxRec = config.maxRec; # same value of number of receivers that qseis can handle in one go check qsglobal.h
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations
    nRea = 1000
    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH
    # flag if NN is computed directly without writing the displacemnet field
    onFlyNN = config.onFlyNN 

    # number of CPUs to be used for displacement and NN simulation
    nCPUDisp = config.cpuCoresDisp
    computeStrategy = config.computeStrategy

    # frequency axis to be used by simDisp  
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    #splitAllNew, tVecN = gfLoader.assembleQseisRuns(splitAll, fInpPath, components, outPath=None, fIndices=idxFreq, minVel=100.0)
    splitAllNew = np.load(os.path.join(fInpPath,'splitAllNew.npy'))
     
    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    zList = np.array((0.0, 250.0))
    # generate the two points between which CC will be computed
    gridX = np.array((0.0,))
    gridY = np.array((0.0,))
    # prepare containers
    dispSurfAllRea = np.zeros((nFreq,3))
    dispDepthAllRea = np.zeros((nFreq,3))
    attnZObs = np.zeros((nFreq,3), dtype=np.float64)
    attnXObs = np.zeros((nFreq,3), dtype=np.float64)
    attnYObs = np.zeros((nFreq,3), dtype=np.float64)
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq, eP = 1/3, eS = 2/3)       
        else:
            metaBody=None
        
        if(ifBody):
            dispTempSurf = simDisp.computeFullBodyDisp_parallel(zList[0], gridX, gridY, nSrc, freqOut, vp[0], vs[0], metaBody,
                                 n_workers=nCPUDisp)
            dispTempDepth = simDisp.computeFullBodyDisp_parallel(-zList[1], gridX, gridY, nSrc, freqOut, vp[0], vs[0], metaBody,
                                 n_workers=nCPUDisp)
        elif(ifRay):
            dispTempSurf = simDisp.computeRayleighDisp(zList[0], gridX, gridY, nSrc, freqOut, azSrc,
                                                    srcMeta["phiV"], srcMeta["ampV"], vR, vp[0], vs[0])
            dispTempDepth = simDisp.computeRayleighDisp(-zList[1], gridX, gridY, nSrc, freqOut, azSrc,
                                                    srcMeta["phiV"], srcMeta["ampV"], vR, vp[0], vs[0])
        else:
            # fullfield case
            dispTempSurf, _, _, shmPathsSurf = simDisp.computeFullDispF(zList[0], gridX, gridY, itmAC, xSrc, ySrc, azSrc, srcMeta,idxFreq, freqOut, outDispPath,
                         splitAllNew, xMaxGF, fInpPath, nCPU=nCPUDisp, nChunk=20000, computeStrategy=computeStrategy,
                         saveHV=False, reduceNN=onFlyNN, nnMode=None, nnMeta=None)
            dispTempDepth, _, _, shmPathsDepth = simDisp.computeFullDispF(zList[1], gridX, gridY, itmAC, xSrc, ySrc, azSrc, srcMeta,idxFreq, freqOut, outDispPath,
                         splitAllNew, xMaxGF, fInpPath, nCPU=nCPUDisp, nChunk=20000, computeStrategy=computeStrategy,
                         saveHV=False, reduceNN=onFlyNN, nnMode=None, nnMeta=None)

        dispSurfAllRea += (np.abs(dispTempSurf[:,0,:]))**2
        dispDepthAllRea += (np.abs(dispTempDepth[:,0,:]))**2

        if(ifFullField):
            del dispTempSurf
            simDisp.cleanup_sharedmem(shmPathsSurf)
            del dispTempDepth
            simDisp.cleanup_sharedmem(shmPathsDepth)
    
    # now get the attenuation
    attnSim = np.sqrt(dispSurfAllRea/dispDepthAllRea)

   # load Terziet Attenuation
    terzAttn = loadmat(os.path.join(config.siteASDPath,'attnModel.mat'))
    for i in range(0,3):
        attnXObs[:,i] = np.interp(freqOut,terzAttn['attnE'][:,0],terzAttn['attnE'][:,i+1])
        attnYObs[:,i] = np.interp(freqOut,terzAttn['attnN'][:,0],terzAttn['attnN'][:,i+1])
        attnZObs[:,i] = np.interp(freqOut,terzAttn['attnZ'][:,0],terzAttn['attnZ'][:,i+1])
    
    # get the theoretical Rayleigh transfer functions to check how it matches when full field
    # for a homogeneous half-space is invoked
    periods = 1/freqOut
    vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    Th, Tz = simDisp.rayleigh_transfer_function(freqOut, vR, vp[0], vs[0], -zList[1])
    # active the plotting routine for consistent fontsizes
    plotUtils.set_plot_style("medium")
    figAttn, axAttn = plotUtils.plotAttn(freqOut, attnSim, attnXObs, attnYObs, attnZObs)
    axAttn[0].plot(freqOut,1/Th,'k',label='Rayleigh wavefield')
    axAttn[1].plot(freqOut,1/Th,'k',label='Rayleigh wavefield')
    axAttn[2].plot(freqOut,1/Tz,'k',label='Rayleigh wavefield')
    axAttn[0].legend(loc='upper right')
    axAttn[1].legend(loc='upper right')
    axAttn[2].legend(loc='upper right')
    
    
if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0.   30.  120.  300. 1000. 5000.]
# Number of points per layer along Z = [ 3  6  3 11 56]
# Spacing in each layer in meters = [10.54852321 15.13199041 52.74261603 63.29113924 70.88607595 79.11392405]
# Qseis Inputs cleaned, parent folder intact.
# Creating all input files ...
# All input files created!
# Prepared 516 total runs
# Cores available: 64
# Preparing to run 516 QSEIS jobs with 64 worker(s)...
# [Worker 1604149] Starting job Layer0Run1 at 17:14:30[Worker 1604148] Starting job Layer0Run0 at 17:14:30[Worker 1604151] Starting job Layer0Run3 at 17:14:30[Worker 1604150] Starting job Layer0Run2 at 17:14:30[Worker 1604152] Starting job Layer0Run4 at 17:14:30
# [Worker 1604153] Starting job Layer0Run5 at 17:14:30
# [Worker 1604154] Starting job Layer0Run6 at 17:14:30[Worker 1604155] Starting job Layer0Run7 at 17:14:30[Worker 1604156] Starting job Layer0Run8 at 17:14:30
# [Worker 1604161] Starting job Layer0Run13 at 17:14:30
# [Worker 1604159] Starting job Layer0Run11 at 17:14:30[Worker 1604157] Starting job Layer0Run9 at 17:14:30[Worker 1604164] Starting job Layer0Run16 at 17:14:30[Worker 1604163] Starting job Layer0Run15 at 17:14:30
# [Worker 1604160] Starting job Layer0Run12 at 17:14:30[Worker 1604162] Starting job Layer0Run14 at 17:14:30[Worker 1604165] Starting job Layer0Run17 at 17:14:30[Worker 1604158] Starting job Layer0Run10 at 17:14:30[Worker 1604167] Starting job Layer0Run19 at 17:14:30[Worker 1604166] Starting job Layer0Run18 at 17:14:30[Worker 1604170] Starting job Layer0Run22 at 17:14:30[Worker 1604171] Starting job Layer0Run23 at 17:14:30[Worker 1604169] Starting job Layer0Run21 at 17:14:30
# [Worker 1604174] Starting job Layer1Run1 at 17:14:30[Worker 1604173] Starting job Layer1Run0 at 17:14:30[Worker 1604175] Starting job Layer1Run2 at 17:14:30[Worker 1604178] Starting job Layer1Run5 at 17:14:30[Worker 1604172] Starting job Layer0Run24 at 17:14:30[Worker 1604176] Starting job Layer1Run3 at 17:14:30[Worker 1604177] Starting job Layer1Run4 at 17:14:30[Worker 1604179] Starting job Layer1Run6 at 17:14:30
# [Worker 1604198] Starting job Layer2Run22 at 17:14:44
# Completed Layer1Run1
# Completed Layer0Run1
# Completed Layer0Run0
# Completed Layer2Run0
# [Worker 1604151] Finished job Layer0Run3 at 17:14:45 (0.3 min, rc=0)
# [Worker 1604151] Starting job Layer2Run23 at 17:14:45
# Completed Layer0Run3
# [Worker 1604176] Finished job Layer1Run3 at 17:14:45 (0.3 min, rc=0)
# [Worker 1604176] Starting job Layer2Run24 at 17:14:45
# [Worker 1604201] Finished job Layer2Run3 at 17:14:46 (0.3 min, rc=0)
# [Worker 1604201] Starting job Layer3Run0 at 17:14:46
# Completed Layer1Run3
# Completed Layer2Run3
# [Worker 1604152] Finished job Layer0Run4 at 17:14:49 (0.3 min, rc=0)
# [Worker 1604152] Starting job Layer3Run1 at 17:14:49
# [Worker 1604177] Finished job Layer1Run4 at 17:14:49 (0.3 min, rc=0)
# [Worker 1604177] Starting job Layer3Run2 at 17:14:49
# Completed Layer0Run4
# Completed Layer1Run4
# [Worker 1604202] Finished job Layer2Run4 at 17:14:49 (0.3 min, rc=0)
# [Worker 1604202] Starting job Layer3Run3 at 17:14:49
# Completed Layer2Run4
# [Worker 1604203] Finished job Layer2Run5 at 17:14:53 (0.4 min, rc=0)
# [Worker 1604203] Starting job Layer3Run4 at 17:14:53
# Completed Layer2Run5
# [Worker 1604178] Finished job Layer1Run5 at 17:14:53 (0.4 min, rc=0)
# [Worker 1604178] Starting job Layer3Run5 at 17:14:53
# [Worker 1604153] Finished job Layer0Run5 at 17:14:53 (0.4 min, rc=0)
# [Worker 1604153] Starting job Layer3Run6 at 17:14:53
# Completed Layer1Run5
# Completed Layer0Run5
# [Worker 1604204] Finished job Layer2Run6 at 17:14:57 (0.4 min, rc=0)
# [Worker 1604204] Starting job Layer3Run7 at 17:14:57
# Completed Layer2Run6
# [Worker 1604154] Finished job Layer0Run6 at 17:14:57 (0.5 min, rc=0)
# [Worker 1604154] Starting job Layer3Run8 at 17:14:57
# Completed Layer0Run6
# [Worker 1604179] Finished job Layer1Run6 at 17:14:57 (0.5 min, rc=0)
# [Worker 1604179] Starting job Layer3Run9 at 17:14:57
# Completed Layer1Run6
# [Worker 1604201] Finished job Layer3Run0 at 17:14:59 (0.2 min, rc=0)
# [Worker 1604201] Starting job Layer3Run10 at 17:14:59
# Completed Layer3Run0
# [Worker 1604205] Finished job Layer2Run7 at 17:15:00 (0.5 min, rc=0)
# [Worker 1604205] Starting job Layer3Run11 at 17:15:00
# Completed Layer2Run7
# [Worker 1604180] Finished job Layer1Run7 at 17:15:01 (0.5 min, rc=0)
# [Worker 1604180] Starting job Layer3Run12 at 17:15:01
# [Worker 1604155] Finished job Layer0Run7 at 17:15:01 (0.5 min, rc=0)
# [Worker 1604155] Starting job Layer3Run13 at 17:15:01
# Completed Layer1Run7
# Completed Layer0Run7
# [Worker 1604177] Finished job Layer3Run2 at 17:15:02 (0.2 min, rc=0)
# [Worker 1604177] Starting job Layer3Run14 at 17:15:02
# [Worker 1604152] Finished job Layer3Run1 at 17:15:02 (0.2 min, rc=0)
# [Worker 1604152] Starting job Layer3Run15 at 17:15:02
# Completed Layer3Run2
# Completed Layer3Run1
# [Worker 1604202] Finished job Layer3Run3 at 17:15:04 (0.2 min, rc=0)
# [Worker 1604202] Starting job Layer3Run16 at 17:15:04
# Completed Layer3Run3
# [Worker 1604206] Finished job Layer2Run8 at 17:15:04 (0.6 min, rc=0)
# [Worker 1604206] Starting job Layer3Run17 at 17:15:04
# Completed Layer2Run8
# [Worker 1604156] Finished job Layer0Run8 at 17:15:04 (0.6 min, rc=0)
# [Worker 1604156] Starting job Layer3Run18 at 17:15:04
# Completed Layer0Run8
# [Worker 1604181] Finished job Layer1Run8 at 17:15:05 (0.6 min, rc=0)
# [Worker 1604181] Starting job Layer3Run19 at 17:15:05
# Completed Layer1Run8
# [Worker 1604157] Finished job Layer0Run9 at 17:15:08 (0.6 min, rc=0)
# [Worker 1604157] Starting job Layer3Run20 at 17:15:08
# [Worker 1604207] Finished job Layer2Run9 at 17:15:08 (0.6 min, rc=0)
# [Worker 1604207] Starting job Layer3Run21 at 17:15:08
# Completed Layer0Run9
# Completed Layer2Run9
# [Worker 1604182] Finished job Layer1Run9 at 17:15:10 (0.7 min, rc=0)
# [Worker 1604182] Starting job Layer3Run22 at 17:15:10
# Completed Layer1Run9
# [Worker 1604203] Finished job Layer3Run4 at 17:15:11 (0.3 min, rc=0)
# [Worker 1604203] Starting job Layer3Run23 at 17:15:11
# Completed Layer3Run4
# [Worker 1604208] Finished job Layer2Run10 at 17:15:11 (0.7 min, rc=0)
# [Worker 1604208] Starting job Layer3Run24 at 17:15:11
# Completed Layer2Run10
# [Worker 1604183] Finished job Layer1Run10 at 17:15:12 (0.7 min, rc=0)
# [Worker 1604183] Starting job Layer4Run0 at 17:15:12
# [Worker 1604158] Finished job Layer0Run10 at 17:15:12 (0.7 min, rc=0)
# [Worker 1604158] Starting job Layer4Run1 at 17:15:12
# Completed Layer1Run10
# Completed Layer0Run10
# [Worker 1604178] Finished job Layer3Run5 at 17:15:16 (0.4 min, rc=0)
# [Worker 1604178] Starting job Layer4Run2 at 17:15:16
# [Worker 1604159] Finished job Layer0Run11 at 17:15:16 (0.8 min, rc=0)
# [Worker 1604159] Starting job Layer4Run3 at 17:15:16
# Completed Layer3Run5
# Completed Layer0Run11
# [Worker 1604209] Finished job Layer2Run11 at 17:15:16 (0.8 min, rc=0)
# [Worker 1604209] Starting job Layer4Run4 at 17:15:16
# Completed Layer2Run11
# [Worker 1604184] Finished job Layer1Run11 at 17:15:17 (0.8 min, rc=0)
# [Worker 1604184] Starting job Layer4Run5 at 17:15:17
# Completed Layer1Run11
# [Worker 1604183] Finished job Layer4Run0 at 17:15:17 (0.1 min, rc=0)
# [Worker 1604183] Starting job Layer4Run6 at 17:15:17
# Completed Layer4Run0
# [Worker 1604158] Finished job Layer4Run1 at 17:15:18 (0.1 min, rc=0)
# [Worker 1604158] Starting job Layer4Run7 at 17:15:18
# Completed Layer4Run1
# [Worker 1604210] Finished job Layer2Run12 at 17:15:19 (0.8 min, rc=0)
# [Worker 1604210] Starting job Layer4Run8 at 17:15:19
# [Worker 1604153] Finished job Layer3Run6 at 17:15:19 (0.4 min, rc=0)
# [Worker 1604153] Starting job Layer4Run9 at 17:15:19
# Completed Layer2Run12
# Completed Layer3Run6
# [Worker 1604160] Finished job Layer0Run12 at 17:15:19 (0.8 min, rc=0)
# [Worker 1604160] Starting job Layer4Run10 at 17:15:19
# Completed Layer0Run12
# [Worker 1604185] Finished job Layer1Run12 at 17:15:21 (0.8 min, rc=0)
# [Worker 1604185] Starting job Layer4Run11 at 17:15:21
# Completed Layer1Run12
# [Worker 1604161] Finished job Layer0Run13 at 17:15:24 (0.9 min, rc=0)
# [Worker 1604161] Starting job Layer4Run12 at 17:15:24
# Completed Layer0Run13
# [Worker 1604178] Finished job Layer4Run2 at 17:15:24 (0.1 min, rc=0)
# [Worker 1604178] Starting job Layer4Run13 at 17:15:24
# [Worker 1604211] Finished job Layer2Run13 at 17:15:24 (0.9 min, rc=0)
# [Worker 1604211] Starting job Layer4Run14 at 17:15:24
# [Worker 1604186] Finished job Layer1Run13 at 17:15:24 (0.9 min, rc=0)
# [Worker 1604186] Starting job Layer4Run15 at 17:15:24
# Completed Layer4Run2
# Completed Layer2Run13
# Completed Layer1Run13
# [Worker 1604204] Finished job Layer3Run7 at 17:15:26 (0.5 min, rc=0)
# [Worker 1604204] Starting job Layer4Run16 at 17:15:26
# Completed Layer3Run7
# [Worker 1604162] Finished job Layer0Run14 at 17:15:27 (0.9 min, rc=0)
# [Worker 1604162] Starting job Layer4Run17 at 17:15:27
# [Worker 1604159] Finished job Layer4Run3 at 17:15:27 (0.2 min, rc=0)
# [Worker 1604159] Starting job Layer5Run0 at 17:15:27
# Completed Layer0Run14
# Completed Layer4Run3
# [Worker 1604187] Finished job Layer1Run14 at 17:15:28 (1.0 min, rc=0)
# [Worker 1604187] Starting job Layer5Run1 at 17:15:28
# Completed Layer1Run14
# [Worker 1604209] Finished job Layer4Run4 at 17:15:29 (0.2 min, rc=0)
# [Worker 1604209] Starting job Layer5Run2 at 17:15:29
# Completed Layer4Run4
# [Worker 1604154] Finished job Layer3Run8 at 17:15:30 (0.5 min, rc=0)
# [Worker 1604154] Starting job Layer5Run3 at 17:15:30
# Completed Layer3Run8
# [Worker 1604163] Finished job Layer0Run15 at 17:15:31 (1.0 min, rc=0)
# [Worker 1604163] Starting job Layer5Run4 at 17:15:31
# Completed Layer0Run15
# [Worker 1604159] Finished job Layer5Run0 at 17:15:32 (0.1 min, rc=0)
# [Worker 1604159] Starting job Layer5Run5 at 17:15:32
# Completed Layer5Run0
# [Worker 1604188] Finished job Layer1Run15 at 17:15:32 (1.0 min, rc=0)
# [Worker 1604188] Starting job Layer5Run6 at 17:15:32
# Completed Layer1Run15
# [Worker 1604184] Finished job Layer4Run5 at 17:15:33 (0.3 min, rc=0)
# [Worker 1604184] Starting job Layer5Run7 at 17:15:33
# Completed Layer4Run5
# [Worker 1604187] Finished job Layer5Run1 at 17:15:33 (0.1 min, rc=0)
# [Worker 1604187] Starting job Layer5Run8 at 17:15:33
# Completed Layer5Run1
# [Worker 1604172] Finished job Layer0Run24 at 17:15:34 (1.1 min, rc=0)
# [Worker 1604172] Starting job Layer5Run9 at 17:15:34
# Completed Layer0Run24
# [Worker 1604179] Finished job Layer3Run9 at 17:15:35 (0.6 min, rc=0)
# [Worker 1604179] Starting job Layer5Run10 at 17:15:35
# [Worker 1604164] Finished job Layer0Run16 at 17:15:35 (1.1 min, rc=0)
# [Worker 1604164] Starting job Layer5Run11 at 17:15:35
# [Worker 1604197] Finished job Layer1Run24 at 17:15:35 (1.1 min, rc=0)
# [Worker 1604197] Starting job Layer5Run12 at 17:15:35
# Completed Layer3Run9
# Completed Layer0Run16
# Completed Layer1Run24
# [Worker 1604183] Finished job Layer4Run6 at 17:15:36 (0.3 min, rc=0)
# [Worker 1604183] Starting job Layer5Run13 at 17:15:36
# Completed Layer4Run6
# [Worker 1604189] Finished job Layer1Run16 at 17:15:37 (1.1 min, rc=0)
# [Worker 1604189] Starting job Layer5Run14 at 17:15:37
# [Worker 1604209] Finished job Layer5Run2 at 17:15:37 (0.1 min, rc=0)
# [Worker 1604209] Starting job Layer5Run15 at 17:15:37
# Completed Layer1Run16
# Completed Layer5Run2
# [Worker 1604158] Finished job Layer4Run7 at 17:15:39 (0.4 min, rc=0)
# [Worker 1604158] Starting job Layer5Run16 at 17:15:39
# [Worker 1604165] Finished job Layer0Run17 at 17:15:39 (1.2 min, rc=0)
# [Worker 1604165] Starting job Layer5Run17 at 17:15:39
# Completed Layer4Run7
# Completed Layer0Run17
# [Worker 1604190] Finished job Layer1Run17 at 17:15:40 (1.2 min, rc=0)
# [Worker 1604190] Starting job Layer6Run0 at 17:15:40
# Completed Layer1Run17
# [Worker 1604201] Finished job Layer3Run10 at 17:15:40 (0.7 min, rc=0)
# [Worker 1604201] Starting job Layer6Run1 at 17:15:40
# Completed Layer3Run10
# [Worker 1604154] Finished job Layer5Run3 at 17:15:41 (0.2 min, rc=0)
# [Worker 1604154] Starting job Layer6Run2 at 17:15:41
# Completed Layer5Run3
# [Worker 1604200] Finished job Layer2Run14 at 17:15:41 (1.0 min, rc=0)
# [Worker 1604200] Starting job Layer6Run3 at 17:15:41
# Completed Layer2Run14
# [Worker 1604210] Finished job Layer4Run8 at 17:15:42 (0.4 min, rc=0)
# [Worker 1604210] Starting job Layer6Run4 at 17:15:42
# Completed Layer4Run8
# [Worker 1604166] Finished job Layer0Run18 at 17:15:43 (1.2 min, rc=0)
# [Worker 1604166] Starting job Layer6Run5 at 17:15:43
# Completed Layer0Run18
# [Worker 1604191] Finished job Layer1Run18 at 17:15:44 (1.2 min, rc=0)
# [Worker 1604191] Starting job Layer6Run6 at 17:15:44
# [Worker 1604205] Finished job Layer3Run11 at 17:15:44 (0.7 min, rc=0)
# [Worker 1604205] Starting job Layer6Run7 at 17:15:44
# Completed Layer1Run18
# Completed Layer3Run11
# [Worker 1604190] Finished job Layer6Run0 at 17:15:44 (0.1 min, rc=0)
# [Worker 1604190] Starting job Layer6Run8 at 17:15:44
# [Worker 1604163] Finished job Layer5Run4 at 17:15:45 (0.2 min, rc=0)
# [Worker 1604163] Starting job Layer6Run9 at 17:15:45
# Completed Layer6Run0
# Completed Layer5Run4
# [Worker 1604153] Finished job Layer4Run9 at 17:15:45 (0.4 min, rc=0)
# [Worker 1604153] Starting job Layer6Run10 at 17:15:45
# Completed Layer4Run9
# [Worker 1604201] Finished job Layer6Run1 at 17:15:46 (0.1 min, rc=0)
# [Worker 1604201] Starting job Layer6Run11 at 17:15:46
# [Worker 1604192] Finished job Layer1Run19 at 17:15:46 (1.3 min, rc=0)
# [Worker 1604192] Starting job Layer6Run12 at 17:15:46
# Completed Layer6Run1
# Completed Layer1Run19
# [Worker 1604199] Finished job Layer2Run15 at 17:15:46 (1.0 min, rc=0)
# [Worker 1604199] Starting job Layer6Run13 at 17:15:46
# Completed Layer2Run15
# [Worker 1604159] Finished job Layer5Run5 at 17:15:47 (0.3 min, rc=0)
# [Worker 1604159] Starting job Layer6Run14 at 17:15:47
# Completed Layer5Run5
# [Worker 1604167] Finished job Layer0Run19 at 17:15:47 (1.3 min, rc=0)
# [Worker 1604167] Starting job Layer6Run15 at 17:15:47
# Completed Layer0Run19
# [Worker 1604160] Finished job Layer4Run10 at 17:15:48 (0.5 min, rc=0)
# [Worker 1604160] Starting job Layer6Run16 at 17:15:48
# Completed Layer4Run10
# [Worker 1604150] Finished job Layer2Run16 at 17:15:48 (1.1 min, rc=0)
# [Worker 1604150] Starting job Layer6Run17 at 17:15:48
# Completed Layer2Run16
# [Worker 1604154] Finished job Layer6Run2 at 17:15:49 (0.1 min, rc=0)
# [Worker 1604154] Starting job Layer7Run0 at 17:15:49
# [Worker 1604180] Finished job Layer3Run12 at 17:15:49 (0.8 min, rc=0)
# [Worker 1604180] Starting job Layer7Run1 at 17:15:49
# Completed Layer6Run2
# Completed Layer3Run12
# [Worker 1604176] Finished job Layer2Run24 at 17:15:49 (1.1 min, rc=0)
# [Worker 1604176] Starting job Layer7Run2 at 17:15:49
# Completed Layer2Run24
# [Worker 1604188] Finished job Layer5Run6 at 17:15:50 (0.3 min, rc=0)
# [Worker 1604188] Starting job Layer7Run3 at 17:15:50
# [Worker 1604168] Finished job Layer0Run20 at 17:15:50 (1.3 min, rc=0)
# [Worker 1604168] Starting job Layer7Run4 at 17:15:50
# Completed Layer5Run6
# Completed Layer0Run20
# [Worker 1604193] Finished job Layer1Run20 at 17:15:51 (1.3 min, rc=0)
# [Worker 1604193] Starting job Layer7Run5 at 17:15:51
# Completed Layer1Run20
# [Worker 1604200] Finished job Layer6Run3 at 17:15:51 (0.2 min, rc=0)
# [Worker 1604200] Starting job Layer7Run6 at 17:15:51
# Completed Layer6Run3
# [Worker 1604185] Finished job Layer4Run11 at 17:15:52 (0.5 min, rc=0)
# [Worker 1604185] Starting job Layer7Run7 at 17:15:52
# Completed Layer4Run11
# [Worker 1604175] Finished job Layer2Run17 at 17:15:53 (1.2 min, rc=0)
# [Worker 1604175] Starting job Layer7Run8 at 17:15:53
# [Worker 1604184] Finished job Layer5Run7 at 17:15:53 (0.3 min, rc=0)
# [Worker 1604184] Starting job Layer7Run9 at 17:15:53
# Completed Layer2Run17
# Completed Layer5Run7
# [Worker 1604154] Finished job Layer7Run0 at 17:15:53 (0.1 min, rc=0)
# [Worker 1604154] Starting job Layer7Run10 at 17:15:53
# Completed Layer7Run0
# [Worker 1604155] Finished job Layer3Run13 at 17:15:54 (0.9 min, rc=0)
# [Worker 1604155] Starting job Layer7Run11 at 17:15:54
# Completed Layer3Run13
# [Worker 1604180] Finished job Layer7Run1 at 17:15:54 (0.1 min, rc=0)
# [Worker 1604180] Starting job Layer7Run12 at 17:15:54
# Completed Layer7Run1
# [Worker 1604169] Finished job Layer0Run21 at 17:15:55 (1.4 min, rc=0)
# [Worker 1604169] Starting job Layer7Run13 at 17:15:55
# [Worker 1604194] Finished job Layer1Run21 at 17:15:55 (1.4 min, rc=0)
# [Worker 1604194] Starting job Layer7Run14 at 17:15:55
# Completed Layer0Run21
# Completed Layer1Run21
# [Worker 1604210] Finished job Layer6Run4 at 17:15:55 (0.2 min, rc=0)
# [Worker 1604210] Starting job Layer7Run15 at 17:15:55
# Completed Layer6Run4
# [Worker 1604173] Finished job Layer2Run18 at 17:15:56 (1.2 min, rc=0)
# [Worker 1604173] Starting job Layer7Run16 at 17:15:56
# Completed Layer2Run18
# [Worker 1604187] Finished job Layer5Run8 at 17:15:57 (0.4 min, rc=0)
# [Worker 1604187] Starting job Layer7Run17 at 17:15:57
# [Worker 1604176] Finished job Layer7Run2 at 17:15:57 (0.1 min, rc=0)
# [Worker 1604176] Starting job Layer8Run0 at 17:15:57
# Completed Layer5Run8
# Completed Layer7Run2
# [Worker 1604161] Finished job Layer4Run12 at 17:15:57 (0.6 min, rc=0)
# [Worker 1604161] Starting job Layer8Run1 at 17:15:57
# Completed Layer4Run12
# [Worker 1604170] Finished job Layer0Run22 at 17:15:58 (1.5 min, rc=0)
# [Worker 1604170] Starting job Layer8Run2 at 17:15:58
# [Worker 1604177] Finished job Layer3Run14 at 17:15:58 (0.9 min, rc=0)
# [Worker 1604177] Starting job Layer8Run3 at 17:15:58
# Completed Layer0Run22
# Completed Layer3Run14
# [Worker 1604166] Finished job Layer6Run5 at 17:15:59 (0.3 min, rc=0)
# [Worker 1604166] Starting job Layer8Run4 at 17:15:59
# Completed Layer6Run5
# [Worker 1604174] Finished job Layer2Run19 at 17:16:00 (1.3 min, rc=0)
# [Worker 1604174] Starting job Layer8Run5 at 17:16:00
# Completed Layer2Run19
# [Worker 1604172] Finished job Layer5Run9 at 17:16:00 (0.4 min, rc=0)
# [Worker 1604172] Starting job Layer8Run6 at 17:16:00
# Completed Layer5Run9
# [Worker 1604188] Finished job Layer7Run3 at 17:16:01 (0.2 min, rc=0)
# [Worker 1604188] Starting job Layer8Run7 at 17:16:01
# Completed Layer7Run3
# [Worker 1604195] Finished job Layer1Run22 at 17:16:01 (1.5 min, rc=0)
# [Worker 1604195] Starting job Layer8Run8 at 17:16:01
# [Worker 1604178] Finished job Layer4Run13 at 17:16:01 (0.6 min, rc=0)
# [Worker 1604178] Starting job Layer8Run9 at 17:16:01
# Completed Layer1Run22
# Completed Layer4Run13
# [Worker 1604152] Finished job Layer3Run15 at 17:16:02 (1.0 min, rc=0)
# [Worker 1604152] Starting job Layer8Run10 at 17:16:02
# Completed Layer3Run15
# [Worker 1604191] Finished job Layer6Run6 at 17:16:02 (0.3 min, rc=0)
# [Worker 1604191] Starting job Layer8Run11 at 17:16:02
# [Worker 1604176] Finished job Layer8Run0 at 17:16:02 (0.1 min, rc=0)
# [Worker 1604176] Starting job Layer8Run12 at 17:16:02
# Completed Layer6Run6
# Completed Layer8Run0
# [Worker 1604196] Finished job Layer1Run23 at 17:16:02 (1.5 min, rc=0)
# [Worker 1604196] Starting job Layer8Run13 at 17:16:02
# Completed Layer1Run23
# [Worker 1604171] Finished job Layer0Run23 at 17:16:02 (1.5 min, rc=0)
# [Worker 1604171] Starting job Layer8Run14 at 17:16:02
# Completed Layer0Run23
# [Worker 1604161] Finished job Layer8Run1 at 17:16:03 (0.1 min, rc=0)
# [Worker 1604161] Starting job Layer8Run15 at 17:16:03
# Completed Layer8Run1
# [Worker 1604211] Finished job Layer4Run14 at 17:16:03 (0.7 min, rc=0)
# [Worker 1604211] Starting job Layer8Run16 at 17:16:03
# [Worker 1604168] Finished job Layer7Run4 at 17:16:03 (0.2 min, rc=0)
# [Worker 1604168] Starting job Layer8Run17 at 17:16:03
# Completed Layer4Run14
# Completed Layer7Run4
# [Worker 1604149] Finished job Layer2Run20 at 17:16:03 (1.3 min, rc=0)
# [Worker 1604149] Starting job Layer9Run0 at 17:16:03
# [Worker 1604179] Finished job Layer5Run10 at 17:16:04 (0.5 min, rc=0)
# [Worker 1604179] Starting job Layer9Run1 at 17:16:04
# Completed Layer2Run20
# Completed Layer5Run10
# [Worker 1604205] Finished job Layer6Run7 at 17:16:05 (0.3 min, rc=0)
# [Worker 1604205] Starting job Layer9Run2 at 17:16:05
# Completed Layer6Run7
# [Worker 1604164] Finished job Layer5Run11 at 17:16:06 (0.5 min, rc=0)
# [Worker 1604164] Starting job Layer9Run3 at 17:16:06
# [Worker 1604170] Finished job Layer8Run2 at 17:16:06 (0.1 min, rc=0)
# [Worker 1604170] Starting job Layer9Run4 at 17:16:06
# Completed Layer5Run11
# Completed Layer8Run2
# [Worker 1604202] Finished job Layer3Run16 at 17:16:06 (1.0 min, rc=0)
# [Worker 1604202] Starting job Layer9Run5 at 17:16:06
# Completed Layer3Run16
# [Worker 1604186] Finished job Layer4Run15 at 17:16:06 (0.7 min, rc=0)
# [Worker 1604186] Starting job Layer9Run6 at 17:16:06
# [Worker 1604193] Finished job Layer7Run5 at 17:16:06 (0.3 min, rc=0)
# [Worker 1604193] Starting job Layer9Run7 at 17:16:06
# Completed Layer4Run15
# Completed Layer7Run5
# [Worker 1604190] Finished job Layer6Run8 at 17:16:07 (0.4 min, rc=0)
# [Worker 1604190] Starting job Layer9Run8 at 17:16:07
# [Worker 1604206] Finished job Layer3Run17 at 17:16:07 (1.1 min, rc=0)
# [Worker 1604206] Starting job Layer9Run9 at 17:16:07
# [Worker 1604162] Finished job Layer4Run17 at 17:16:08 (0.7 min, rc=0)
# [Worker 1604162] Starting job Layer9Run10 at 17:16:08
# Completed Layer6Run8
# Completed Layer3Run17
# Completed Layer4Run17
# [Worker 1604148] Finished job Layer2Run21 at 17:16:08 (1.4 min, rc=0)
# [Worker 1604148] Starting job Layer9Run11 at 17:16:08
# Completed Layer2Run21
# [Worker 1604149] Finished job Layer9Run0 at 17:16:08 (0.1 min, rc=0)
# [Worker 1604149] Starting job Layer9Run12 at 17:16:08
# [Worker 1604177] Finished job Layer8Run3 at 17:16:08 (0.2 min, rc=0)
# [Worker 1604177] Starting job Layer9Run13 at 17:16:08
# [Worker 1604197] Finished job Layer5Run12 at 17:16:08 (0.6 min, rc=0)
# [Worker 1604197] Starting job Layer9Run14 at 17:16:08
# Completed Layer9Run0
# Completed Layer8Run3
# Completed Layer5Run12
# [Worker 1604179] Finished job Layer9Run1 at 17:16:08 (0.1 min, rc=0)
# [Worker 1604179] Starting job Layer9Run15 at 17:16:08
# Completed Layer9Run1
# [Worker 1604200] Finished job Layer7Run6 at 17:16:09 (0.3 min, rc=0)
# [Worker 1604200] Starting job Layer9Run16 at 17:16:09
# Completed Layer7Run6
# [Worker 1604163] Finished job Layer6Run9 at 17:16:10 (0.4 min, rc=0)
# [Worker 1604163] Starting job Layer9Run17 at 17:16:10
# [Worker 1604204] Finished job Layer4Run16 at 17:16:10 (0.7 min, rc=0)
# [Worker 1604204] Starting job Layer10Run0 at 17:16:10
# Completed Layer6Run9
# Completed Layer4Run16
# [Worker 1604198] Finished job Layer2Run22 at 17:16:11 (1.5 min, rc=0)
# [Worker 1604198] Starting job Layer10Run1 at 17:16:11
# [Worker 1604183] Finished job Layer5Run13 at 17:16:12 (0.6 min, rc=0)
# [Worker 1604183] Starting job Layer10Run2 at 17:16:12
# [Worker 1604185] Finished job Layer7Run7 at 17:16:12 (0.3 min, rc=0)
# [Worker 1604185] Starting job Layer10Run3 at 17:16:12
# Completed Layer2Run22
# Completed Layer5Run13
# Completed Layer7Run7
# [Worker 1604166] Finished job Layer8Run4 at 17:16:12 (0.2 min, rc=0)
# [Worker 1604166] Starting job Layer10Run4 at 17:16:12
# Completed Layer8Run4
# [Worker 1604205] Finished job Layer9Run2 at 17:16:12 (0.1 min, rc=0)
# [Worker 1604205] Starting job Layer11Run0 at 17:16:12
# Completed Layer9Run2
# [Worker 1604153] Finished job Layer6Run10 at 17:16:13 (0.5 min, rc=0)
# [Worker 1604153] Starting job Layer11Run1 at 17:16:13
# Completed Layer6Run10
# [Worker 1604208] Finished job Layer3Run24 at 17:16:13 (1.0 min, rc=0)
# [Worker 1604208] Starting job Layer11Run2 at 17:16:13
# Completed Layer3Run24
# [Worker 1604174] Finished job Layer8Run5 at 17:16:15 (0.3 min, rc=0)
# [Worker 1604174] Starting job Layer11Run3 at 17:16:15
# [Worker 1604156] Finished job Layer3Run18 at 17:16:15 (1.2 min, rc=0)
# [Worker 1604156] Starting job Layer11Run4 at 17:16:15
# Completed Layer8Run5
# Completed Layer3Run18
# [Worker 1604164] Finished job Layer9Run3 at 17:16:15 (0.2 min, rc=0)
# [Worker 1604164] Starting job Layer12Run0 at 17:16:15
# Completed Layer9Run3
# [Worker 1604189] Finished job Layer5Run14 at 17:16:16 (0.6 min, rc=0)
# [Worker 1604189] Starting job Layer12Run1 at 17:16:16
# [Worker 1604201] Finished job Layer6Run11 at 17:16:16 (0.5 min, rc=0)
# [Worker 1604201] Starting job Layer12Run2 at 17:16:16
# [Worker 1604175] Finished job Layer7Run8 at 17:16:16 (0.4 min, rc=0)
# [Worker 1604175] Starting job Layer12Run3 at 17:16:16
# Completed Layer5Run14
# Completed Layer6Run11
# Completed Layer7Run8
# [Worker 1604151] Finished job Layer2Run23 at 17:16:17 (1.5 min, rc=0)
# [Worker 1604151] Starting job Layer12Run4 at 17:16:17
# Completed Layer2Run23
# [Worker 1604181] Finished job Layer3Run19 at 17:16:18 (1.2 min, rc=0)
# [Worker 1604181] Starting job Layer13Run0 at 17:16:18
# Completed Layer3Run19
# [Worker 1604170] Finished job Layer9Run4 at 17:16:18 (0.2 min, rc=0)
# [Worker 1604170] Starting job Layer13Run1 at 17:16:18
# Completed Layer9Run4
# [Worker 1604204] Finished job Layer10Run0 at 17:16:18 (0.1 min, rc=0)
# [Worker 1604204] Starting job Layer13Run2 at 17:16:18
# [Worker 1604172] Finished job Layer8Run6 at 17:16:18 (0.3 min, rc=0)
# [Worker 1604172] Starting job Layer13Run3 at 17:16:18
# Completed Layer10Run0
# Completed Layer8Run6
# [Worker 1604209] Finished job Layer5Run15 at 17:16:19 (0.7 min, rc=0)
# [Worker 1604209] Starting job Layer13Run4 at 17:16:19
# Completed Layer5Run15
# [Worker 1604184] Finished job Layer7Run9 at 17:16:19 (0.4 min, rc=0)
# [Worker 1604184] Starting job Layer14Run0 at 17:16:19
# Completed Layer7Run9
# [Worker 1604192] Finished job Layer6Run12 at 17:16:19 (0.6 min, rc=0)
# [Worker 1604192] Starting job Layer14Run1 at 17:16:19
# [Worker 1604165] Finished job Layer5Run17 at 17:16:19 (0.7 min, rc=0)
# [Worker 1604165] Starting job Layer14Run2 at 17:16:19
# Completed Layer6Run12
# Completed Layer5Run17
# [Worker 1604205] Finished job Layer11Run0 at 17:16:20 (0.1 min, rc=0)
# [Worker 1604205] Starting job Layer14Run3 at 17:16:20
# Completed Layer11Run0
# [Worker 1604202] Finished job Layer9Run5 at 17:16:20 (0.2 min, rc=0)
# [Worker 1604176] Finished job Layer8Run12 at 17:16:34 (0.5 min, rc=0)
# [Worker 1604176] Starting job Layer22Run0 at 17:16:34
# Completed Layer3Run22
# Completed Layer8Run12
# [Worker 1604154] Finished job Layer15Run1 at 17:16:34 (0.2 min, rc=0)
# [Worker 1604154] Starting job Layer22Run1 at 17:16:34
# Completed Layer15Run1
# [Worker 1604162] Finished job Layer9Run10 at 17:16:35 (0.5 min, rc=0)
# [Worker 1604162] Starting job Layer22Run2 at 17:16:35
# [Worker 1604207] Finished job Layer19Run0 at 17:16:35 (0.1 min, rc=0)
# [Worker 1604207] Starting job Layer22Run3 at 17:16:35
# [Worker 1604183] Finished job Layer10Run2 at 17:16:35 (0.4 min, rc=0)
# [Worker 1604183] Starting job Layer22Run4 at 17:16:35
# Completed Layer9Run10
# Completed Layer19Run0
# Completed Layer10Run2
# [Worker 1604210] Finished job Layer7Run15 at 17:16:35 (0.7 min, rc=0)
# [Worker 1604210] Starting job Layer23Run0 at 17:16:35
# Completed Layer7Run15
# [Worker 1604148] Finished job Layer9Run11 at 17:16:36 (0.5 min, rc=0)
# [Worker 1604148] Starting job Layer23Run1 at 17:16:36
# [Worker 1604186] Finished job Layer16Run1 at 17:16:36 (0.2 min, rc=0)
# [Worker 1604186] Starting job Layer23Run2 at 17:16:36
# Completed Layer9Run11
# Completed Layer16Run1
# [Worker 1604208] Finished job Layer11Run2 at 17:16:37 (0.4 min, rc=0)
# [Worker 1604208] Starting job Layer23Run3 at 17:16:37
# Completed Layer11Run2
# [Worker 1604187] Finished job Layer7Run17 at 17:16:37 (0.7 min, rc=0)
# [Worker 1604187] Starting job Layer23Run4 at 17:16:37
# [Worker 1604189] Finished job Layer20Run0 at 17:16:37 (0.1 min, rc=0)
# [Worker 1604189] Starting job Layer24Run0 at 17:16:37
# Completed Layer7Run17
# Completed Layer20Run0
# [Worker 1604196] Finished job Layer8Run13 at 17:16:38 (0.6 min, rc=0)
# [Worker 1604196] Starting job Layer24Run1 at 17:16:38
# [Worker 1604193] Finished job Layer17Run1 at 17:16:38 (0.2 min, rc=0)
# [Worker 1604193] Starting job Layer24Run2 at 17:16:38
# Completed Layer8Run13
# Completed Layer17Run1
# [Worker 1604160] Finished job Layer21Run0 at 17:16:38 (0.1 min, rc=0)
# [Worker 1604160] Starting job Layer24Run3 at 17:16:38
# Completed Layer21Run0
# [Worker 1604165] Finished job Layer14Run2 at 17:16:39 (0.3 min, rc=0)
# [Worker 1604165] Starting job Layer24Run4 at 17:16:39
# Completed Layer14Run2
# [Worker 1604203] Finished job Layer3Run23 at 17:16:39 (1.5 min, rc=0)
# [Worker 1604203] Starting job Layer25Run0 at 17:16:39
# [Worker 1604149] Finished job Layer9Run12 at 17:16:39 (0.5 min, rc=0)
# [Worker 1604149] Starting job Layer25Run1 at 17:16:39
# [Worker 1604201] Finished job Layer12Run2 at 17:16:39 (0.4 min, rc=0)
# [Worker 1604201] Starting job Layer25Run2 at 17:16:39
# [Worker 1604180] Finished job Layer18Run1 at 17:16:39 (0.2 min, rc=0)
# [Worker 1604180] Starting job Layer25Run3 at 17:16:39
# Completed Layer3Run23
# Completed Layer9Run12
# Completed Layer12Run2
# Completed Layer18Run1
# [Worker 1604173] Finished job Layer7Run16 at 17:16:40 (0.7 min, rc=0)
# [Worker 1604173] Starting job Layer25Run4 at 17:16:40
# Completed Layer7Run16
# [Worker 1604176] Finished job Layer22Run0 at 17:16:40 (0.1 min, rc=0)
# [Worker 1604176] Starting job Layer26Run0 at 17:16:40
# Completed Layer22Run0
# [Worker 1604204] Finished job Layer13Run2 at 17:16:40 (0.4 min, rc=0)
# [Worker 1604204] Starting job Layer26Run1 at 17:16:40
# [Worker 1604150] Finished job Layer19Run1 at 17:16:41 (0.2 min, rc=0)
# [Worker 1604150] Starting job Layer26Run2 at 17:16:41
# Completed Layer13Run2
# Completed Layer19Run1
# [Worker 1604171] Finished job Layer8Run14 at 17:16:41 (0.6 min, rc=0)
# [Worker 1604171] Starting job Layer26Run3 at 17:16:41
# Completed Layer8Run14
# [Worker 1604210] Finished job Layer23Run0 at 17:16:41 (0.1 min, rc=0)
# [Worker 1604210] Starting job Layer27Run0 at 17:16:41
# Completed Layer23Run0
# [Worker 1604199] Finished job Layer15Run2 at 17:16:42 (0.3 min, rc=0)
# [Worker 1604199] Starting job Layer27Run1 at 17:16:42
# Completed Layer15Run2
# [Worker 1604177] Finished job Layer9Run13 at 17:16:42 (0.6 min, rc=0)
# [Worker 1604177] Starting job Layer27Run2 at 17:16:42
# Completed Layer9Run13
# [Worker 1604155] Finished job Layer16Run2 at 17:16:43 (0.3 min, rc=0)
# [Worker 1604155] Starting job Layer27Run3 at 17:16:43
# [Worker 1604189] Finished job Layer24Run0 at 17:16:43 (0.1 min, rc=0)
# [Worker 1604189] Starting job Layer28Run0 at 17:16:43
# Completed Layer16Run2
# Completed Layer24Run0
# [Worker 1604168] Finished job Layer8Run17 at 17:16:43 (0.7 min, rc=0)
# [Worker 1604168] Starting job Layer28Run1 at 17:16:43
# Completed Layer8Run17
# [Worker 1604185] Finished job Layer10Run3 at 17:16:43 (0.5 min, rc=0)
# [Worker 1604185] Starting job Layer28Run2 at 17:16:43
# [Worker 1604161] Finished job Layer8Run15 at 17:16:43 (0.7 min, rc=0)
# [Worker 1604161] Starting job Layer28Run3 at 17:16:43
# [Worker 1604191] Finished job Layer20Run1 at 17:16:43 (0.2 min, rc=0)
# [Worker 1604191] Starting job Layer29Run0 at 17:16:43
# Completed Layer10Run3
# Completed Layer8Run15
# Completed Layer20Run1
# [Worker 1604170] Finished job Layer21Run1 at 17:16:44 (0.2 min, rc=0)
# [Worker 1604170] Starting job Layer29Run1 at 17:16:44
# Completed Layer21Run1
# [Worker 1604157] Finished job Layer17Run2 at 17:16:44 (0.3 min, rc=0)
# [Worker 1604157] Starting job Layer29Run2 at 17:16:44
# [Worker 1604197] Finished job Layer9Run14 at 17:16:44 (0.6 min, rc=0)
# [Worker 1604197] Starting job Layer29Run3 at 17:16:44
# Completed Layer17Run2
# Completed Layer9Run14
# [Worker 1604203] Finished job Layer25Run0 at 17:16:45 (0.1 min, rc=0)
# [Worker 1604203] Starting job Layer30Run0 at 17:16:45
# Completed Layer25Run0
# [Worker 1604190] Finished job Layer18Run2 at 17:16:45 (0.3 min, rc=0)
# [Worker 1604190] Starting job Layer30Run1 at 17:16:45
# Completed Layer18Run2
# [Worker 1604205] Finished job Layer14Run3 at 17:16:46 (0.4 min, rc=0)
# [Worker 1604205] Starting job Layer30Run2 at 17:16:46
# [Worker 1604154] Finished job Layer22Run1 at 17:16:46 (0.2 min, rc=0)
# [Worker 1604154] Starting job Layer30Run3 at 17:16:46
# Completed Layer14Run3
# Completed Layer22Run1
# [Worker 1604174] Finished job Layer11Run3 at 17:16:46 (0.5 min, rc=0)
# [Worker 1604174] Starting job Layer31Run0 at 17:16:46
# [Worker 1604179] Finished job Layer9Run15 at 17:16:46 (0.6 min, rc=0)
# [Worker 1604179] Starting job Layer31Run1 at 17:16:46
# Completed Layer11Run3
# Completed Layer9Run15
# [Worker 1604211] Finished job Layer8Run16 at 17:16:46 (0.7 min, rc=0)
# [Worker 1604211] Starting job Layer31Run2 at 17:16:46
# [Worker 1604175] Finished job Layer12Run3 at 17:16:46 (0.5 min, rc=0)
# [Worker 1604175] Starting job Layer31Run3 at 17:16:46
# Completed Layer8Run16
# Completed Layer12Run3
# [Worker 1604152] Finished job Layer19Run2 at 17:16:47 (0.3 min, rc=0)
# [Worker 1604152] Starting job Layer32Run0 at 17:16:47
# Completed Layer19Run2
# [Worker 1604148] Finished job Layer23Run1 at 17:16:47 (0.2 min, rc=0)
# [Worker 1604148] Starting job Layer32Run1 at 17:16:47
# Completed Layer23Run1
# [Worker 1604163] Finished job Layer9Run17 at 17:16:48 (0.6 min, rc=0)
# [Worker 1604163] Starting job Layer32Run2 at 17:16:48
# [Worker 1604172] Finished job Layer13Run3 at 17:16:48 (0.5 min, rc=0)
# [Worker 1604172] Starting job Layer32Run3 at 17:16:48
# [Worker 1604176] Finished job Layer26Run0 at 17:16:48 (0.1 min, rc=0)
# [Worker 1604176] Starting job Layer33Run0 at 17:16:48
# Completed Layer9Run17
# Completed Layer13Run3
# Completed Layer26Run0
# [Worker 1604166] Finished job Layer10Run4 at 17:16:48 (0.6 min, rc=0)
# [Worker 1604166] Starting job Layer33Run1 at 17:16:48
# Completed Layer10Run4
# [Worker 1604164] Finished job Layer15Run3 at 17:16:49 (0.4 min, rc=0)[Worker 1604159] Finished job Layer20Run2 at 17:16:49 (0.3 min, rc=0)
#
# [Worker 1604164] Starting job Layer33Run2 at 17:16:49[Worker 1604159] Starting job Layer33Run3 at 17:16:49
#
# Completed Layer15Run3
# Completed Layer20Run2
# [Worker 1604210] Finished job Layer27Run0 at 17:16:49 (0.1 min, rc=0)
# [Worker 1604210] Starting job Layer34Run0 at 17:16:49
# [Worker 1604196] Finished job Layer24Run1 at 17:16:49 (0.2 min, rc=0)
# [Worker 1604196] Starting job Layer34Run1 at 17:16:49
# Completed Layer27Run0
# Completed Layer24Run1
# [Worker 1604194] Finished job Layer21Run2 at 17:16:50 (0.3 min, rc=0)
# [Worker 1604194] Starting job Layer34Run2 at 17:16:50
# Completed Layer21Run2
# [Worker 1604149] Finished job Layer25Run1 at 17:16:50 (0.2 min, rc=0)
# [Worker 1604149] Starting job Layer34Run3 at 17:16:50
# [Worker 1604181] Finished job Layer16Run3 at 17:16:50 (0.4 min, rc=0)
# [Worker 1604181] Starting job Layer35Run0 at 17:16:50
# Completed Layer25Run1
# Completed Layer16Run3
# [Worker 1604156] Finished job Layer11Run4 at 17:16:50 (0.6 min, rc=0)
# [Worker 1604156] Starting job Layer35Run1 at 17:16:50
# [Worker 1604189] Finished job Layer28Run0 at 17:16:51 (0.1 min, rc=0)
# [Worker 1604189] Starting job Layer35Run2 at 17:16:51
# Completed Layer11Run4
# Completed Layer28Run0
# [Worker 1604200] Finished job Layer9Run16 at 17:16:51 (0.7 min, rc=0)
# [Worker 1604200] Starting job Layer35Run3 at 17:16:51
# Completed Layer9Run16
# [Worker 1604178] Finished job Layer17Run3 at 17:16:51 (0.4 min, rc=0)
# [Worker 1604178] Starting job Layer36Run0 at 17:16:51
# [Worker 1604191] Finished job Layer29Run0 at 17:16:51 (0.1 min, rc=0)
# [Worker 1604191] Starting job Layer36Run1 at 17:16:51
# Completed Layer17Run3
# Completed Layer29Run0
# [Worker 1604151] Finished job Layer12Run4 at 17:16:51 (0.6 min, rc=0)
# [Worker 1604151] Starting job Layer36Run2 at 17:16:51
# Completed Layer12Run4
# [Worker 1604153] Finished job Layer18Run3 at 17:16:51 (0.4 min, rc=0)
# [Worker 1604153] Starting job Layer36Run3 at 17:16:51
# Completed Layer18Run3
# [Worker 1604162] Finished job Layer22Run2 at 17:16:52 (0.3 min, rc=0)
# [Worker 1604162] Starting job Layer37Run0 at 17:16:52
# Completed Layer22Run2
# [Worker 1604202] Finished job Layer14Run4 at 17:16:52 (0.5 min, rc=0)
# [Worker 1604202] Starting job Layer37Run1 at 17:16:52
# [Worker 1604158] Finished job Layer19Run3 at 17:16:52 (0.4 min, rc=0)
# [Worker 1604158] Starting job Layer37Run2 at 17:16:52
# Completed Layer14Run4
# Completed Layer19Run3
# [Worker 1604203] Finished job Layer30Run0 at 17:16:53 (0.1 min, rc=0)
# [Worker 1604203] Starting job Layer37Run3 at 17:16:53
# Completed Layer30Run0
# [Worker 1604186] Finished job Layer23Run2 at 17:16:53 (0.3 min, rc=0)
# [Worker 1604186] Starting job Layer38Run0 at 17:16:53
# Completed Layer23Run2
# [Worker 1604209] Finished job Layer13Run4 at 17:16:53 (0.6 min, rc=0)
# [Worker 1604209] Starting job Layer38Run1 at 17:16:53
# [Worker 1604174] Finished job Layer31Run0 at 17:16:54 (0.1 min, rc=0)
# [Worker 1604174] Starting job Layer38Run2 at 17:16:54
# Completed Layer13Run4
# Completed Layer31Run0
# [Worker 1604152] Finished job Layer32Run0 at 17:16:54 (0.1 min, rc=0)
# [Worker 1604152] Starting job Layer38Run3 at 17:16:54
# Completed Layer32Run0
# [Worker 1604206] Finished job Layer20Run3 at 17:16:54 (0.4 min, rc=0)
# [Worker 1604206] Starting job Layer39Run0 at 17:16:54
# Completed Layer20Run3
# [Worker 1604195] Finished job Layer15Run4 at 17:16:55 (0.5 min, rc=0)
# [Worker 1604195] Starting job Layer39Run1 at 17:16:55
# [Worker 1604193] Finished job Layer24Run2 at 17:16:55 (0.3 min, rc=0)
# [Worker 1604193] Starting job Layer39Run2 at 17:16:55
# Completed Layer15Run4
# Completed Layer24Run2
# [Worker 1604188] Finished job Layer21Run3 at 17:16:55 (0.4 min, rc=0)
# [Worker 1604188] Starting job Layer39Run3 at 17:16:55
# Completed Layer21Run3
# [Worker 1604176] Finished job Layer33Run0 at 17:16:56 (0.1 min, rc=0)
# [Worker 1604176] Starting job Layer40Run0 at 17:16:56
# [Worker 1604201] Finished job Layer25Run2 at 17:16:56 (0.3 min, rc=0)
# [Worker 1604201] Starting job Layer40Run1 at 17:16:56
# Completed Layer33Run0
# Completed Layer25Run2
# [Worker 1604204] Finished job Layer26Run1 at 17:16:56 (0.3 min, rc=0)
# [Worker 1604204] Starting job Layer40Run2 at 17:16:56
# [Worker 1604210] Finished job Layer34Run0 at 17:16:56 (0.1 min, rc=0)
# [Worker 1604210] Starting job Layer40Run3 at 17:16:56
# Completed Layer26Run1
# Completed Layer34Run0
# [Worker 1604167] Finished job Layer18Run4 at 17:16:57 (0.5 min, rc=0)
# [Worker 1604167] Starting job Layer41Run0 at 17:16:57
# [Worker 1604207] Finished job Layer22Run3 at 17:16:57 (0.4 min, rc=0)
# [Worker 1604207] Starting job Layer41Run1 at 17:16:57
# Completed Layer18Run4
# Completed Layer22Run3
# [Worker 1604184] Finished job Layer16Run4 at 17:16:57 (0.5 min, rc=0)
# [Worker 1604184] Starting job Layer41Run2 at 17:16:57
# [Worker 1604198] Finished job Layer17Run4 at 17:16:57 (0.5 min, rc=0)
# [Worker 1604198] Starting job Layer41Run3 at 17:16:57
# Completed Layer16Run4
# Completed Layer17Run4
# [Worker 1604181] Finished job Layer35Run0 at 17:16:58 (0.1 min, rc=0)
# [Worker 1604181] Starting job Layer42Run0 at 17:16:58
# [Worker 1604199] Finished job Layer27Run1 at 17:16:58 (0.3 min, rc=0)
# [Worker 1604199] Starting job Layer42Run1 at 17:16:58
# Completed Layer35Run0
# Completed Layer27Run1
# [Worker 1604208] Finished job Layer23Run3 at 17:16:58 (0.4 min, rc=0)
# [Worker 1604208] Starting job Layer42Run2 at 17:16:58
# [Worker 1604178] Finished job Layer36Run0 at 17:16:58 (0.1 min, rc=0)
# [Worker 1604178] Starting job Layer42Run3 at 17:16:58
# [Worker 1604169] Finished job Layer19Run4 at 17:16:58 (0.5 min, rc=0)
# [Worker 1604169] Starting job Layer43Run0 at 17:16:58
# Completed Layer23Run3
# Completed Layer36Run0
# Completed Layer19Run4
# [Worker 1604168] Finished job Layer28Run1 at 17:16:59 (0.3 min, rc=0)
# [Worker 1604168] Starting job Layer43Run1 at 17:16:59
# Completed Layer28Run1
# [Worker 1604170] Finished job Layer29Run1 at 17:16:59 (0.3 min, rc=0)
# [Worker 1604170] Starting job Layer43Run2 at 17:16:59
# [Worker 1604162] Finished job Layer37Run0 at 17:16:59 (0.1 min, rc=0)
# [Worker 1604162] Starting job Layer43Run3 at 17:16:59
# Completed Layer29Run1
# Completed Layer37Run0
# [Worker 1604192] Finished job Layer20Run4 at 17:17:00 (0.5 min, rc=0)
# [Worker 1604192] Starting job Layer44Run0 at 17:17:00
# Completed Layer20Run4
# [Worker 1604160] Finished job Layer24Run3 at 17:17:00 (0.4 min, rc=0)
# [Worker 1604160] Starting job Layer44Run1 at 17:17:00
# [Worker 1604186] Finished job Layer38Run0 at 17:17:00 (0.1 min, rc=0)
# [Worker 1604186] Starting job Layer44Run2 at 17:17:00
# Completed Layer24Run3
# Completed Layer38Run0
# [Worker 1604179] Finished job Layer31Run1 at 17:17:01 (0.2 min, rc=0)[Worker 1604190] Finished job Layer30Run1 at 17:17:01 (0.3 min, rc=0)
#
# [Worker 1604179] Starting job Layer44Run3 at 17:17:01[Worker 1604190] Starting job Layer45Run0 at 17:17:01
#
# Completed Layer31Run1
# Completed Layer30Run1
# [Worker 1604180] Finished job Layer25Run3 at 17:17:01 (0.4 min, rc=0)
# [Worker 1604180] Starting job Layer45Run1 at 17:17:01
# Completed Layer25Run3
# [Worker 1604206] Finished job Layer39Run0 at 17:17:02 (0.1 min, rc=0)
# [Worker 1604206] Starting job Layer45Run2 at 17:17:02
# Completed Layer39Run0
# [Worker 1604182] Finished job Layer21Run4 at 17:17:02 (0.5 min, rc=0)
# [Worker 1604182] Starting job Layer45Run3 at 17:17:02
# ...
# Doing realization = 334
# Doing realization = 335
# Doing realization = 336
# Doing realization = 337
# Doing realization = 338
# Doing realization = 339
# Doing realization = 340
# Doing realization = 341
# Doing realization = 342
# Doing realization = 343
# Doing realization = 344
# Doing realization = 345
# Doing realization = 346
# Doing realization = 347
# Doing realization = 348
# Doing realization = 349
# Doing realization = 350
# Doing realization = 351
# Doing realization = 352
# Doing realization = 353
# Doing realization = 354
# Doing realization = 355
# Doing realization = 356
# Doing realization = 357
# Doing realization = 358
# Doing realization = 359
# Doing realization = 360
# Doing realization = 361
# Doing realization = 362
# Doing realization = 363
# Doing realization = 364
# Doing realization = 365
# Doing realization = 366
# Doing realization = 367
# Doing realization = 368
# Doing realization = 369
# Doing realization = 370
# Doing realization = 371
# Doing realization = 372
# Doing realization = 373
# Doing realization = 374
# Doing realization = 375
# Doing realization = 376
# Doing realization = 377
# Doing realization = 378
# Doing realization = 379
# Doing realization = 380
# Doing realization = 381
# Doing realization = 382
# Doing realization = 383
# Doing realization = 384
# Doing realization = 385
# Doing realization = 386
# Doing realization = 387
# Doing realization = 388
# Doing realization = 389
# Doing realization = 390
# Doing realization = 391
# Doing realization = 392
# Doing realization = 393
