# %%
# script for checking the attenuation between any two points at different depths but same (x,y)
# script written to test the accuracy of simpDisp module, tested with latest version
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
import scipy.constants as const
from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from  modules import createDB
from modules import gfLoader
from modules import simDisp
from modules import plotUtils

def main():

    # load the config file
    configFile="/home/koley/Results/TutorialConfig/configParseLayerFullAttn.ini"
    config = configLoader.load_config(configFile)
    validateInputs.validateInputs(config)
    
    # generating the Green's function for all depths might not be necessary, but recommended
    # in case you want to redo the computation for another depth
    #splitAll = createDB.createFinalInputs(config)

    #print(f"Prepared {splitAll.shape[0]} total runs")
    #print(f"Cores available: {config.cpuCoresQseis}")

    #results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    #print("Database generation complete")
    
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay

    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody

    # flag for wavefield simulation
    ifFullField = config.ifFullField

    saveHV = config.saveHV

    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used

    xMin = -config.xExtent; xMax = config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = -config.yExtent; yMax = config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")
        
    G = const.G
    # some other inputs for simDisp
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations
    nRea = 1000

    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH

    # loky_sharedmem only strategy retained from legacy version
    computeStrategy = config.computeStrategy

     # flag for whether computation saves the displacement field and then computes NN
    # or its on the fly, if False saves the field in /dev/shm
    onFlyNN = config.onFlyNN

    # frequency axis to be used by simDisp
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    # add this for the new frequency domain solutions
    if(ifFullField):
        #splitAllNew, _ = gfLoader.assembleQseisRuns(splitAll, fInpPath, components, outPath=None, fIndices=idxFreq, minVel=100.0)
        # in case assembleQseisRuns was used before
        splitAllNew = np.load(os.path.join(fInpPath,'splitAllNew.npy'))

    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    zTar = np.array((0.0, 250.0,))
    gridX = np.array((0.0,))
    gridY = np.array((0.0,))

    #recDistAB = np.sqrt((gridX[0]-gridX[1])**2 + (gridY[0]-gridY[1])**2 + (zTar[0]-zTar[1])**2)
    
    # nFreqx3 for the three percentiles
    attnZObs = np.zeros((nFreq,3), dtype=np.float64)
    attnXObs = np.zeros((nFreq,3), dtype=np.float64)
    attnYObs = np.zeros((nFreq,3), dtype=np.float64)
    attnZSim = np.zeros((nFreq,), dtype=np.float64)
    attnXSim = np.zeros((nFreq,), dtype=np.float64)
    attnYSim = np.zeros((nFreq,), dtype=np.float64)
    dispTotalAllReaSurf = np.zeros((nFreq,1,3), dtype=np.float64)
    dispTotalAllReaDepth = np.zeros((nFreq,1,3), dtype=np.float64)
    
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        # in case you want to test a few scenarios of forcing
        #srcMeta["ampV"] *= 0.0
        #ySrc = np.zeros((nSrc,))

        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq)
        else:
            metaBody=None
        
        # simulate the displacement field
        if(ifBody):
            dispTotalSurf = simDisp.computeFullBodyDisp(zTar[0], gridX, gridY, nSrc, freqOut, vp[0], vs[0], metaBody)
            dispTotalDepth = simDisp.computeFullBodyDisp(-zTar[1], gridX, gridY, nSrc, freqOut, vp[0], vs[0], metaBody)
        elif(ifRay):
            dispTotalSurf = simDisp.computeRayleighDisp(zTar[0], gridX, gridY, nSrc, freqOut, azSrc,
                                                srcMeta["phiV"], srcMeta["ampV"], vR, vp[0], vs[0])
            dispTotalDepth = simDisp.computeRayleighDisp(-zTar[1], gridX, gridY, nSrc, freqOut, azSrc,
                                                srcMeta["phiV"], srcMeta["ampV"], vR, vp[0], vs[0])
        else:
            # fullfield case
            dispTotalSurf, outDir, fOut, shmPathsSurf = simDisp.computeFullDispF(zTar[0], gridX, gridY, xSrc, ySrc, azSrc, srcMeta, idxFreq, freqOut,
                     outDispPath, splitAllNew, xMaxGF, fInpPath, nCPU=1, nChunk=20000,
                     computeStrategy=computeStrategy, saveHV=saveHV, reduceNN=onFlyNN,nnMode=None,nnMeta=None)
            dispTotalDepth, outDir, fOut, shmPathsDepth = simDisp.computeFullDispF(zTar[1], gridX, gridY, xSrc, ySrc, azSrc, srcMeta, idxFreq, freqOut,
                     outDispPath, splitAllNew, xMaxGF, fInpPath, nCPU=1, nChunk=20000,
                     computeStrategy=computeStrategy, saveHV=saveHV, reduceNN=onFlyNN,nnMode=None,nnMeta=None)
            

        # populate the rms displacement matrices while looping over realizations
        dispTotalAllReaSurf += (np.abs(dispTotalSurf))**2
        dispTotalAllReaDepth += (np.abs(dispTotalDepth))**2

        # remove the shm paths
        if(ifFullField):
            del dispTotalSurf
            simDisp.cleanup_sharedmem(shmPathsSurf)
            del dispTotalDepth
            simDisp.cleanup_sharedmem(shmPathsDepth)

    dispTotalAllReaSurf = np.sqrt(dispTotalAllReaSurf/nRea)
    dispTotalAllReaDepth = np.sqrt(dispTotalAllReaDepth/nRea)
    
          
    attnXSim += (dispTotalAllReaSurf[:,0,0]/dispTotalAllReaDepth[:,0,0])
    attnYSim += (dispTotalAllReaSurf[:,0,1]/dispTotalAllReaDepth[:,0,1])
    attnZSim += (dispTotalAllReaSurf[:,0,2]/dispTotalAllReaDepth[:,0,2])

    attnSim = np.stack((attnXSim,attnYSim,attnZSim),axis=-1)
    print(np.shape(attnSim))    
    # load Terziet Attenuation
    terzAttn = loadmat(os.path.join(config.siteASDPath,'attnModel.mat'))
    for i in range(0,3):
        attnXObs[:,i] = np.interp(freqOut,terzAttn['attnE'][:,0],terzAttn['attnE'][:,i+1])
        attnYObs[:,i] = np.interp(freqOut,terzAttn['attnN'][:,0],terzAttn['attnN'][:,i+1])
        attnZObs[:,i] = np.interp(freqOut,terzAttn['attnZ'][:,0],terzAttn['attnZ'][:,i+1])
    
    # get the theoretical Rayleigh transfer functions to check how it matches when full field
    # for a homogeneous half-space is invoked
    periods = 1/freqOut
    vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    Th, Tz = simDisp.rayleigh_transfer_function(freqOut, vR, vp[0], vs[0], -zTar[1])
    # active the plotting routine for consistent fontsizes
    plotUtils.set_plot_style(labelsize=16, ticksize=14, legendsize=12, titlesize=16)
    figAttn, axAttn = plotUtils.plotAttn(freqOut, attnSim, attnXObs, attnYObs, attnZObs)
    #axAttn[0].plot(freqOut,1/Th,'r',label='Rayleigh wavefield')
    #axAttn[1].plot(freqOut,1/Th,'r',label='Rayleigh wavefield')
    #axAttn[2].plot(freqOut,1/Tz,'r',label='Rayleigh wavefield')

    saveDict = {"attnSimBigRing":attnSim,"freqOut":freqOut,"Th":Th,"Tz":Tz}
    saveName = config.outDispPathRea + 'InternalAttn.mat'
    savemat(saveName,saveDict)

if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0.   30.  120.  300. 1000. 5000.]
# Number of points per layer along Z = [ 3  6  3 11 56]
# Spacing in each layer in meters = [10.54852321 15.13199041 52.74261603 63.29113924 70.88607595 79.11392405]
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# [Worker 2259454] Starting job Layer7Run4 at 23:48:45
# Completed Layer3Run2
# [Worker 2259453] Finished job Layer3Run1 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259453] Starting job Layer7Run5 at 23:48:45
# [Worker 2259442] Finished job Layer2Run2 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259442] Starting job Layer7Run6 at 23:48:45
# Completed Layer3Run1
# Completed Layer2Run2
# [Worker 2259418] Finished job Layer0Run2 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259418] Starting job Layer7Run7 at 23:48:45
# [Worker 2259417] Finished job Layer0Run1 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259417] Starting job Layer8Run0 at 23:48:45
# [Worker 2259428] Finished job Layer1Run0 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259428] Starting job Layer8Run1 at 23:48:45
# [Worker 2259416] Finished job Layer0Run0 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259416] Starting job Layer8Run2 at 23:48:45
# [Worker 2259455] Finished job Layer3Run3 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259455] Starting job Layer8Run3 at 23:48:45
# [Worker 2259441] Finished job Layer2Run1 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259441] Starting job Layer8Run4 at 23:48:45
# Completed Layer0Run2
# Completed Layer0Run1
# Completed Layer1Run0
# Completed Layer0Run0
# Completed Layer3Run3
# Completed Layer2Run1
# [Worker 2259429] Finished job Layer1Run1 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259429] Starting job Layer8Run5 at 23:48:45
# [Worker 2259430] Finished job Layer1Run2 at 23:48:45 (0.2 min, rc=0)
# [Worker 2259430] Starting job Layer8Run6 at 23:48:45
# Completed Layer1Run1
# Completed Layer1Run2
# [Worker 2259443] Finished job Layer2Run3 at 23:48:46 (0.2 min, rc=0)
# [Worker 2259443] Starting job Layer8Run7 at 23:48:46
# Completed Layer2Run3
# [Worker 2259431] Finished job Layer1Run3 at 23:48:46 (0.2 min, rc=0)
# [Worker 2259431] Starting job Layer9Run0 at 23:48:46
# [Worker 2259419] Finished job Layer0Run3 at 23:48:46 (0.2 min, rc=0)
# [Worker 2259419] Starting job Layer9Run1 at 23:48:46
# [Worker 2259468] Finished job Layer4Run4 at 23:48:46 (0.2 min, rc=0)
# [Worker 2259468] Starting job Layer9Run2 at 23:48:46
# Completed Layer1Run3
# Completed Layer0Run3
# Completed Layer4Run4
# [Worker 2259476] Finished job Layer5Run4 at 23:48:47 (0.2 min, rc=0)
# [Worker 2259476] Starting job Layer9Run3 at 23:48:47
# [Worker 2259473] Finished job Layer6Run2 at 23:48:47 (0.2 min, rc=0)
# [Worker 2259473] Starting job Layer9Run4 at 23:48:47
# Completed Layer5Run4
# Completed Layer6Run2
# [Worker 2259456] Finished job Layer3Run4 at 23:48:48 (0.3 min, rc=0)
# [Worker 2259456] Starting job Layer9Run5 at 23:48:48
# Completed Layer3Run4
# [Worker 2259475] Finished job Layer7Run0 at 23:48:49 (0.1 min, rc=0)
# [Worker 2259475] Starting job Layer9Run6 at 23:48:49
# Completed Layer7Run0
# [Worker 2259420] Finished job Layer0Run4 at 23:48:49 (0.3 min, rc=0)
# [Worker 2259420] Starting job Layer9Run7 at 23:48:49
# [Worker 2259469] Finished job Layer4Run5 at 23:48:49 (0.3 min, rc=0)
# [Worker 2259469] Starting job Layer10Run0 at 23:48:49
# Completed Layer0Run4
# Completed Layer4Run5
# [Worker 2259444] Finished job Layer2Run4 at 23:48:49 (0.3 min, rc=0)
# [Worker 2259444] Starting job Layer10Run1 at 23:48:49
# [Worker 2259465] Finished job Layer6Run3 at 23:48:49 (0.2 min, rc=0)
# [Worker 2259465] Starting job Layer10Run2 at 23:48:49
# Completed Layer2Run4
# Completed Layer6Run3
# [Worker 2259432] Finished job Layer1Run4 at 23:48:50 (0.3 min, rc=0)
# [Worker 2259432] Starting job Layer11Run0 at 23:48:50
# [Worker 2259477] Finished job Layer5Run5 at 23:48:50 (0.3 min, rc=0)
# [Worker 2259477] Starting job Layer11Run1 at 23:48:50
# Completed Layer1Run4
# Completed Layer5Run5
# [Worker 2259467] Finished job Layer7Run1 at 23:48:50 (0.1 min, rc=0)
# [Worker 2259467] Starting job Layer11Run2 at 23:48:50
# [Worker 2259417] Finished job Layer8Run0 at 23:48:50 (0.1 min, rc=0)
# [Worker 2259417] Starting job Layer12Run0 at 23:48:50
# Completed Layer7Run1
# Completed Layer8Run0
# [Worker 2259428] Finished job Layer8Run1 at 23:48:51 (0.1 min, rc=0)
# [Worker 2259428] Starting job Layer12Run1 at 23:48:51
# Completed Layer8Run1
# [Worker 2259431] Finished job Layer9Run0 at 23:48:51 (0.1 min, rc=0)
# [Worker 2259431] Starting job Layer12Run2 at 23:48:51
# Completed Layer9Run0
# [Worker 2259479] Finished job Layer5Run7 at 23:48:51 (0.3 min, rc=0)
# [Worker 2259479] Starting job Layer13Run0 at 23:48:51
# [Worker 2259457] Finished job Layer3Run5 at 23:48:51 (0.3 min, rc=0)
# [Worker 2259457] Starting job Layer13Run1 at 23:48:51
# [Worker 2259471] Finished job Layer4Run7 at 23:48:52 (0.3 min, rc=0)
# [Worker 2259471] Starting job Layer13Run2 at 23:48:52
# Completed Layer5Run7
# Completed Layer3Run5
# Completed Layer4Run7
# [Worker 2259419] Finished job Layer9Run1 at 23:48:52 (0.1 min, rc=0)
# [Worker 2259419] Starting job Layer14Run0 at 23:48:52
# [Worker 2259445] Finished job Layer2Run5 at 23:48:52 (0.3 min, rc=0)
# [Worker 2259445] Starting job Layer14Run1 at 23:48:52
# [Worker 2259470] Finished job Layer4Run6 at 23:48:52 (0.3 min, rc=0)
# [Worker 2259470] Starting job Layer15Run0 at 23:48:52
# Completed Layer9Run1
# Completed Layer2Run5
# Completed Layer4Run6
# [Worker 2259478] Finished job Layer5Run6 at 23:48:53 (0.3 min, rc=0)
# [Worker 2259478] Starting job Layer15Run1 at 23:48:53
# [Worker 2259421] Finished job Layer0Run5 at 23:48:53 (0.3 min, rc=0)
# [Worker 2259421] Starting job Layer16Run0 at 23:48:53
# Completed Layer5Run6
# Completed Layer0Run5
# [Worker 2259452] Finished job Layer7Run2 at 23:48:53 (0.1 min, rc=0)
# [Worker 2259462] Finished job Layer71Run1 at 23:49:25 (0.2 min, rc=0)
# [Worker 2259470] Finished job Layer73Run1 at 23:49:25 (0.2 min, rc=0)
# Completed Layer71Run1
# Completed Layer73Run1
# [Worker 2259424] Finished job Layer76Run1 at 23:49:25 (0.2 min, rc=0)
# Completed Layer76Run1
# [Worker 2259428] Finished job Layer74Run1 at 23:49:26 (0.2 min, rc=0)
# [Worker 2259458] Finished job Layer78Run1 at 23:49:26 (0.2 min, rc=0)
# Completed Layer74Run1
# Completed Layer78Run1
# [Worker 2259421] Finished job Layer77Run1 at 23:49:26 (0.2 min, rc=0)
# Completed Layer77Run1
# [Worker 2259469] Finished job Layer79Run1 at 23:49:27 (0.2 min, rc=0)
# [Worker 2259433] Finished job Layer72Run1 at 23:49:27 (0.2 min, rc=0)
# Completed Layer79Run1
# Completed Layer72Run1
# [Worker 2259451] Finished job Layer75Run1 at 23:49:27 (0.2 min, rc=0)
# [Worker 2259438] Finished job Layer82Run1 at 23:49:27 (0.2 min, rc=0)
# Completed Layer75Run1
# Completed Layer82Run1
# [Worker 2259478] Finished job Layer80Run1 at 23:49:28 (0.2 min, rc=0)
# Completed Layer80Run1
# [Worker 2259436] Finished job Layer81Run1 at 23:49:29 (0.2 min, rc=0)
# Completed Layer81Run1
# All QSEIS runs finished.
# Database generation complete
# [0.    0.025 0.05  0.075 0.1  ]
# [assembleQseisRuns] saved | z=0.000 m |
# [assembleQseisRuns] saved | z=10.549 m |
# [assembleQseisRuns] saved | z=21.097 m |
# [assembleQseisRuns] saved | z=30.000 m |
# [assembleQseisRuns] saved | z=45.132 m |
# [assembleQseisRuns] saved | z=60.264 m |
# [assembleQseisRuns] saved | z=75.396 m |
# [assembleQseisRuns] saved | z=90.528 m |
# [assembleQseisRuns] saved | z=105.660 m |
# [assembleQseisRuns] saved | z=120.000 m |
# [assembleQseisRuns] saved | z=172.743 m |
# [assembleQseisRuns] saved | z=225.485 m |
# [assembleQseisRuns] saved | z=278.228 m |
# [assembleQseisRuns] saved | z=300.000 m |
# [assembleQseisRuns] saved | z=363.291 m |
# [assembleQseisRuns] saved | z=426.582 m |
# [assembleQseisRuns] saved | z=489.873 m |
# ...
# Doing realization = 352
# Doing realization = 353
# Doing realization = 354
# Doing realization = 355
# Doing realization = 356
# Doing realization = 357
# Doing realization = 358
# Doing realization = 359
# Doing realization = 360
# Doing realization = 361
# Doing realization = 362
# Doing realization = 363
# Doing realization = 364
# Doing realization = 365
# Doing realization = 366
# Doing realization = 367
# Doing realization = 368
# Doing realization = 369
# Doing realization = 370
# Doing realization = 371
# Doing realization = 372
# Doing realization = 373
# Doing realization = 374
# Doing realization = 375
# Doing realization = 376
# Doing realization = 377
# Doing realization = 378
# Doing realization = 379
# Doing realization = 380
# Doing realization = 381
# Doing realization = 382
# Doing realization = 383
# Doing realization = 384
# Doing realization = 385
# Doing realization = 386
# Doing realization = 387
# Doing realization = 388
# Doing realization = 389
# Doing realization = 390
# Doing realization = 391
# Doing realization = 392
# Doing realization = 393
# Doing realization = 394
# Doing realization = 395
# Doing realization = 396
# Doing realization = 869
# Doing realization = 870
# Doing realization = 871
# Doing realization = 872
# Doing realization = 873
# Doing realization = 874
# Doing realization = 875
# Doing realization = 876
# Doing realization = 877
# Doing realization = 878
# Doing realization = 879
# Doing realization = 880
# Doing realization = 881
# Doing realization = 882
# Doing realization = 883
# Doing realization = 884
# Doing realization = 885
# Doing realization = 886
# Doing realization = 887
# Doing realization = 888
# Doing realization = 889
# Doing realization = 890
# Doing realization = 891
# Doing realization = 892
# Doing realization = 893
# Doing realization = 894
# Doing realization = 895
# Doing realization = 896
# Doing realization = 897
# Doing realization = 898
# Doing realization = 899
# Doing realization = 900
# Doing realization = 901
# Doing realization = 902
# Doing realization = 903
# Doing realization = 904
# Doing realization = 905
# Doing realization = 906
# Doing realization = 907
# Doing realization = 908
# Doing realization = 909
# Doing realization = 910
# Doing realization = 911
# Doing realization = 912
# Doing realization = 913
# Doing realization = 914
# Doing realization = 915
# Doing realization = 916
# Doing realization = 917
# Doing realization = 918
# Doing realization = 919
# Doing realization = 920
# Doing realization = 921
# Doing realization = 922
# Doing realization = 923
# Doing realization = 924
# Doing realization = 925
# Doing realization = 926
# Doing realization = 927
# Doing realization = 928
# Doing realization = 929
# Doing realization = 930
# Doing realization = 931
# Doing realization = 932
# Doing realization = 933
# Doing realization = 934
# Doing realization = 935
# Doing realization = 936
# Doing realization = 937
# Doing realization = 938
# Doing realization = 939
# Doing realization = 940
# Doing realization = 941
# Doing realization = 942
# Doing realization = 943
# Doing realization = 944
# Doing realization = 945
# Doing realization = 946
# Doing realization = 947
# Doing realization = 948
# Doing realization = 949
# Doing realization = 950
# Doing realization = 951
# Doing realization = 952
# Doing realization = 953
# Doing realization = 954
# Doing realization = 955
# Doing realization = 956
# Doing realization = 957
# Doing realization = 958
# Doing realization = 959
# Doing realization = 960
# Doing realization = 961
# Doing realization = 962
# Doing realization = 963
# Doing realization = 964
# Doing realization = 965
# Doing realization = 966
# Doing realization = 967
# Doing realization = 968
# Doing realization = 969
# Doing realization = 970
# Doing realization = 971
# Doing realization = 972
# Doing realization = 973
# Doing realization = 974
# Doing realization = 975
# Doing realization = 976
# Doing realization = 977
# Doing realization = 978
# Doing realization = 979
# Doing realization = 980
# Doing realization = 981
# Doing realization = 982
# Doing realization = 983
# Doing realization = 984
# Doing realization = 985
# Doing realization = 986
# Doing realization = 987
# Doing realization = 988
# Doing realization = 989
# Doing realization = 990
# Doing realization = 991
# Doing realization = 992
# Doing realization = 993
# Doing realization = 994
# Doing realization = 995
# Doing realization = 996
# Doing realization = 997
# Doing realization = 998
# Doing realization = 999
# (60, 3)
# /home/koley/pySeis1DNN/modules/simDisp.py:1635: RuntimeWarning: invalid value encountered in sqrt
#   alpha = k * np.sqrt(1.0 - (vR / vp)**2)
# /home/koley/pySeis1DNN/modules/simDisp.py:1636: RuntimeWarning: invalid value encountered in sqrt
#   beta  = k * np.sqrt(1.0 - (vR / vs)**2)
# /home/koley/pySeis1DNN/modules/simDisp.py:1638: RuntimeWarning: invalid value encountered in divide
#   r = -2j * k * alpha / (k**2 + beta**2 + tiny)   # B/A
