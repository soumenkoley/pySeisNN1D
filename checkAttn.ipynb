# %%
# script for checking the attenuation between any two points at different depths but same (x,y)
# script written to test the accuracy of simpDisp module
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
import scipy.constants as const
from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from  modules import createDB
from modules import simDisp
from modules import plotUtils

def main():

    # load the config file
    configFile="configParseAttnTest.ini"
    config = configLoader.load_config(configFile)
    validateInputs.validateInputs(config)
    
    splitAll = createDB.createFinalInputs(config)

    print(f"Prepared {splitAll.shape[0]} total runs")
    print(f"Cores available: {config.cpuCoresQseis}")

    results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    print("Database generation complete")
    
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay

    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody

    # flag for wavefield simulation
    ifFullField = config.ifFullField

    saveHV = config.saveHV

    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    rhoAir = config.rhoAir # density of air
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    lambdaFrac = config.lambdaFrac # fraction
    lambdaRes = config.lambdaRes; #must be greater than 4
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used
    maxRec = config.maxRec # same value of number of receivers that qseis can handle in one go check qsglobal.h
    
    xMin = -config.xExtent; xMax = config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = -config.yExtent; yMax = config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")
        
    domXYBounds = (xMin,xMax,yMin,yMax)
    cubeC = config.cavityDepth; rCavity = config.cavityRadius
    cubeS = 2*rCavity
    cubeTop = cubeC-cubeS; cubeBot = cubeC+cubeS
    
    G = const.G
    
    # some other inputs for simDisp
    maxRec = config.maxRec; # same value of number of receivers that qseis can handle in one go check qsglobal.h
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # saves the NN and displacement values per realization
    outDispRea = config.outDispPathRea # like "/data/gravwav/koley/OutDispRea/"
    
    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations

    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH

    # number of CPUs to be used for displacement and NN simulation
    nCPUDisp = config.cpuCoresDisp
    nCPUNN = config.cpuCoresNN
    computeStrategy = config.computeStrategy

    # frequency axis to be used by simDisp
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    zTar = np.array((0.0, 250.0,))
    gridX = np.array((0.0,))
    gridY = np.array((0.0,))

    #recDistAB = np.sqrt((gridX[0]-gridX[1])**2 + (gridY[0]-gridY[1])**2 + (zTar[0]-zTar[1])**2)
    
    # nFreqx3 for the three percentiles
    attnZObs = np.zeros((nFreq,3), dtype=np.complex128)
    attnXObs = np.zeros((nFreq,3), dtype=np.complex128)
    attnYObs = np.zeros((nFreq,3), dtype=np.complex128)
    attnZSim = np.zeros((nFreq,), dtype=np.complex128)
    attnXSim = np.zeros((nFreq,), dtype=np.complex128)
    attnYSim = np.zeros((nFreq,), dtype=np.complex128)
    dispTotalAllReaSurf = np.zeros((nFreq,1,3), dtype=np.complex128)
    dispTotalAllReaDepth = np.zeros((nFreq,1,3), dtype=np.complex128)
    
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        #srcMeta["ampV"] *= 0.0
        #ySrc = np.zeros((nSrc,))

        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq)
        else:
            metaBody=None
        
        dispTotalSurf, outDir, fOut = simDisp.computeFullDispN(zTar[0], gridX, gridY, xSrc, ySrc, azSrc, srcMeta, idxFreq, freqOut, fMin, fMax,
                     outDispPath, splitAll, xMaxGF, fInpPath, components, nCPU=1, nChunk=20000, minVel=100.0,
                     computeStrategy=computeStrategy, saveHV=saveHV)
        
        dispTotalDepth, outDir, fOut = simDisp.computeFullDispN(zTar[1], gridX, gridY, xSrc, ySrc, azSrc, srcMeta, idxFreq, freqOut, fMin, fMax,
                     outDispPath, splitAll, xMaxGF, fInpPath, components, nCPU=1, nChunk=20000, minVel=100.0,
                     computeStrategy=computeStrategy, saveHV=saveHV)
        # populate the cross correlation matrices
        
        dispTotalAllReaSurf += (np.abs(dispTotalSurf))**2
        dispTotalAllReaDepth += (np.abs(dispTotalDepth))**2

    dispTotalAllReaSurf = np.sqrt(dispTotalAllReaSurf/nRea)
    dispTotalAllReaDepth = np.sqrt(dispTotalAllReaDepth/nRea)
    
          
    attnXSim += (dispTotalAllReaSurf[:,0,0]/dispTotalAllReaDepth[:,0,0])
    attnYSim += (dispTotalAllReaSurf[:,0,1]/dispTotalAllReaDepth[:,0,1])
    attnZSim += (dispTotalAllReaSurf[:,0,2]/dispTotalAllReaDepth[:,0,2])

    attnSim = np.stack((attnXSim,attnYSim,attnZSim),axis=-1)
    print(np.shape(attnSim))    
    # load Terziet Attenuation
    terzAttn = loadmat(os.path.join(config.siteASDPath,'attnModel.mat'))
    for i in range(0,3):
        attnXObs[:,i] = np.interp(freqOut,terzAttn['attnE'][:,0],terzAttn['attnE'][:,i+1])
        attnYObs[:,i] = np.interp(freqOut,terzAttn['attnN'][:,0],terzAttn['attnN'][:,i+1])
        attnZObs[:,i] = np.interp(freqOut,terzAttn['attnZ'][:,0],terzAttn['attnZ'][:,i+1])
    
    figAttn, axAttn = plotUtils.plotAttn(freqOut, attnSim, attnXObs, attnYObs, attnZObs)

if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0.      9.37   16.03   37.22   48.54   68.5   214.43 5000.  ]
# Number of points per layer along Z = [ 2  1  3  1  1  4 73]
# Spacing in each layer in meters = [ 4.34388186  5.00984617  8.3798768  15.50738397 24.50348437 39.09861048
#  65.45295359]
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# Qseis Inputs cleaned, parent folder intact.
# Creating all input files ...
# All input files created!
# Prepared 382 total runs
# Cores available: 64
# Preparing to run 382 QSEIS jobs with 64 worker(s)...
# [Worker 99590] Starting job Layer0Run0 at 21:42:25[Worker 99591] Starting job Layer0Run1 at 21:42:25[Worker 99592] Starting job Layer0Run2 at 21:42:25[Worker 99593] Starting job Layer0Run3 at 21:42:25[Worker 99594] Starting job Layer0Run4 at 21:42:25[Worker 99598] Starting job Layer0Run8 at 21:42:25[Worker 99595] Starting job Layer0Run5 at 21:42:25[Worker 99596] Starting job Layer0Run6 at 21:42:25
# [Worker 99597] Starting job Layer0Run7 at 21:42:25[Worker 99599] Starting job Layer0Run9 at 21:42:25[Worker 99600] Starting job Layer0Run10 at 21:42:25[Worker 99602] Starting job Layer0Run12 at 21:42:25[Worker 99601] Starting job Layer0Run11 at 21:42:25
# [Worker 99603] Starting job Layer0Run13 at 21:42:25[Worker 99604] Starting job Layer0Run14 at 21:42:25[Worker 99605] Starting job Layer0Run15 at 21:42:25
#
# [Worker 99606] Starting job Layer0Run16 at 21:42:25
# [Worker 99608] Starting job Layer0Run18 at 21:42:25
# [Worker 99607] Starting job Layer0Run17 at 21:42:25[Worker 99612] Starting job Layer0Run22 at 21:42:25
# [Worker 99609] Starting job Layer0Run19 at 21:42:25
#
# [Worker 99611] Starting job Layer0Run21 at 21:42:25[Worker 99613] Starting job Layer0Run23 at 21:42:25[Worker 99610] Starting job Layer0Run20 at 21:42:25
#
#
#
#
# [Worker 99618] Starting job Layer1Run0 at 21:42:25[Worker 99616] Starting job Layer0Run26 at 21:42:25
# [Worker 99621] Starting job Layer1Run3 at 21:42:25[Worker 99619] Starting job Layer1Run1 at 21:42:25
# [Worker 99622] Starting job Layer1Run4 at 21:42:25[Worker 99620] Starting job Layer1Run2 at 21:42:25[Worker 99617] Starting job Layer0Run27 at 21:42:25
# [Worker 99623] Starting job Layer1Run5 at 21:42:25[Worker 99624] Starting job Layer1Run6 at 21:42:25[Worker 99625] Starting job Layer1Run7 at 21:42:25[Worker 99629] Starting job Layer1Run11 at 21:42:25[Worker 99628] Starting job Layer1Run10 at 21:42:25[Worker 99626] Starting job Layer1Run8 at 21:42:25[Worker 99631] Starting job Layer1Run13 at 21:42:25[Worker 99627] Starting job Layer1Run9 at 21:42:25[Worker 99632] Starting job Layer1Run14 at 21:42:25[Worker 99630] Starting job Layer1Run12 at 21:42:25[Worker 99634] Starting job Layer1Run16 at 21:42:25[Worker 99633] Starting job Layer1Run15 at 21:42:25[Worker 99635] Starting job Layer1Run17 at 21:42:25[Worker 99637] Starting job Layer1Run19 at 21:42:25
#
# [Worker 99638] Starting job Layer1Run20 at 21:42:25
# [Worker 99636] Starting job Layer1Run18 at 21:42:25[Worker 99642] Starting job Layer1Run24 at 21:42:25[Worker 99641] Starting job Layer1Run23 at 21:42:25[Worker 99639] Starting job Layer1Run21 at 21:42:25
# [Worker 99640] Starting job Layer1Run22 at 21:42:25[Worker 99643] Starting job Layer1Run25 at 21:42:25[Worker 99644] Starting job Layer1Run26 at 21:42:25[Worker 99645] Starting job Layer1Run27 at 21:42:25[Worker 99646] Starting job Layer2Run0 at 21:42:25
# [Worker 99647] Starting job Layer2Run1 at 21:42:25
# [Worker 99651] Starting job Layer2Run5 at 21:42:25[Worker 99650] Starting job Layer2Run4 at 21:42:25[Worker 99652] Starting job Layer2Run6 at 21:42:25[Worker 99649] Starting job Layer2Run3 at 21:42:25[Worker 99648] Starting job Layer2Run2 at 21:42:25[Worker 99653] Starting job Layer2Run7 at 21:42:25
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [Worker 99615] Starting job Layer0Run25 at 21:42:25[Worker 99614] Starting job Layer0Run24 at 21:42:25
#
# [Worker 99590] Finished job Layer0Run0 at 21:42:29 (0.1 min, rc=0)
# [Worker 99590] Starting job Layer2Run8 at 21:42:29
# [Worker 99646] Finished job Layer2Run0 at 21:42:29 (0.1 min, rc=0)
# [Worker 99646] Starting job Layer2Run9 at 21:42:29
# Completed Layer0Run0
# Completed Layer2Run0
# [Worker 99618] Finished job Layer1Run0 at 21:42:30 (0.1 min, rc=0)
# [Worker 99618] Starting job Layer2Run10 at 21:42:30
# Completed Layer1Run0
# [Worker 99591] Finished job Layer0Run1 at 21:42:33 (0.1 min, rc=0)
# [Worker 99591] Starting job Layer2Run11 at 21:42:33
# [Worker 99647] Finished job Layer2Run1 at 21:42:33 (0.1 min, rc=0)
# [Worker 99647] Starting job Layer2Run12 at 21:42:33
# Completed Layer0Run1
# Completed Layer2Run1
# [Worker 99619] Finished job Layer1Run1 at 21:42:33 (0.1 min, rc=0)
# [Worker 99619] Starting job Layer2Run13 at 21:42:33
# Completed Layer1Run1
# [Worker 99592] Finished job Layer0Run2 at 21:42:36 (0.2 min, rc=0)
# [Worker 99592] Starting job Layer2Run14 at 21:42:36
# Completed Layer0Run2
# [Worker 99648] Finished job Layer2Run2 at 21:42:37 (0.2 min, rc=0)
# [Worker 99648] Starting job Layer2Run15 at 21:42:37
# Completed Layer2Run2
# [Worker 99620] Finished job Layer1Run2 at 21:42:37 (0.2 min, rc=0)
# [Worker 99620] Starting job Layer2Run16 at 21:42:37
# Completed Layer1Run2
# [Worker 99593] Finished job Layer0Run3 at 21:42:40 (0.2 min, rc=0)
# [Worker 99593] Starting job Layer2Run17 at 21:42:40
# Completed Layer0Run3
# [Worker 99621] Finished job Layer1Run3 at 21:42:41 (0.3 min, rc=0)
# [Worker 99621] Starting job Layer2Run18 at 21:42:41
# [Worker 99649] Finished job Layer2Run3 at 21:42:41 (0.3 min, rc=0)
# [Worker 99649] Starting job Layer2Run19 at 21:42:41
# Completed Layer1Run3
# Completed Layer2Run3
# [Worker 99594] Finished job Layer0Run4 at 21:42:44 (0.3 min, rc=0)
# [Worker 99594] Starting job Layer2Run20 at 21:42:44
# Completed Layer0Run4
# [Worker 99650] Finished job Layer2Run4 at 21:42:45 (0.3 min, rc=0)
# [Worker 99650] Starting job Layer2Run21 at 21:42:45
# Completed Layer2Run4
# [Worker 99622] Finished job Layer1Run4 at 21:42:45 (0.3 min, rc=0)
# [Worker 99622] Starting job Layer2Run22 at 21:42:45
# Completed Layer1Run4
# [Worker 99595] Finished job Layer0Run5 at 21:42:48 (0.4 min, rc=0)
# [Worker 99595] Starting job Layer2Run23 at 21:42:48
# Completed Layer0Run5
# [Worker 99623] Finished job Layer1Run5 at 21:42:49 (0.4 min, rc=0)
# [Worker 99623] Starting job Layer2Run24 at 21:42:49
# [Worker 99651] Finished job Layer2Run5 at 21:42:49 (0.4 min, rc=0)
# [Worker 99651] Starting job Layer2Run25 at 21:42:49
# Completed Layer1Run5
# Completed Layer2Run5
# [Worker 99596] Finished job Layer0Run6 at 21:42:52 (0.4 min, rc=0)
# [Worker 99596] Starting job Layer2Run26 at 21:42:52
# Completed Layer0Run6
# [Worker 99652] Finished job Layer2Run6 at 21:42:52 (0.5 min, rc=0)
# [Worker 99652] Starting job Layer2Run27 at 21:42:52
# Completed Layer2Run6
# [Worker 99624] Finished job Layer1Run6 at 21:42:53 (0.5 min, rc=0)
# [Worker 99624] Starting job Layer3Run0 at 21:42:53
# Completed Layer1Run6
# [Worker 99653] Finished job Layer2Run7 at 21:42:56 (0.5 min, rc=0)
# [Worker 99653] Starting job Layer3Run1 at 21:42:56
# [Worker 99597] Finished job Layer0Run7 at 21:42:56 (0.5 min, rc=0)
# [Worker 99597] Starting job Layer3Run2 at 21:42:56
# [Worker 99624] Finished job Layer3Run0 at 21:42:56 (0.1 min, rc=0)
# [Worker 99624] Starting job Layer3Run3 at 21:42:56
# Completed Layer2Run7
# Completed Layer0Run7
# Completed Layer3Run0
# [Worker 99625] Finished job Layer1Run7 at 21:42:56 (0.5 min, rc=0)
# [Worker 99625] Starting job Layer3Run4 at 21:42:56
# Completed Layer1Run7
# [Worker 99598] Finished job Layer0Run8 at 21:43:00 (0.6 min, rc=0)
# [Worker 99598] Starting job Layer3Run5 at 21:43:00
# Completed Layer0Run8
# [Worker 99626] Finished job Layer1Run8 at 21:43:01 (0.6 min, rc=0)
# [Worker 99626] Starting job Layer3Run6 at 21:43:01
# Completed Layer1Run8
# [Worker 99653] Finished job Layer3Run1 at 21:43:02 (0.1 min, rc=0)
# [Worker 99653] Starting job Layer3Run7 at 21:43:02
# Completed Layer3Run1
# [Worker 99590] Finished job Layer2Run8 at 21:43:03 (0.6 min, rc=0)
# [Worker 99590] Starting job Layer3Run8 at 21:43:03
# Completed Layer2Run8
# [Worker 99599] Finished job Layer0Run9 at 21:43:05 (0.7 min, rc=0)
# [Worker 99599] Starting job Layer3Run9 at 21:43:05
# [Worker 99597] Finished job Layer3Run2 at 21:43:05 (0.1 min, rc=0)
# [Worker 99597] Starting job Layer3Run10 at 21:43:05
# [Worker 99627] Finished job Layer1Run9 at 21:43:05 (0.7 min, rc=0)
# [Worker 99627] Starting job Layer3Run11 at 21:43:05
# Completed Layer0Run9
# Completed Layer3Run2
# Completed Layer1Run9
# [Worker 99600] Finished job Layer0Run10 at 21:43:07 (0.7 min, rc=0)
# [Worker 99600] Starting job Layer3Run12 at 21:43:07
# Completed Layer0Run10
# [Worker 99624] Finished job Layer3Run3 at 21:43:08 (0.2 min, rc=0)
# [Worker 99624] Starting job Layer3Run13 at 21:43:08
# Completed Layer3Run3
# [Worker 99646] Finished job Layer2Run9 at 21:43:08 (0.6 min, rc=0)
# [Worker 99646] Starting job Layer3Run14 at 21:43:08
# Completed Layer2Run9
# [Worker 99628] Finished job Layer1Run10 at 21:43:09 (0.7 min, rc=0)
# [Worker 99628] Starting job Layer3Run15 at 21:43:09
# Completed Layer1Run10
# [Worker 99625] Finished job Layer3Run4 at 21:43:11 (0.2 min, rc=0)
# [Worker 99625] Starting job Layer3Run16 at 21:43:11
# Completed Layer3Run4
# [Worker 99601] Finished job Layer0Run11 at 21:43:12 (0.8 min, rc=0)
# [Worker 99601] Starting job Layer3Run17 at 21:43:12
# Completed Layer0Run11
# [Worker 99618] Finished job Layer2Run10 at 21:43:12 (0.7 min, rc=0)
# [Worker 99618] Starting job Layer3Run18 at 21:43:12
# Completed Layer2Run10
# [Worker 99629] Finished job Layer1Run11 at 21:43:13 (0.8 min, rc=0)
# [Worker 99629] Starting job Layer3Run19 at 21:43:13
# Completed Layer1Run11
# [Worker 99602] Finished job Layer0Run12 at 21:43:16 (0.8 min, rc=0)
# [Worker 99602] Starting job Layer3Run20 at 21:43:16
# Completed Layer0Run12
# [Worker 99630] Finished job Layer1Run12 at 21:43:16 (0.8 min, rc=0)
# [Worker 99630] Starting job Layer3Run21 at 21:43:16
# Completed Layer1Run12
# [Worker 99598] Finished job Layer3Run5 at 21:43:17 (0.3 min, rc=0)
# [Worker 99598] Starting job Layer3Run22 at 21:43:17
# Completed Layer3Run5
# [Worker 99631] Finished job Layer1Run13 at 21:43:19 (0.9 min, rc=0)
# [Worker 99631] Starting job Layer3Run23 at 21:43:19
# Completed Layer1Run13
# [Worker 99603] Finished job Layer0Run13 at 21:43:19 (0.9 min, rc=0)
# [Worker 99603] Starting job Layer3Run24 at 21:43:19
# Completed Layer0Run13
# [Worker 99591] Finished job Layer2Run11 at 21:43:20 (0.8 min, rc=0)
# [Worker 99591] Starting job Layer3Run25 at 21:43:20
# Completed Layer2Run11
# [Worker 99626] Finished job Layer3Run6 at 21:43:21 (0.3 min, rc=0)
# [Worker 99626] Starting job Layer3Run26 at 21:43:21
# Completed Layer3Run6
# [Worker 99604] Finished job Layer0Run14 at 21:43:22 (1.0 min, rc=0)
# [Worker 99604] Starting job Layer3Run27 at 21:43:22
# Completed Layer0Run14
# [Worker 99632] Finished job Layer1Run14 at 21:43:24 (1.0 min, rc=0)
# [Worker 99632] Starting job Layer4Run0 at 21:43:24
# Completed Layer1Run14
# [Worker 99647] Finished job Layer2Run12 at 21:43:24 (0.9 min, rc=0)
# [Worker 99647] Starting job Layer4Run1 at 21:43:24
# Completed Layer2Run12
# [Worker 99653] Finished job Layer3Run7 at 21:43:25 (0.4 min, rc=0)
# [Worker 99653] Starting job Layer4Run2 at 21:43:25
# Completed Layer3Run7
# [Worker 99605] Finished job Layer0Run15 at 21:43:26 (1.0 min, rc=0)
# [Worker 99605] Starting job Layer4Run3 at 21:43:26
# Completed Layer0Run15
# [Worker 99632] Finished job Layer4Run0 at 21:43:28 (0.1 min, rc=0)
# [Worker 99632] Starting job Layer4Run4 at 21:43:28
# Completed Layer4Run0
# [Worker 99590] Finished job Layer3Run8 at 21:43:28 (0.4 min, rc=0)
# [Worker 99590] Starting job Layer4Run5 at 21:43:28
# [Worker 99633] Finished job Layer1Run15 at 21:43:28 (1.1 min, rc=0)
# [Worker 99633] Starting job Layer4Run6 at 21:43:28
# Completed Layer3Run8
# Completed Layer1Run15
# [Worker 99619] Finished job Layer2Run13 at 21:43:29 (0.9 min, rc=0)
# [Worker 99619] Starting job Layer4Run7 at 21:43:29
# Completed Layer2Run13
# [Worker 99647] Finished job Layer4Run1 at 21:43:31 (0.1 min, rc=0)
# [Worker 99647] Starting job Layer4Run8 at 21:43:31
# Completed Layer4Run1
# [Worker 99606] Finished job Layer0Run16 at 21:43:32 (1.1 min, rc=0)
# [Worker 99606] Starting job Layer4Run9 at 21:43:32
# [Worker 99617] Finished job Layer0Run27 at 21:43:32 (1.1 min, rc=0)
# [Worker 99617] Starting job Layer4Run10 at 21:43:32
# Completed Layer0Run16
# Completed Layer0Run27
# [Worker 99634] Finished job Layer1Run16 at 21:43:33 (1.1 min, rc=0)
# [Worker 99634] Starting job Layer4Run11 at 21:43:33
# Completed Layer1Run16
# [Worker 99599] Finished job Layer3Run9 at 21:43:34 (0.5 min, rc=0)
# [Worker 99599] Starting job Layer4Run12 at 21:43:34
# Completed Layer3Run9
# [Worker 99607] Finished job Layer0Run17 at 21:43:35 (1.2 min, rc=0)
# [Worker 99607] Starting job Layer4Run13 at 21:43:35
# Completed Layer0Run17
# [Worker 99592] Finished job Layer2Run14 at 21:43:35 (1.0 min, rc=0)
# [Worker 99592] Starting job Layer4Run14 at 21:43:35
# [Worker 99635] Finished job Layer1Run17 at 21:43:35 (1.2 min, rc=0)
# [Worker 99635] Starting job Layer4Run15 at 21:43:35
# Completed Layer2Run14
# Completed Layer1Run17
# [Worker 99653] Finished job Layer4Run2 at 21:43:35 (0.2 min, rc=0)
# [Worker 99653] Starting job Layer4Run16 at 21:43:35
# Completed Layer4Run2
# [Worker 99645] Finished job Layer1Run27 at 21:43:37 (1.2 min, rc=0)
# [Worker 99645] Starting job Layer4Run17 at 21:43:37
# Completed Layer1Run27
# [Worker 99597] Finished job Layer3Run10 at 21:43:37 (0.5 min, rc=0)
# [Worker 99597] Starting job Layer4Run18 at 21:43:37
# Completed Layer3Run10
# [Worker 99648] Finished job Layer2Run15 at 21:43:39 (1.0 min, rc=0)
# [Worker 99648] Starting job Layer4Run19 at 21:43:39
# Completed Layer2Run15
# [Worker 99605] Finished job Layer4Run3 at 21:43:39 (0.2 min, rc=0)
# [Worker 99605] Starting job Layer4Run20 at 21:43:39
# [Worker 99608] Finished job Layer0Run18 at 21:43:39 (1.2 min, rc=0)
# [Worker 99608] Starting job Layer4Run21 at 21:43:39
# Completed Layer4Run3
# Completed Layer0Run18
# [Worker 99627] Finished job Layer3Run11 at 21:43:39 (0.6 min, rc=0)
# [Worker 99627] Starting job Layer4Run22 at 21:43:39
# Completed Layer3Run11
# [Worker 99636] Finished job Layer1Run18 at 21:43:40 (1.3 min, rc=0)
# [Worker 99636] Starting job Layer4Run23 at 21:43:40
# Completed Layer1Run18
# [Worker 99637] Finished job Layer1Run19 at 21:43:43 (1.3 min, rc=0)
# [Worker 99637] Starting job Layer5Run0 at 21:43:43
# Completed Layer1Run19
# [Worker 99620] Finished job Layer2Run16 at 21:43:43 (1.1 min, rc=0)
# [Worker 99620] Starting job Layer5Run1 at 21:43:43
# Completed Layer2Run16
# [Worker 99632] Finished job Layer4Run4 at 21:43:44 (0.3 min, rc=0)
# [Worker 99632] Starting job Layer5Run2 at 21:43:44
# [Worker 99609] Finished job Layer0Run19 at 21:43:44 (1.3 min, rc=0)
# [Worker 99609] Starting job Layer5Run3 at 21:43:44
# Completed Layer4Run4
# Completed Layer0Run19
# [Worker 99600] Finished job Layer3Run12 at 21:43:45 (0.6 min, rc=0)
# [Worker 99600] Starting job Layer5Run4 at 21:43:45
# [Worker 99637] Finished job Layer5Run0 at 21:43:46 (0.0 min, rc=0)
# [Worker 99637] Starting job Layer5Run5 at 21:43:46
# Completed Layer3Run12
# Completed Layer5Run0
# [Worker 99610] Finished job Layer0Run20 at 21:43:47 (1.4 min, rc=0)
# [Worker 99610] Starting job Layer5Run6 at 21:43:47
# Completed Layer0Run20
# [Worker 99638] Finished job Layer1Run20 at 21:43:47 (1.4 min, rc=0)
# [Worker 99638] Starting job Layer5Run7 at 21:43:47
# Completed Layer1Run20
# [Worker 99590] Finished job Layer4Run5 at 21:43:48 (0.3 min, rc=0)
# [Worker 99590] Starting job Layer5Run8 at 21:43:48
# Completed Layer4Run5
# [Worker 99620] Finished job Layer5Run1 at 21:43:48 (0.1 min, rc=0)
# [Worker 99620] Starting job Layer5Run9 at 21:43:48
# Completed Layer5Run1
# [Worker 99624] Finished job Layer3Run13 at 21:43:48 (0.7 min, rc=0)
# [Worker 99624] Starting job Layer5Run10 at 21:43:48
# Completed Layer3Run13
# [Worker 99611] Finished job Layer0Run21 at 21:43:49 (1.4 min, rc=0)
# [Worker 99611] Starting job Layer5Run11 at 21:43:49
# Completed Layer0Run21
# [Worker 99593] Finished job Layer2Run17 at 21:43:51 (1.2 min, rc=0)
# [Worker 99593] Starting job Layer5Run12 at 21:43:51
# Completed Layer2Run17
# [Worker 99639] Finished job Layer1Run21 at 21:43:52 (1.4 min, rc=0)
# [Worker 99639] Starting job Layer5Run13 at 21:43:52
# Completed Layer1Run21
# [Worker 99633] Finished job Layer4Run6 at 21:43:52 (0.4 min, rc=0)
# [Worker 99633] Starting job Layer5Run14 at 21:43:52
# [Worker 99632] Finished job Layer5Run2 at 21:43:52 (0.1 min, rc=0)
# [Worker 99632] Starting job Layer5Run15 at 21:43:52
# Completed Layer4Run6
# Completed Layer5Run2
# [Worker 99646] Finished job Layer3Run14 at 21:43:53 (0.7 min, rc=0)
# [Worker 99646] Starting job Layer5Run16 at 21:43:53
# Completed Layer3Run14
# [Worker 99621] Finished job Layer2Run18 at 21:43:54 (1.2 min, rc=0)
# [Worker 99621] Starting job Layer5Run17 at 21:43:54
# Completed Layer2Run18
# [Worker 99609] Finished job Layer5Run3 at 21:43:54 (0.2 min, rc=0)
# [Worker 99609] Starting job Layer5Run18 at 21:43:54
# Completed Layer5Run3
# [Worker 99628] Finished job Layer3Run15 at 21:43:55 (0.8 min, rc=0)
# [Worker 99628] Starting job Layer5Run19 at 21:43:55
# Completed Layer3Run15
# [Worker 99613] Finished job Layer0Run23 at 21:43:55 (1.5 min, rc=0)
# [Worker 99613] Starting job Layer5Run20 at 21:43:55
# [Worker 99641] Finished job Layer1Run23 at 21:43:55 (1.5 min, rc=0)
# [Worker 99641] Starting job Layer5Run21 at 21:43:55
# Completed Layer0Run23
# Completed Layer1Run23
# [Worker 99619] Finished job Layer4Run7 at 21:43:56 (0.4 min, rc=0)
# [Worker 99619] Starting job Layer5Run22 at 21:43:56
# [Worker 99612] Finished job Layer0Run22 at 21:43:57 (1.5 min, rc=0)
# [Worker 99612] Starting job Layer5Run23 at 21:43:57
# Completed Layer4Run7
# Completed Layer0Run22
# [Worker 99640] Finished job Layer1Run22 at 21:43:57 (1.5 min, rc=0)
# [Worker 99640] Starting job Layer6Run0 at 21:43:57
# Completed Layer1Run22
# [Worker 99600] Finished job Layer5Run4 at 21:43:57 (0.2 min, rc=0)
# [Worker 99600] Starting job Layer6Run1 at 21:43:57
# Completed Layer5Run4
# [Worker 99649] Finished job Layer2Run19 at 21:44:00 (1.3 min, rc=0)
# [Worker 99649] Starting job Layer6Run2 at 21:44:00
# [Worker 99637] Finished job Layer5Run5 at 21:44:00 (0.2 min, rc=0)
# [Worker 99637] Starting job Layer6Run3 at 21:44:00
# Completed Layer2Run19
# Completed Layer5Run5
# [Worker 99625] Finished job Layer3Run16 at 21:44:01 (0.8 min, rc=0)
# [Worker 99625] Starting job Layer6Run4 at 21:44:01
# [Worker 99640] Finished job Layer6Run0 at 21:44:01 (0.1 min, rc=0)
# [Worker 99640] Starting job Layer6Run5 at 21:44:01
# Completed Layer3Run16
# Completed Layer6Run0
# [Worker 99647] Finished job Layer4Run8 at 21:44:01 (0.5 min, rc=0)
# [Worker 99647] Starting job Layer6Run6 at 21:44:01
# Completed Layer4Run8
# [Worker 99652] Finished job Layer2Run27 at 21:44:01 (1.1 min, rc=0)
# [Worker 99652] Starting job Layer6Run7 at 21:44:01
# Completed Layer2Run27
# [Worker 99614] Finished job Layer0Run24 at 21:44:02 (1.6 min, rc=0)
# [Worker 99614] Starting job Layer6Run8 at 21:44:02
# Completed Layer0Run24
# [Worker 99601] Finished job Layer3Run17 at 21:44:03 (0.9 min, rc=0)
# [Worker 99601] Starting job Layer6Run9 at 21:44:03
# Completed Layer3Run17
# [Worker 99610] Finished job Layer5Run6 at 21:44:03 (0.3 min, rc=0)
# [Worker 99610] Starting job Layer6Run10 at 21:44:03
# Completed Layer5Run6
# [Worker 99642] Finished job Layer1Run24 at 21:44:05 (1.7 min, rc=0)
# [Worker 99642] Starting job Layer6Run11 at 21:44:05
# [Worker 99600] Finished job Layer6Run1 at 21:44:05 (0.1 min, rc=0)
# [Worker 99600] Starting job Layer6Run12 at 21:44:05
# Completed Layer1Run24
# Completed Layer6Run1
# [Worker 99615] Finished job Layer0Run25 at 21:44:05 (1.7 min, rc=0)
# [Worker 99615] Starting job Layer6Run13 at 21:44:05
# Completed Layer0Run25
# [Worker 99606] Finished job Layer4Run9 at 21:44:06 (0.6 min, rc=0)
# [Worker 99606] Starting job Layer6Run14 at 21:44:06
# [Worker 99638] Finished job Layer5Run7 at 21:44:06 (0.3 min, rc=0)
# [Worker 99638] Starting job Layer7Run0 at 21:44:06
# Completed Layer4Run9
# Completed Layer5Run7
# [Worker 99643] Finished job Layer1Run25 at 21:44:06 (1.7 min, rc=0)
# [Worker 99643] Starting job Layer7Run1 at 21:44:06
# [Worker 99618] Finished job Layer3Run18 at 21:44:06 (0.9 min, rc=0)
# [Worker 99618] Starting job Layer7Run2 at 21:44:06
# Completed Layer1Run25
# Completed Layer3Run18
# [Worker 99594] Finished job Layer2Run20 at 21:44:07 (1.4 min, rc=0)
# [Worker 99594] Starting job Layer7Run3 at 21:44:07
# Completed Layer2Run20
# [Worker 99617] Finished job Layer4Run10 at 21:44:09 (0.6 min, rc=0)
# [Worker 99617] Starting job Layer7Run4 at 21:44:09
# [Worker 99616] Finished job Layer0Run26 at 21:44:09 (1.7 min, rc=0)
# [Worker 99616] Starting job Layer7Run5 at 21:44:09
# Completed Layer4Run10
# Completed Layer0Run26
# [Worker 99590] Finished job Layer5Run8 at 21:44:09 (0.4 min, rc=0)
# [Worker 99590] Starting job Layer7Run6 at 21:44:09
# Completed Layer5Run8
# [Worker 99644] Finished job Layer1Run26 at 21:44:09 (1.7 min, rc=0)
# [Worker 99644] Starting job Layer7Run7 at 21:44:09
# Completed Layer1Run26
# [Worker 99638] Finished job Layer7Run0 at 21:44:10 (0.1 min, rc=0)
# [Worker 99638] Starting job Layer7Run8 at 21:44:10
# Completed Layer7Run0
# [Worker 99649] Finished job Layer6Run2 at 21:44:11 (0.2 min, rc=0)
# [Worker 99649] Starting job Layer7Run9 at 21:44:11
# Completed Layer6Run2
# [Worker 99650] Finished job Layer2Run21 at 21:44:11 (1.4 min, rc=0)
# [Worker 99650] Starting job Layer7Run10 at 21:44:11
# Completed Layer2Run21
# [Worker 99620] Finished job Layer5Run9 at 21:44:12 (0.4 min, rc=0)
# [Worker 99620] Starting job Layer7Run11 at 21:44:12
# Completed Layer5Run9
# [Worker 99629] Finished job Layer3Run19 at 21:44:12 (1.0 min, rc=0)
# [Worker 99629] Starting job Layer7Run12 at 21:44:12
# Completed Layer3Run19
# [Worker 99634] Finished job Layer4Run11 at 21:44:13 (0.7 min, rc=0)
# [Worker 99634] Starting job Layer7Run13 at 21:44:13
# [Worker 99604] Finished job Layer3Run27 at 21:44:13 (0.8 min, rc=0)
# [Worker 99604] Starting job Layer7Run14 at 21:44:13
# Completed Layer4Run11
# Completed Layer3Run27
# [Worker 99643] Finished job Layer7Run1 at 21:44:14 (0.1 min, rc=0)
# [Worker 99643] Starting job Layer8Run0 at 21:44:14
# Completed Layer7Run1
# [Worker 99637] Finished job Layer6Run3 at 21:44:15 (0.2 min, rc=0)
# [Worker 99637] Starting job Layer8Run1 at 21:44:15
# Completed Layer6Run3
# [Worker 99624] Finished job Layer5Run10 at 21:44:15 (0.4 min, rc=0)
# [Worker 99624] Starting job Layer8Run2 at 21:44:15
# [Worker 99622] Finished job Layer2Run22 at 21:44:15 (1.5 min, rc=0)
# [Worker 99622] Starting job Layer8Run3 at 21:44:15
# Completed Layer5Run10
# Completed Layer2Run22
# [Worker 99599] Finished job Layer4Run12 at 21:44:16 (0.7 min, rc=0)
# [Worker 99599] Starting job Layer8Run4 at 21:44:16
# Completed Layer4Run12
# [Worker 99643] Finished job Layer8Run0 at 21:44:16 (0.0 min, rc=0)
# [Worker 99643] Starting job Layer8Run5 at 21:44:16
# [Worker 99602] Finished job Layer3Run20 at 21:44:17 (1.0 min, rc=0)
# [Worker 99602] Starting job Layer8Run6 at 21:44:17
# Completed Layer8Run0
# Completed Layer3Run20
# [Worker 99611] Finished job Layer5Run11 at 21:44:17 (0.5 min, rc=0)
# [Worker 99611] Starting job Layer8Run7 at 21:44:17
# Completed Layer5Run11
# [Worker 99618] Finished job Layer7Run2 at 21:44:18 (0.2 min, rc=0)
# [Worker 99618] Starting job Layer8Run8 at 21:44:18
# Completed Layer7Run2
# [Worker 99625] Finished job Layer6Run4 at 21:44:19 (0.3 min, rc=0)
# [Worker 99625] Starting job Layer8Run9 at 21:44:19
# Completed Layer6Run4
# [Worker 99637] Finished job Layer8Run1 at 21:44:19 (0.1 min, rc=0)
# [Worker 99637] Starting job Layer8Run10 at 21:44:19
# Completed Layer8Run1
# [Worker 99630] Finished job Layer3Run21 at 21:44:20 (1.1 min, rc=0)
# [Worker 99630] Starting job Layer8Run11 at 21:44:20
# Completed Layer3Run21
# [Worker 99594] Finished job Layer7Run3 at 21:44:21 (0.2 min, rc=0)
# [Worker 99594] Starting job Layer8Run12 at 21:44:21
# Completed Layer7Run3
# [Worker 99607] Finished job Layer4Run13 at 21:44:21 (0.8 min, rc=0)
# [Worker 99607] Starting job Layer8Run13 at 21:44:21
# [Worker 99624] Finished job Layer8Run2 at 21:44:21 (0.1 min, rc=0)
# [Worker 99624] Starting job Layer8Run14 at 21:44:21
# Completed Layer4Run13
# Completed Layer8Run2
# [Worker 99593] Finished job Layer5Run12 at 21:44:22 (0.5 min, rc=0)
# [Worker 99593] Starting job Layer9Run0 at 21:44:22
# [Worker 99595] Finished job Layer2Run23 at 21:44:22 (1.6 min, rc=0)
# [Worker 99595] Starting job Layer9Run1 at 21:44:22
# Completed Layer5Run12
# Completed Layer2Run23
# [Worker 99640] Finished job Layer6Run5 at 21:44:23 (0.4 min, rc=0)
# [Worker 99640] Starting job Layer9Run2 at 21:44:23
# Completed Layer6Run5
# [Worker 99622] Finished job Layer8Run3 at 21:44:23 (0.1 min, rc=0)
# [Worker 99622] Starting job Layer9Run3 at 21:44:23
# Completed Layer8Run3
# [Worker 99639] Finished job Layer5Run13 at 21:44:24 (0.5 min, rc=0)
# [Worker 99639] Starting job Layer9Run4 at 21:44:24
# Completed Layer5Run13
# [Worker 99592] Finished job Layer4Run14 at 21:44:25 (0.8 min, rc=0)
# [Worker 99592] Starting job Layer9Run5 at 21:44:25
# Completed Layer4Run14
# [Worker 99598] Finished job Layer3Run22 at 21:44:25 (1.1 min, rc=0)
# [Worker 99598] Starting job Layer9Run6 at 21:44:25
# Completed Layer3Run22
# [Worker 99593] Finished job Layer9Run0 at 21:44:26 (0.1 min, rc=0)
# [Worker 99593] Starting job Layer9Run7 at 21:44:26
# Completed Layer9Run0
# [Worker 99647] Finished job Layer6Run6 at 21:44:26 (0.4 min, rc=0)
# [Worker 99647] Starting job Layer10Run0 at 21:44:26
# [Worker 99599] Finished job Layer8Run4 at 21:44:26 (0.2 min, rc=0)
# [Worker 99599] Starting job Layer10Run1 at 21:44:26
# Completed Layer6Run6
# Completed Layer8Run4
# [Worker 99617] Finished job Layer7Run4 at 21:44:27 (0.3 min, rc=0)
# [Worker 99617] Starting job Layer10Run2 at 21:44:27
# Completed Layer7Run4
# [Worker 99633] Finished job Layer5Run14 at 21:44:27 (0.6 min, rc=0)
# [Worker 99633] Starting job Layer10Run3 at 21:44:27
# [Worker 99623] Finished job Layer2Run24 at 21:44:27 (1.6 min, rc=0)
# [Worker 99623] Starting job Layer10Run4 at 21:44:27
# Completed Layer5Run14
# Completed Layer2Run24
# [Worker 99635] Finished job Layer4Run15 at 21:44:28 (0.9 min, rc=0)
# [Worker 99635] Starting job Layer11Run0 at 21:44:28
# Completed Layer4Run15
# [Worker 99631] Finished job Layer3Run23 at 21:44:29 (1.2 min, rc=0)
# [Worker 99631] Starting job Layer11Run1 at 21:44:29
# Completed Layer3Run23
# [Worker 99643] Finished job Layer8Run5 at 21:44:29 (0.2 min, rc=0)
# [Worker 99643] Starting job Layer11Run2 at 21:44:29
# Completed Layer8Run5
# [Worker 99595] Finished job Layer9Run1 at 21:44:29 (0.1 min, rc=0)
# [Worker 99595] Starting job Layer11Run3 at 21:44:29
# Completed Layer9Run1
# [Worker 99632] Finished job Layer5Run15 at 21:44:30 (0.6 min, rc=0)
# [Worker 99632] Starting job Layer12Run0 at 21:44:30
# Completed Layer5Run15
# [Worker 99616] Finished job Layer7Run5 at 21:44:30 (0.4 min, rc=0)
# [Worker 99616] Starting job Layer12Run1 at 21:44:30
# [Worker 99651] Finished job Layer2Run25 at 21:44:30 (1.7 min, rc=0)
# [Worker 99651] Starting job Layer12Run2 at 21:44:30
# Completed Layer7Run5
# Completed Layer2Run25
# [Worker 99652] Finished job Layer6Run7 at 21:44:31 (0.5 min, rc=0)
# [Worker 99652] Starting job Layer12Run3 at 21:44:31
# [Worker 99602] Finished job Layer8Run6 at 21:44:31 (0.2 min, rc=0)
# [Worker 99602] Starting job Layer13Run0 at 21:44:31
# Completed Layer6Run7
# Completed Layer8Run6
# [Worker 99647] Finished job Layer10Run0 at 21:44:32 (0.1 min, rc=0)
# [Worker 99647] Starting job Layer13Run1 at 21:44:32
# [Worker 99603] Finished job Layer3Run24 at 21:44:32 (1.2 min, rc=0)
# [Worker 99603] Starting job Layer13Run2 at 21:44:32
# Completed Layer10Run0
# Completed Layer3Run24
# [Worker 99635] Finished job Layer11Run0 at 21:44:32 (0.1 min, rc=0)
# [Worker 99635] Starting job Layer13Run3 at 21:44:32
# Completed Layer11Run0
# [Worker 99653] Finished job Layer4Run16 at 21:44:33 (1.0 min, rc=0)
# [Worker 99653] Starting job Layer14Run0 at 21:44:33
# Completed Layer4Run16
# [Worker 99646] Finished job Layer5Run16 at 21:44:33 (0.7 min, rc=0)
# [Worker 99646] Starting job Layer14Run1 at 21:44:33
# Completed Layer5Run16
# [Worker 99640] Finished job Layer9Run2 at 21:44:34 (0.2 min, rc=0)
# [Worker 99640] Starting job Layer14Run2 at 21:44:34
# [Worker 99611] Finished job Layer8Run7 at 21:44:34 (0.3 min, rc=0)
# [Worker 99611] Starting job Layer14Run3 at 21:44:34
# Completed Layer9Run2
# Completed Layer8Run7
# [Worker 99590] Finished job Layer7Run6 at 21:44:34 (0.4 min, rc=0)
# [Worker 99590] Starting job Layer15Run0 at 21:44:34
# [Worker 99632] Finished job Layer12Run0 at 21:44:35 (0.1 min, rc=0)
# [Worker 99632] Starting job Layer15Run1 at 21:44:35
# Completed Layer7Run6
# Completed Layer12Run0
# [Worker 99614] Finished job Layer6Run8 at 21:44:35 (0.5 min, rc=0)
# [Worker 99614] Starting job Layer16Run0 at 21:44:35
# [Worker 99591] Finished job Layer3Run25 at 21:44:35 (1.3 min, rc=0)
# [Worker 99591] Starting job Layer16Run1 at 21:44:35
# Completed Layer6Run8
# Completed Layer3Run25
# [Worker 99602] Finished job Layer13Run0 at 21:44:35 (0.1 min, rc=0)
# [Worker 99602] Starting job Layer17Run0 at 21:44:35
# Completed Layer13Run0
# [Worker 99618] Finished job Layer8Run8 at 21:44:36 (0.3 min, rc=0)
# [Worker 99618] Starting job Layer17Run1 at 21:44:36
# Completed Layer8Run8
# [Worker 99621] Finished job Layer5Run17 at 21:44:36 (0.7 min, rc=0)
# [Worker 99621] Starting job Layer18Run0 at 21:44:36
# [Worker 99653] Finished job Layer14Run0 at 21:44:36 (0.1 min, rc=0)
# [Worker 99653] Starting job Layer18Run1 at 21:44:36
# Completed Layer5Run17
# Completed Layer14Run0
# [Worker 99645] Finished job Layer4Run17 at 21:44:36 (1.0 min, rc=0)
# [Worker 99645] Starting job Layer19Run0 at 21:44:36
# Completed Layer4Run17
# [Worker 99599] Finished job Layer10Run1 at 21:44:37 (0.2 min, rc=0)
# [Worker 99599] Starting job Layer19Run1 at 21:44:37
# Completed Layer10Run1
# [Worker 99631] Finished job Layer11Run1 at 21:44:37 (0.1 min, rc=0)
# [Worker 99631] Starting job Layer20Run0 at 21:44:37
# Completed Layer11Run1
# [Worker 99622] Finished job Layer9Run3 at 21:44:38 (0.2 min, rc=0)
# [Worker 99622] Starting job Layer20Run1 at 21:44:38
# Completed Layer9Run3
# [Worker 99644] Finished job Layer7Run7 at 21:44:38 (0.5 min, rc=0)
# [Worker 99644] Starting job Layer21Run0 at 21:44:38
# Completed Layer7Run7
# [Worker 99625] Finished job Layer8Run9 at 21:44:39 (0.3 min, rc=0)
# [Worker 99625] Starting job Layer21Run1 at 21:44:39
# Completed Layer8Run9
# [Worker 99609] Finished job Layer5Run18 at 21:44:39 (0.7 min, rc=0)
# [Worker 99609] Starting job Layer22Run0 at 21:44:39
# Completed Layer5Run18
# [Worker 99601] Finished job Layer6Run9 at 21:44:39 (0.6 min, rc=0)
# [Worker 99601] Starting job Layer22Run1 at 21:44:39
# [Worker 99616] Finished job Layer12Run1 at 21:44:39 (0.1 min, rc=0)
# [Worker 99616] Starting job Layer23Run0 at 21:44:39[Worker 99596] Finished job Layer2Run26 at 21:44:39 (1.8 min, rc=0)
#
# [Worker 99596] Starting job Layer23Run1 at 21:44:39
# Completed Layer6Run9
# Completed Layer12Run1
# Completed Layer2Run26
# [Worker 99646] Finished job Layer14Run1 at 21:44:39 (0.1 min, rc=0)
# [Worker 99646] Starting job Layer24Run0 at 21:44:39
# Completed Layer14Run1
# [Worker 99626] Finished job Layer3Run26 at 21:44:40 (1.3 min, rc=0)
# [Worker 99626] Starting job Layer24Run1 at 21:44:40
# [Worker 99647] Finished job Layer13Run1 at 21:44:40 (0.1 min, rc=0)
# [Worker 99647] Starting job Layer25Run0 at 21:44:40
# [Worker 99597] Finished job Layer4Run18 at 21:44:40 (1.1 min, rc=0)
# [Worker 99597] Starting job Layer25Run1 at 21:44:40
# Completed Layer3Run26
# Completed Layer13Run1
# Completed Layer4Run18
# [Worker 99637] Finished job Layer8Run10 at 21:44:41 (0.4 min, rc=0)
# [Worker 99637] Starting job Layer26Run0 at 21:44:41
# Completed Layer8Run10
# [Worker 99643] Finished job Layer11Run2 at 21:44:42 (0.2 min, rc=0)
# [Worker 99643] Starting job Layer26Run1 at 21:44:42
# [Worker 99617] Finished job Layer10Run2 at 21:44:42 (0.3 min, rc=0)
# [Worker 99617] Starting job Layer27Run0 at 21:44:42
# Completed Layer11Run2
# Completed Layer10Run2
# [Worker 99628] Finished job Layer5Run19 at 21:44:42 (0.8 min, rc=0)
# [Worker 99628] Starting job Layer27Run1 at 21:44:42
# [Worker 99638] Finished job Layer7Run8 at 21:44:43 (0.5 min, rc=0)
# [Worker 99638] Starting job Layer28Run0 at 21:44:43
# Completed Layer5Run19
# Completed Layer7Run8
# [Worker 99639] Finished job Layer9Run4 at 21:44:43 (0.3 min, rc=0)
# [Worker 99639] Starting job Layer28Run1 at 21:44:43
# [Worker 99640] Finished job Layer14Run2 at 21:44:43 (0.1 min, rc=0)
# [Worker 99640] Starting job Layer29Run0 at 21:44:43
# Completed Layer9Run4
# Completed Layer14Run2
# [Worker 99590] Finished job Layer15Run0 at 21:44:43 (0.1 min, rc=0)
# [Worker 99590] Starting job Layer29Run1 at 21:44:43
# Completed Layer15Run0
# [Worker 99651] Finished job Layer12Run2 at 21:44:43 (0.2 min, rc=0)
# [Worker 99651] Starting job Layer30Run0 at 21:44:43
# [Worker 99614] Finished job Layer16Run0 at 21:44:43 (0.1 min, rc=0)
# [Worker 99614] Starting job Layer30Run1 at 21:44:43
# [Worker 99610] Finished job Layer6Run10 at 21:44:44 (0.7 min, rc=0)
# [Worker 99610] Starting job Layer31Run0 at 21:44:44
# Completed Layer12Run2
# Completed Layer16Run0
# Completed Layer6Run10
# [Worker 99602] Finished job Layer17Run0 at 21:44:44 (0.1 min, rc=0)
# [Worker 99602] Starting job Layer31Run1 at 21:44:44
# Completed Layer17Run0
# [Worker 99630] Finished job Layer8Run11 at 21:44:44 (0.4 min, rc=0)
# [Worker 99630] Starting job Layer32Run0 at 21:44:44
# [Worker 99621] Finished job Layer18Run0 at 21:44:44 (0.1 min, rc=0)
# [Worker 99621] Starting job Layer32Run1 at 21:44:44
# [Worker 99645] Finished job Layer19Run0 at 21:44:44 (0.1 min, rc=0)
# [Worker 99645] Starting job Layer33Run0 at 21:44:44
# Completed Layer8Run11
# Completed Layer18Run0
# Completed Layer19Run0
# [Worker 99613] Finished job Layer5Run20 at 21:44:45 (0.8 min, rc=0)
# [Worker 99613] Starting job Layer33Run1 at 21:44:45
# [Worker 99603] Finished job Layer13Run2 at 21:44:45 (0.2 min, rc=0)
# [Worker 99603] Starting job Layer34Run0 at 21:44:45
# Completed Layer5Run20
# Completed Layer13Run2
# [Worker 99611] Finished job Layer14Run3 at 21:44:45 (0.2 min, rc=0)
# [Worker 99611] Starting job Layer34Run1 at 21:44:45
# Completed Layer14Run3
# [Worker 99631] Finished job Layer20Run0 at 21:44:45 (0.1 min, rc=0)
# [Worker 99631] Starting job Layer35Run0 at 21:44:45
# [Worker 99648] Finished job Layer4Run19 at 21:44:45 (1.1 min, rc=0)
# [Worker 99648] Starting job Layer35Run1 at 21:44:45
# Completed Layer20Run0
# Completed Layer4Run19
# [Worker 99594] Finished job Layer8Run12 at 21:44:46 (0.4 min, rc=0)
# [Worker 99594] Starting job Layer36Run0 at 21:44:46
# [Worker 99644] Finished job Layer21Run0 at 21:44:46 (0.1 min, rc=0)
# [Worker 99644] Starting job Layer36Run1 at 21:44:46
# Completed Layer8Run12
# Completed Layer21Run0
# [Worker 99595] Finished job Layer11Run3 at 21:44:46 (0.3 min, rc=0)
# [Worker 99595] Starting job Layer37Run0 at 21:44:46
# Completed Layer11Run3
# [Worker 99609] Finished job Layer22Run0 at 21:44:46 (0.1 min, rc=0)
# [Worker 99609] Starting job Layer37Run1 at 21:44:46
# Completed Layer22Run0
# [Worker 99616] Finished job Layer23Run0 at 21:44:47 (0.1 min, rc=0)
# [Worker 99616] Starting job Layer38Run0 at 21:44:47
# [Worker 99646] Finished job Layer24Run0 at 21:44:47 (0.1 min, rc=0)
# [Worker 99646] Starting job Layer38Run1 at 21:44:47
# [Worker 99649] Finished job Layer7Run9 at 21:44:47 (0.6 min, rc=0)
# [Worker 99649] Starting job Layer39Run0 at 21:44:47
# [Worker 99592] Finished job Layer9Run5 at 21:44:47 (0.4 min, rc=0)
# [Worker 99592] Starting job Layer39Run1 at 21:44:47
# Completed Layer23Run0
# Completed Layer24Run0
# Completed Layer7Run9
# Completed Layer9Run5
# [Worker 99641] Finished job Layer5Run21 at 21:44:47 (0.9 min, rc=0)
# [Worker 99641] Starting job Layer40Run0 at 21:44:47
# Completed Layer5Run21
# [Worker 99652] Finished job Layer12Run3 at 21:44:47 (0.3 min, rc=0)
# [Worker 99652] Starting job Layer40Run1 at 21:44:47
# Completed Layer12Run3
# [Worker 99633] Finished job Layer10Run3 at 21:44:48 (0.3 min, rc=0)
# [Worker 99633] Starting job Layer41Run0 at 21:44:48
# [Worker 99647] Finished job Layer25Run0 at 21:44:48 (0.1 min, rc=0)
# [Worker 99647] Starting job Layer41Run1 at 21:44:48
# Completed Layer10Run3
# Completed Layer25Run0
# [Worker 99642] Finished job Layer6Run11 at 21:44:48 (0.7 min, rc=0)
# [Worker 99642] Starting job Layer42Run0 at 21:44:48
# Completed Layer6Run11
# [Worker 99635] Finished job Layer13Run3 at 21:44:49 (0.3 min, rc=0)
# [Worker 99635] Starting job Layer42Run1 at 21:44:49
# [Worker 99637] Finished job Layer26Run0 at 21:44:49 (0.1 min, rc=0)
# [Worker 99637] Starting job Layer43Run0 at 21:44:49
# [Worker 99624] Finished job Layer8Run14 at 21:44:49 (0.5 min, rc=0)
# [Worker 99624] Starting job Layer43Run1 at 21:44:49
# Completed Layer13Run3
# Completed Layer26Run0
# Completed Layer8Run14
# [Worker 99607] Finished job Layer8Run13 at 21:44:49 (0.5 min, rc=0)
# [Worker 99607] Starting job Layer44Run0 at 21:44:49
# Completed Layer8Run13
# [Worker 99605] Finished job Layer4Run20 at 21:44:49 (1.2 min, rc=0)
# [Worker 99605] Starting job Layer44Run1 at 21:44:49
# Completed Layer4Run20
# [Worker 99617] Finished job Layer27Run0 at 21:44:50 (0.1 min, rc=0)
# [Worker 99617] Starting job Layer45Run0 at 21:44:50
# [Worker 99640] Finished job Layer29Run0 at 21:44:50 (0.1 min, rc=0)
# [Worker 99640] Starting job Layer45Run1 at 21:44:50
# Completed Layer27Run0
# Completed Layer29Run0
# [Worker 99638] Finished job Layer28Run0 at 21:44:50 (0.1 min, rc=0)
# [Worker 99638] Starting job Layer46Run0 at 21:44:50
# Completed Layer28Run0
# [Worker 99619] Finished job Layer5Run22 at 21:44:50 (0.9 min, rc=0)
# [Worker 99619] Starting job Layer46Run1 at 21:44:50
# Completed Layer5Run22
# [Worker 99598] Finished job Layer9Run6 at 21:44:50 (0.4 min, rc=0)
# [Worker 99598] Starting job Layer47Run0 at 21:44:50
# ...
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 912
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 913
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 914
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 915
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 916
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 917
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 918
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 919
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 920
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 921
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 922
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 923
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 924
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 925
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 926
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 927
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 928
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 929
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 930
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 931
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 932
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 933
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 934
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 935
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 936
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 937
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 938
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 939
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 940
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 941
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 942
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 943
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 944
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 945
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 946
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 947
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 948
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 949
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 950
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 951
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 952
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 953
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 954
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 955
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 956
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 957
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 958
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 959
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 960
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 961
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 962
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 963
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 964
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 965
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 966
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 967
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 968
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 969
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 970
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 971
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 972
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 973
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 974
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 975
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 976
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 977
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 978
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 979
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 980
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 981
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 982
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 983
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 984
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 985
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 986
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 987
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 988
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 989
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 990
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 991
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 992
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 993
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 994
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 995
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 996
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 997
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 998
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# Doing realization = 999
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# [simDisp] nRec=1, nSrc=100, nFreq=60, workers=1, strategy=threading_shared
# (60, 3)
# /home/koley/.conda/envs/pySeis1DNN/lib/python3.11/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/koley/.conda/envs/pySeis1DNN/lib/python3.11/site-packages/numpy/ma/core.py:2885: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data = np.array(data, dtype=dtype, copy=copy,
# /home/koley/.conda/envs/pySeis1DNN/lib/python3.11/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import os
print("OMP:", os.environ.get("OMP_NUM_THREADS"))
print("MKL:", os.environ.get("MKL_NUM_THREADS"))
print("OPENBLAS:", os.environ.get("OPENBLAS_NUM_THREADS"))
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
print("OMP:", os.environ.get("OMP_NUM_THREADS"))
print("MKL:", os.environ.get("MKL_NUM_THREADS"))
print("OPENBLAS:", os.environ.get("OPENBLAS_NUM_THREADS"))
# Out:
# OMP: None
# MKL: None
# OPENBLAS: None
# OMP: 1
# MKL: 1
# OPENBLAS: 1

# %%
np.shape(attnSim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.shape(attnSim)
#
# NameError: name 'attnSim' is not defined
