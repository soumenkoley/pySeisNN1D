# %%
# script for computing NN for a homogeneous half-space or full space
# for different cuboidal cavity orientations
import numpy as np
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from scipy.io import savemat
from scipy.io import loadmat
from scipy.integrate import quad, tplquad, dblquad
import scipy.constants as const

from pysurf96 import surf96
from modules import configLoader
from modules import validateInputs
from modules import createDB
from modules import NNGeometryNN
from modules import gfLoader
from modules import simDisp
from modules import NNCompute

def main():

    # load the config file
    configFile="/home/koley/CavityResults/SurfMirrorConfig/configParseLayerFullStoch.ini"
    config = configLoader.load_config(configFile)
    wType = 'SHy' # can be Px, Pz, SV, SHx, SHy
    # load all cavities
    allCavities = configLoader.loadCavities('/home/koley/CavityResults/SurfMirrorConfig/SingleCavityHalfSpace.ini')
    validateInputs.validateInputs(config)
    
    splitAll = createDB.createFinalInputs(config)

    print(f"Prepared {splitAll.shape[0]} total runs")
    print(f"Cores available: {config.cpuCoresQseis}")

    results = createDB.runMultiQseis(splitAll, config.inputPath, config.qseisExe, nWorkers = config.cpuCoresQseis)
    
    print("Database generation complete")
    # flag for pure Rayleigh wavefield in homogeneous half-space
    ifRay = config.ifRay
    # flag for plane P and S waves in homogeneous half space
    ifBody = config.ifBody
    # flag for wavefield simulation
    ifFullField = config.ifFullField
    saveHV = config.saveHV
    thickness = config.thickness # units in meters
    vs = config.vS # units in m/s
    vp = config.vP # units in m/s
    rho = config.rho # units in kg/m^3
    rhoAir = config.rhoAir # density of air
    fMin = config.fMin; fMax = config.fMax; df = config.df;# units in Hz
    lambdaFrac = config.lambdaFrac # fraction
    lambdaRes = config.lambdaRes; #must be greater than 4
    
    # given a cuboidal domain should be greater than sqrt of 
    xMaxGF = config.xMaxGF # maximum horizontal offset upto which displacements will be used
    zMaxGF = config.zMaxGF # maximum depth upto which displacements will be used
    maxRec = config.maxRec # same value of number of receivers that qseis can handle in one go check qsglobal.h
    xCenter = config.xCenter; yCenter = config.yCenter
    xMin = xCenter-config.xExtent; xMax = xCenter+config.xExtent # minimum and maximum of the simulation domain in X-direction (EW)
    yMin = yCenter-config.yExtent; yMax = yCenter+config.yExtent # maximum and minimum of the simulation domain in Y-direction (NS)
    zMin = 0.0; zMax = config.zExtent # maximum and minimum of the simulation domain in Z-direction (depth)

    # check if the GFs are generated up to correct hoizontal offsets
    xDiag = (xMax-xMin)*np.sqrt(2); yDiag = (yMax-yMin)*np.sqrt(2);
    if(xMaxGF<xDiag or xMaxGF<yDiag):
        raise ValueError("xMaxGF must be >= sqrt(2)x(xMax-xMin) and sqrt(2)x(yMax-yMin)")

    if(zMaxGF<zMax):
        raise ValueError("zMaxGF must be greater >= zMax")
        
    domXYBounds = (xMin,xMax,yMin,yMax)
    
    refineBoxes = NNGeometryNN.makeRefineBoxesFromCavities(allCavities)
    cubeTopAll = np.zeros((len(allCavities),))
    cubeBotAll = np.zeros((len(allCavities),))
    for boxNo, box in enumerate(refineBoxes):
        cubeTopAll[boxNo] = box.zMin
        cubeBotAll[boxNo] = box.zMax
    cubeTop = min(cubeTopAll)
    cubeBot = max(cubeBotAll)
    
    cavDepthAll = np.zeros((len(allCavities),))
    for cavNo, cav in enumerate(allCavities):    
        if(cav["shape"]=="cuboid"):
            cavDepthAll[cavNo] = cav["zC"]
        elif(cav["shape"] == 'sphere'):
            cavDepthAll[cavNo] = cav["zC"]
        else:
            ValueError('Unsupported cavity type')
    cavDepthUse = min(cavDepthAll)

    print("CubeTop = " + str(cubeTop) +  'CubeBot = ' + str(cubeBot))
    
    itmAC = config.itmAC; itmAB = config.itmAB; etmCA = config.etmCA; etmBA = config.etmBA

    print('itmAC = ' + str(itmAC[0]) + ', ' + str(itmAC[1]) + ', ' + str(itmAC[2]))
    # make itmAC[2] negative, because in the configfile it is positive
    itmACUse = itmAC.copy(); itmACUse[2] = -itmACUse[2]
    itmABUse = itmAB.copy(); itmABUse[2] = -itmABUse[2]
    etmCAUse = etmCA.copy(); etmCAUse[2] = -etmCAUse[2]
    etmBAUse = etmBA.copy(); etmBAUse[2] = -etmBAUse[2]

    itmAll = np.vstack((itmACUse,itmABUse))
    nTM = len(itmAll[:,0])
    G = const.G
    
    # some other inputs for simDisp
    maxRec = config.maxRec; # same value of number of receivers that qseis can handle in one go check qsglobal.h
    tMax = config.tMax; nSamp = config.nSamp
    
    # specify the folder where you want to write all input files, should have rw access
    # fInpPath is the path where the Green's function database exists
    fInpPath = config.inputPath #like "/data/gravwav/koley/QseisInpN/"
    #fInpPath = "/data/gravwav/koley/SALVUSOut/"

    # outDispPath should have rw access and is used for saving temp displacementy files
    outDispPath = config.outDispPath # like "/data/gravwav/koley/OutDisp/"

    # saves the NN and displacement values per realization
    outDispRea = config.outDispPathRea # like "/data/gravwav/koley/OutDispRea/"
    
    # GF components to be used
    components = ['fh-2.tz', 'fh-2.tr', 'fh-2.tt', 'fz-2.tz', 'fz-2.tr']

    # splitAll is necessary so load it
    nRea = config.nRea # number of realizations

    # this file is created at the time of database generation
    splitFileName = fInpPath + 'splitAll.mat'
    splitMat = loadmat(splitFileName)
    splitAll = splitMat['splitAll']

    # source distribution parameters
    R1 = config.R1; R2 = config.R2
    nSrc = config.nSrc
    srcDistri = config.srcDistri
    scaleVH = config.scaleVH
    # flag if NN is computed directly without writing the displacemnet field
    onFlyNN = config.onFlyNN 

    # number of CPUs to be used for displacement and NN simulation
    nCPUDisp = config.cpuCoresDisp
    nCPUNN = config.cpuCoresNN
    computeStrategy = config.computeStrategy

    # frequency axis to be used by simDisp
    freqOut, idxFreq, df_native = simDisp.getFreqGrid(tMax, nSamp, fMin, fMax, df)
    nFreq = len(freqOut)

    splitAllNew, tVecN = gfLoader.assembleQseisRuns(splitAll, fInpPath, components, outPath=None, fIndices=idxFreq, minVel=100.0)
    #splitAllNew = np.load(os.path.join(fInpPath,'splitAllNew.npy'))

    # in case only Rayleigh waves in homogeneous half space is used, Rayleigh wave phase velocity is needed
    if(ifRay):
        periods = 1/freqOut
        vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
    else:
        vR = None
    # two depth points for scaling, displacement saved per realization
    #zList = [0.0,cavDepthUse]
    # change for mirror above the ground
    zList = [0.0, 250.0]
    
    # generate the grid size required
    gridSize = NNCompute.getGridSize(thickness,vp, vs, rho, fMin, fMax, lambdaFrac, lambdaRes)
    
    print('grid size in each layer before partitioning = ' + str(gridSize))
    
    # create the layers and partition
    layers, vp2, vs2, rho2, gridSize2 = NNGeometryNN.createAllLayers(xMin, xMax, yMin, yMax, thickness,
                                                                     zMax,vp,vs,rho,gridSize,cubeTop,cubeBot)
    print('New gridSize after partioning = '+ str(gridSize2))

    print('Total number of layers = ' + str(len(layers)))
    nLayers = len(layers)
    
    for reaNo in range(0,nRea):
        print('Doing realization = ' +str(reaNo))
        # get the source distribution per realization
        xSrc, ySrc, azSrc, srcMeta =  simDisp.genAmbSrc(nSrc , mode = srcDistri, R1 = R1, R2 = R2, xMin=xMin, xMax=xMax, yMin=yMin,
                                           yMax=yMax, randomPhase=True, freqDependent=True, nFreq=nFreq, decoupledHV=config.decoupledHV,
                                           scaleVH = scaleVH)
        
        # in case the body wave in homogeneous half-space flag is turned on
        if(ifBody):
            metaBody = simDisp.genBodySrc(nSrc, nFreq, eP = 0.1, eS = 0.9)
            
            if(wType == 'Px'):
                # P wave along +x
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"] = np.array([0.0])

                # Amplitude and phase for the P-wave
                metaBody["ampP"] = 1.0 * np.ones((1, nFreq))
                metaBody["phaseP"] = 0.0 * np.ones((1, nFreq))

                # Keep one dummy S-wave so your existing loops still work,
                # but set its amplitude to zero.
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"] = np.array([0.0])
                metaBody["psiS"] = np.array([0.0])
                metaBody["ampS"] = np.zeros((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
            
            elif(wType=='Pz'):
            
                # P-wave propagating along +z

                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([1.0])   # +z direction

                # Amplitude and phase for the P-wave
                metaBody["ampP"]   = np.ones((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))

                # Dummy S-wave with zero amplitude
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"]    = np.array([0.0])
                metaBody["psiS"]   = np.array([0.0])
                metaBody["ampS"]   = np.zeros((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
            elif(wType=='SHy'):
                # for SH wave propagating along +y and displacement field along +x
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([0.0])
                metaBody["ampP"]   = np.zeros((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))

                # One S/SH wave propagating along +y
                metaBody["thetaS"] = np.array([0.5*np.pi])
                metaBody["muS"]    = np.array([0.0])
                # For uS = +y, psiS = 0 gives polarization +x
                metaBody["psiS"]   = np.array([0.0])
                metaBody["ampS"]   = np.ones((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
                uS = simDisp.rand_dirs(metaBody["thetaS"], metaBody["muS"])
                polS = simDisp.s_polarizations(uS, metaBody["psiS"])
                print("uS =", uS)
                print("polS =", polS)
                print("ampS first few =", metaBody["ampS"][0, :5])
                print("phaseS first few =", metaBody["phaseS"][0, :5])
            elif(wType=='SHx'):
            
                # SH wave propagating along +x and displacement field along +y
                # No P-wave
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([0.0])
                metaBody["ampP"]   = np.zeros((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))
                # One S/SH wave propagating along +x
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"]    = np.array([0.0])
                # For uS = +x, psiS = pi gives polarization +y
                metaBody["psiS"]   = np.array([np.pi])
                metaBody["ampS"]   = np.ones((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))
                uS = simDisp.rand_dirs(metaBody["thetaS"], metaBody["muS"])
                polS = simDisp.s_polarizations(uS, metaBody["psiS"])
                print("uS =", uS)
                print("polS =", polS)
                print("ampS first few =", metaBody["ampS"][0, :5])
                print("phaseS first few =", metaBody["phaseS"][0, :5])
            
            else:
                # SV wave propagating along +x and displacement field along +z
                # No P-wave
                metaBody["thetaP"] = np.array([0.0])
                metaBody["muP"]    = np.array([0.0])
                metaBody["ampP"]   = np.zeros((1, nFreq))
                metaBody["phaseP"] = np.zeros((1, nFreq))

                # One S/SV wave propagating along +x
                metaBody["thetaS"] = np.array([0.0])
                metaBody["muS"]    = np.array([0.0])

                # For uS = +x, psiS = 3*pi/2 gives polarization +z
                metaBody["psiS"]   = np.array([1.5*np.pi])

                metaBody["ampS"]   = np.ones((1, nFreq))
                metaBody["phaseS"] = np.zeros((1, nFreq))

                nSrc = 1

                uS = simDisp.rand_dirs(metaBody["thetaS"], metaBody["muS"])
                polS = simDisp.s_polarizations(uS, metaBody["psiS"])

                print("uS =", uS)
                print("polS =", polS)
        else:
            metaBody=None
        
        # create and save the displacement field on surface and depth for scaling afterwards
        if(ifRay):
            # uses ambient Rayleigh wavefield in homogeneous half space
            #srcMeta["phiV"][0,:] = 0*np.ones((nFreq,))
            #srcMeta["ampV"][0,:] = np.ones((nFreq,))
            phiSrc = srcMeta["phiV"]; ampSrc = srcMeta["ampV"]
            #print(srcMeta["phiV"])
            #print(srcMeta["ampV"])
            #print(azSrc)
            #phiSrc = np.array((0,)); ampSrc = np.array((100.0,))
            #azSrc = np.array((0,))
            simDisp.getSurfDeepRayDispPerRea(zList, azSrc, phiSrc, ampSrc, outDispRea, reaNo, vR,
                                             vp2[0], vs2[0], freqOut=freqOut)
        elif(ifBody):
            # uses Plane P and S wave in homogeneous half space
            simDisp.getSurfDeepBodyDispPerRea(zList, metaBody, outDispRea, reaNo, vp2[0], vs2[0], freqOut=freqOut)
        
        else:
            # uses QSEIS full wavefield simulation instead
            simDisp.getSurfDeepDispPerRea(zList, xSrc, ySrc, azSrc, srcMeta, xMaxGF, splitAll, fMin, fMax, outDispRea,
                    fInpPath, components, reaNo, idxFreq = idxFreq, freqOut=freqOut)
        
        # preallocate per realization
        IBlockTot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        IVertFaceTot  = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        IHorFaceTot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        ITot = np.zeros((nFreq,3,nTM),dtype=np.complex128)
        
        for layerNo, layer in enumerate(layers):
            layer = layers[layerNo]

            # need to redefine cubeTop and cubeBot for multiple cavities
            layer.updateCubeInteraction(cubeTop, cubeBot)
            #layer.generateBlocks(xMin, xMax, yMin, yMax, cubeC, ax, ay, az, domXYBounds)
            layer.generateBlocksNew(refineBoxes=refineBoxes,domXYBounds=domXYBounds,
                                    domainZBounds=(zMin, zMax))
            
            print(layer)
            blkNo = 1
            for blk in layer.blocks:
                print(blk);
                print('Block = '+str(blkNo))
                print('Integrating volume  NN block in layer' + str(layerNo))
                #print(srcMeta['ampV'])
                # new version signature
                IBlock = NNCompute.runVolNNComputeBlock(blk, gridSize2[layerNo], freqOut, allCavities, itmAll,
                                                        xSrc, ySrc, azSrc,srcMeta, idxFreq, fMin, fMax, outDispPath, splitAll, xMaxGF,
                                                        fInpPath, components, vR, useSimDisp=ifFullField, ifRay = ifRay, ifBody = ifBody,
                                                        nCPUDisp=nCPUDisp, nCPUNN=nCPUNN, nChunk=20000,metaBody=metaBody,
                                                        computeStrategy=computeStrategy,saveHV=saveHV)
                # new version
                IBlockTot = IBlockTot + IBlock

                # now compute the surface NN from the vertical faces of the block which form the outer boundary
                for f in blk.verticalFaces:
                    if(f.isBoundary):
                        print('Integrating vertical surface NN block in layer' + str(layerNo))
                        print('vertical boundary face found')
                        # is an outer boundary
                        IVertFace = NNCompute.runVertSurfNNCompute(f, gridSize2[layerNo], freqOut, itmAll, xSrc, ySrc, azSrc,
                                                         srcMeta, idxFreq, fMin, fMax, outDispPath, splitAllNew,
                                                         xMaxGF, fInpPath, components, vR, nCPUDisp=1, nChunk = 20000, 
                                                         useSimDisp=ifFullField, ifRay = ifRay, ifBody = ifBody, vP_for_test=blk.vP,
                                                         vS_for_test=blk.vS, metaBody=metaBody,
                                                         computeStrategy=computeStrategy,saveHV=saveHV, reduceNN=onFlyNN)
                        
                        IVertFaceTot = IVertFaceTot + IVertFace
        
                
                # now compute the surface NN from the horizontal interfaces at the very end of layers
                print('Integrating horizontal surface NN block in layer' + str(layerNo))
                IHorFace = NNCompute.handleHorSurfNN(layer, layers, blk, gridSize2[layerNo], nLayers, layerNo, rhoAir, freqOut, 
                                           allCavities, itmAll, xSrc, ySrc, azSrc, srcMeta, idxFreq, fMin, fMax, outDispPath,
                                           splitAllNew, xMaxGF, fInpPath, components, vR, nCPUDisp=nCPUDisp,
                                           nCPUNN=nCPUNN, useSimDisp = ifFullField, ifRay = ifRay, ifBody = ifBody,
                                           vP_for_test=blk.vP, vS_for_test = blk.vS, metaBody = metaBody, chunk_size=20000,
                                           computeStrategy=computeStrategy, saveHV=saveHV, reduceNN=onFlyNN)
                                
                IHorFaceTot = IHorFaceTot + IHorFace
                
                blkNo = blkNo+1
    
        IVertFaceTot = IVertFaceTot*G
        IHorFaceTot = IHorFaceTot*G
        IBlockTot = IBlockTot*G
        ITot = (IBlockTot-IVertFaceTot-IHorFaceTot)
        # save the NN per realization
        nnFName = 'NNFullRea' + str(reaNo) + '.npz'
        np.savez(os.path.join(outDispRea, nnFName), IVertFaceTot = IVertFaceTot, IHorFaceTot = IHorFaceTot,
                 IBlockTot = IBlockTot, ITot = ITot, freqOut=freqOut)

    dispPointAllRea, attnAllRea, freqDisp = simDisp.assembleSurfDeepDispAllRea(outDispRea, zList, freqOut, nRea)
    nnAllRea, nnVolAllRea, nnSurfAllRea, fNN = NNCompute.assembleNNAllReaAllTM(outDispRea,freqOut, nRea,nTM)

if __name__ == "__main__":
    main()
# Out:
# All configuration and model checks passed.
# Layer depths = [   0. 5000.]
# Number of points per layer along Z = [125]
# Spacing in each layer in meters = [39.85153559 42.19409283]
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# QSEIS output folders from past runs deleted!
# Qseis Inputs cleaned, parent folder intact.
# Creating all input files ...
# All input files created!
# Prepared 508 total runs
# Cores available: 64
# Preparing to run 508 QSEIS jobs with 64 worker(s)...
# [Worker 2596136] Starting job Layer0Run1 at 18:14:27[Worker 2596137] Starting job Layer0Run2 at 18:14:27[Worker 2596135] Starting job Layer0Run0 at 18:14:27[Worker 2596138] Starting job Layer0Run3 at 18:14:27[Worker 2596139] Starting job Layer1Run0 at 18:14:27[Worker 2596140] Starting job Layer1Run1 at 18:14:27[Worker 2596141] Starting job Layer1Run2 at 18:14:27[Worker 2596142] Starting job Layer1Run3 at 18:14:27[Worker 2596143] Starting job Layer2Run0 at 18:14:27[Worker 2596144] Starting job Layer2Run1 at 18:14:27
#
#
# [Worker 2596147] Starting job Layer3Run0 at 18:14:27
#
#
# [Worker 2596146] Starting job Layer2Run3 at 18:14:27[Worker 2596148] Starting job Layer3Run1 at 18:14:27[Worker 2596150] Starting job Layer3Run3 at 18:14:27[Worker 2596145] Starting job Layer2Run2 at 18:14:27[Worker 2596152] Starting job Layer4Run1 at 18:14:27[Worker 2596153] Starting job Layer4Run2 at 18:14:27[Worker 2596149] Starting job Layer3Run2 at 18:14:27
#
# [Worker 2596151] Starting job Layer4Run0 at 18:14:27[Worker 2596155] Starting job Layer5Run0 at 18:14:27[Worker 2596156] Starting job Layer5Run1 at 18:14:27
# [Worker 2596157] Starting job Layer5Run2 at 18:14:27[Worker 2596158] Starting job Layer5Run3 at 18:14:27[Worker 2596159] Starting job Layer6Run0 at 18:14:27[Worker 2596161] Starting job Layer6Run2 at 18:14:27[Worker 2596160] Starting job Layer6Run1 at 18:14:27
# [Worker 2596164] Starting job Layer7Run1 at 18:14:27
#
# [Worker 2596163] Starting job Layer7Run0 at 18:14:27
#
# [Worker 2596162] Starting job Layer6Run3 at 18:14:27[Worker 2596165] Starting job Layer7Run2 at 18:14:27
# [Worker 2596166] Starting job Layer7Run3 at 18:14:27
# [Worker 2596168] Starting job Layer8Run1 at 18:14:27[Worker 2596167] Starting job Layer8Run0 at 18:14:27
# [Worker 2596169] Starting job Layer8Run2 at 18:14:27
#
# [Worker 2596171] Starting job Layer9Run0 at 18:14:27[Worker 2596170] Starting job Layer8Run3 at 18:14:27
#
# [Worker 2596172] Starting job Layer9Run1 at 18:14:27
#
# [Worker 2596175] Starting job Layer10Run0 at 18:14:27
# [Worker 2596177] Starting job Layer10Run2 at 18:14:27[Worker 2596173] Starting job Layer9Run2 at 18:14:27
# [Worker 2596176] Starting job Layer10Run1 at 18:14:27[Worker 2596174] Starting job Layer9Run3 at 18:14:27
# [Worker 2596178] Starting job Layer10Run3 at 18:14:27
# [Worker 2596179] Starting job Layer11Run0 at 18:14:27[Worker 2596180] Starting job Layer11Run1 at 18:14:27
# [Worker 2596181] Starting job Layer11Run2 at 18:14:27[Worker 2596182] Starting job Layer11Run3 at 18:14:27[Worker 2596185] Starting job Layer12Run2 at 18:14:27[Worker 2596183] Starting job Layer12Run0 at 18:14:27[Worker 2596184] Starting job Layer12Run1 at 18:14:27
# [Worker 2596186] Starting job Layer12Run3 at 18:14:27[Worker 2596188] Starting job Layer13Run1 at 18:14:27[Worker 2596187] Starting job Layer13Run0 at 18:14:27
# [Worker 2596190] Starting job Layer13Run3 at 18:14:27
#
#
# [Worker 2596192] Starting job Layer14Run1 at 18:14:27[Worker 2596193] Starting job Layer14Run2 at 18:14:27[Worker 2596191] Starting job Layer14Run0 at 18:14:27
# [Worker 2596189] Starting job Layer13Run2 at 18:14:27[Worker 2596195] Starting job Layer15Run0 at 18:14:27
# [Worker 2596194] Starting job Layer14Run3 at 18:14:27
#
# [Worker 2596198] Starting job Layer15Run3 at 18:14:27[Worker 2596196] Starting job Layer15Run1 at 18:14:27
# [Worker 2596197] Starting job Layer15Run2 at 18:14:27
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [Worker 2596154] Starting job Layer4Run3 at 18:14:27
# [Worker 2596179] Finished job Layer11Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596179] Starting job Layer16Run0 at 18:14:32
# [Worker 2596191] Finished job Layer14Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596191] Starting job Layer16Run1 at 18:14:32
# [Worker 2596167] Finished job Layer8Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596167] Starting job Layer16Run2 at 18:14:32
# [Worker 2596183] Finished job Layer12Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596183] Starting job Layer16Run3 at 18:14:32
# [Worker 2596195] Finished job Layer15Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596195] Starting job Layer17Run0 at 18:14:32
# Completed Layer11Run0
# Completed Layer14Run0
# Completed Layer8Run0
# Completed Layer12Run0
# Completed Layer15Run0
# [Worker 2596171] Finished job Layer9Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596171] Starting job Layer17Run1 at 18:14:32
# [Worker 2596175] Finished job Layer10Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596175] Starting job Layer17Run2 at 18:14:32
# [Worker 2596187] Finished job Layer13Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596187] Starting job Layer17Run3 at 18:14:32
# Completed Layer9Run0
# Completed Layer10Run0
# Completed Layer13Run0
# [Worker 2596159] Finished job Layer6Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596159] Starting job Layer18Run0 at 18:14:32
# [Worker 2596163] Finished job Layer7Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596163] Starting job Layer18Run1 at 18:14:32
# [Worker 2596155] Finished job Layer5Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596155] Starting job Layer18Run2 at 18:14:32
# Completed Layer6Run0
# Completed Layer7Run0
# Completed Layer5Run0
# [Worker 2596151] Finished job Layer4Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596151] Starting job Layer18Run3 at 18:14:32
# [Worker 2596143] Finished job Layer2Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596143] Starting job Layer19Run0 at 18:14:32
# [Worker 2596139] Finished job Layer1Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596147] Finished job Layer3Run0 at 18:14:32 (0.1 min, rc=0)
# [Worker 2596139] Starting job Layer19Run1 at 18:14:32
# [Worker 2596147] Starting job Layer19Run2 at 18:14:32
# Completed Layer4Run0
# Completed Layer2Run0
# Completed Layer1Run0
# Completed Layer3Run0
# [Worker 2596135] Finished job Layer0Run0 at 18:14:33 (0.1 min, rc=0)
# [Worker 2596135] Starting job Layer19Run3 at 18:14:33
# Completed Layer0Run0
# [Worker 2596196] Finished job Layer15Run1 at 18:14:34 (0.1 min, rc=0)
# [Worker 2596196] Starting job Layer20Run0 at 18:14:34
# [Worker 2596184] Finished job Layer12Run1 at 18:14:34 (0.1 min, rc=0)
# [Worker 2596184] Starting job Layer20Run1 at 18:14:34
# [Worker 2596188] Finished job Layer13Run1 at 18:14:34 (0.1 min, rc=0)
# [Worker 2596188] Starting job Layer20Run2 at 18:14:34
# [Worker 2596176] Finished job Layer10Run1 at 18:14:34 (0.1 min, rc=0)
# [Worker 2596176] Starting job Layer20Run3 at 18:14:34
# Completed Layer15Run1
# Completed Layer12Run1
# Completed Layer13Run1
# Completed Layer10Run1
# [Worker 2596180] Finished job Layer11Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596180] Starting job Layer21Run0 at 18:14:35
# [Worker 2596192] Finished job Layer14Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596192] Starting job Layer21Run1 at 18:14:35
# [Worker 2596172] Finished job Layer9Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596172] Starting job Layer21Run2 at 18:14:35
# Completed Layer11Run1
# Completed Layer14Run1
# Completed Layer9Run1
# [Worker 2596164] Finished job Layer7Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596164] Starting job Layer21Run3 at 18:14:35
# [Worker 2596168] Finished job Layer8Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596168] Starting job Layer22Run0 at 18:14:35
# [Worker 2596160] Finished job Layer6Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596160] Starting job Layer22Run1 at 18:14:35
# Completed Layer7Run1
# Completed Layer8Run1
# Completed Layer6Run1
# [Worker 2596156] Finished job Layer5Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596156] Starting job Layer22Run2 at 18:14:35
# [Worker 2596152] Finished job Layer4Run1 at 18:14:35 (0.1 min, rc=0)
# [Worker 2596152] Starting job Layer22Run3 at 18:14:35
# Completed Layer5Run1
# Completed Layer4Run1
# [Worker 2596136] Finished job Layer0Run1 at 18:14:36 (0.1 min, rc=0)
# [Worker 2596136] Starting job Layer23Run0 at 18:14:36
# [Worker 2596148] Finished job Layer3Run1 at 18:14:36 (0.1 min, rc=0)
# [Worker 2596148] Starting job Layer23Run1 at 18:14:36
# [Worker 2596144] Finished job Layer2Run1 at 18:14:36 (0.1 min, rc=0)
# [Worker 2596144] Starting job Layer23Run2 at 18:14:36
# [Worker 2596140] Finished job Layer1Run1 at 18:14:36 (0.1 min, rc=0)
# [Worker 2596140] Starting job Layer23Run3 at 18:14:36
# Completed Layer0Run1
# Completed Layer3Run1
# Completed Layer2Run1
# Completed Layer1Run1
# [Worker 2596179] Finished job Layer16Run0 at 18:14:36 (0.1 min, rc=0)
# [Worker 2596179] Starting job Layer24Run0 at 18:14:36
# Completed Layer16Run0
# [Worker 2596195] Finished job Layer17Run0 at 18:14:37 (0.1 min, rc=0)
# [Worker 2596195] Starting job Layer24Run1 at 18:14:37
# Completed Layer17Run0
# [Worker 2596159] Finished job Layer18Run0 at 18:14:37 (0.1 min, rc=0)
# [Worker 2596159] Starting job Layer24Run2 at 18:14:37
# Completed Layer18Run0
# [Worker 2596143] Finished job Layer19Run0 at 18:14:37 (0.1 min, rc=0)
# [Worker 2596143] Starting job Layer24Run3 at 18:14:37
# Completed Layer19Run0
# [Worker 2596185] Finished job Layer12Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596185] Starting job Layer25Run0 at 18:14:38
# [Worker 2596169] Finished job Layer8Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596169] Starting job Layer25Run1 at 18:14:38
# [Worker 2596193] Finished job Layer14Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596193] Starting job Layer25Run2 at 18:14:38
# Completed Layer12Run2
# Completed Layer8Run2
# Completed Layer14Run2
# [Worker 2596177] Finished job Layer10Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596177] Starting job Layer25Run3 at 18:14:38
# [Worker 2596189] Finished job Layer13Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596189] Starting job Layer26Run0 at 18:14:38
# [Worker 2596197] Finished job Layer15Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596197] Starting job Layer26Run1 at 18:14:38
# [Worker 2596181] Finished job Layer11Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596181] Starting job Layer26Run2 at 18:14:38
# [Worker 2596173] Finished job Layer9Run2 at 18:14:38 (0.2 min, rc=0)
# [Worker 2596173] Starting job Layer26Run3 at 18:14:38
# Completed Layer10Run2
# Completed Layer13Run2
# Completed Layer15Run2
# Completed Layer11Run2
# Completed Layer9Run2
# [Worker 2596165] Finished job Layer7Run2 at 18:14:39 (0.2 min, rc=0)
# [Worker 2596165] Starting job Layer27Run0 at 18:14:39
# [Worker 2596196] Finished job Layer20Run0 at 18:14:39 (0.1 min, rc=0)
# [Worker 2596196] Starting job Layer27Run1 at 18:14:39
# Completed Layer7Run2
# Completed Layer20Run0
# [Worker 2596157] Finished job Layer5Run2 at 18:14:39 (0.2 min, rc=0)
# [Worker 2596157] Starting job Layer27Run2 at 18:14:39[Worker 2596161] Finished job Layer6Run2 at 18:14:39 (0.2 min, rc=0)
#
# [Worker 2596161] Starting job Layer27Run3 at 18:14:39
# Completed Layer5Run2
# Completed Layer6Run2
# [Worker 2596191] Finished job Layer16Run1 at 18:14:40 (0.1 min, rc=0)
# [Worker 2596191] Starting job Layer28Run0 at 18:14:40
# [Worker 2596171] Finished job Layer17Run1 at 18:14:40 (0.1 min, rc=0)
# [Worker 2596171] Starting job Layer28Run1 at 18:14:40
# [Worker 2596163] Finished job Layer18Run1 at 18:14:40 (0.1 min, rc=0)
# [Worker 2596163] Starting job Layer28Run2 at 18:14:40
# [Worker 2596153] Finished job Layer4Run2 at 18:14:40 (0.2 min, rc=0)
# [Worker 2596153] Starting job Layer28Run3 at 18:14:40
# Completed Layer16Run1
# Completed Layer17Run1
# Completed Layer18Run1
# Completed Layer4Run2
# [Worker 2596180] Finished job Layer21Run0 at 18:14:40 (0.1 min, rc=0)
# [Worker 2596180] Starting job Layer29Run0 at 18:14:40
# [Worker 2596141] Finished job Layer1Run2 at 18:14:40 (0.2 min, rc=0)
# [Worker 2596141] Starting job Layer29Run1 at 18:14:40
# Completed Layer21Run0
# Completed Layer1Run2
# [Worker 2596139] Finished job Layer19Run1 at 18:14:40 (0.1 min, rc=0)
# [Worker 2596139] Starting job Layer29Run2 at 18:14:40
# [Worker 2596168] Finished job Layer22Run0 at 18:14:40 (0.1 min, rc=0)
# [Worker 2596168] Starting job Layer29Run3 at 18:14:40
# [Worker 2596145] Finished job Layer2Run2 at 18:14:40 (0.2 min, rc=0)
# [Worker 2596137] Finished job Layer0Run2 at 18:14:40 (0.2 min, rc=0)
# [Worker 2596145] Starting job Layer30Run0 at 18:14:40
# [Worker 2596137] Starting job Layer30Run1 at 18:14:40
# Completed Layer19Run1
# Completed Layer22Run0
# Completed Layer2Run2
# Completed Layer0Run2
# [Worker 2596149] Finished job Layer3Run2 at 18:14:40 (0.2 min, rc=0)
# [Worker 2596149] Starting job Layer30Run2 at 18:14:40
# Completed Layer3Run2
# [Worker 2596136] Finished job Layer23Run0 at 18:14:41 (0.1 min, rc=0)
# [Worker 2596136] Starting job Layer30Run3 at 18:14:41
# [Worker 2596194] Finished job Layer14Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596194] Starting job Layer31Run0 at 18:14:41
# Completed Layer23Run0
# Completed Layer14Run3
# [Worker 2596190] Finished job Layer13Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596190] Starting job Layer31Run1 at 18:14:41
# [Worker 2596170] Finished job Layer8Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596170] Starting job Layer31Run2 at 18:14:41
# [Worker 2596174] Finished job Layer9Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596174] Starting job Layer31Run3 at 18:14:41
# [Worker 2596186] Finished job Layer12Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596186] Starting job Layer32Run0 at 18:14:41
# Completed Layer13Run3
# Completed Layer8Run3
# Completed Layer9Run3
# Completed Layer12Run3
# [Worker 2596182] Finished job Layer11Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596182] Starting job Layer32Run1 at 18:14:41
# [Worker 2596198] Finished job Layer15Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596198] Starting job Layer32Run2 at 18:14:41
# Completed Layer11Run3
# Completed Layer15Run3
# [Worker 2596179] Finished job Layer24Run0 at 18:14:41 (0.1 min, rc=0)
# [Worker 2596179] Starting job Layer32Run3 at 18:14:41
# [Worker 2596178] Finished job Layer10Run3 at 18:14:41 (0.2 min, rc=0)
# [Worker 2596178] Starting job Layer33Run0 at 18:14:41
# Completed Layer24Run0
# Completed Layer10Run3
# [Worker 2596166] Finished job Layer7Run3 at 18:14:42 (0.2 min, rc=0)
# [Worker 2596166] Starting job Layer33Run1 at 18:14:42
# [Worker 2596158] Finished job Layer5Run3 at 18:14:42 (0.3 min, rc=0)[Worker 2596162] Finished job Layer6Run3 at 18:14:42 (0.3 min, rc=0)
#
# [Worker 2596162] Starting job Layer33Run2 at 18:14:42
# [Worker 2596158] Starting job Layer33Run3 at 18:14:42
# Completed Layer7Run3
# Completed Layer6Run3
# Completed Layer5Run3
# [Worker 2596184] Finished job Layer20Run1 at 18:14:42 (0.1 min, rc=0)
# [Worker 2596184] Starting job Layer34Run0 at 18:14:42
# [Worker 2596192] Finished job Layer21Run1 at 18:14:42 (0.1 min, rc=0)
# [Worker 2596192] Starting job Layer34Run1 at 18:14:42
# Completed Layer20Run1
# Completed Layer21Run1
# [Worker 2596160] Finished job Layer22Run1 at 18:14:42 (0.1 min, rc=0)
# [Worker 2596160] Starting job Layer34Run2 at 18:14:42
# [Worker 2596154] Finished job Layer4Run3 at 18:14:42 (0.3 min, rc=0)
# [Worker 2596154] Starting job Layer34Run3 at 18:14:42
# Completed Layer22Run1
# Completed Layer4Run3
# [Worker 2596185] Finished job Layer25Run0 at 18:14:43 (0.1 min, rc=0)
# [Worker 2596185] Starting job Layer35Run0 at 18:14:43
# [Worker 2596167] Finished job Layer16Run2 at 18:14:43 (0.2 min, rc=0)
# [Worker 2596167] Starting job Layer35Run1 at 18:14:43
# [Worker 2596150] Finished job Layer3Run3 at 18:14:43 (0.3 min, rc=0)
# [Worker 2596150] Starting job Layer35Run2 at 18:14:43
# Completed Layer25Run0
# Completed Layer16Run2
# Completed Layer3Run3
# [Worker 2596146] Finished job Layer2Run3 at 18:14:43 (0.3 min, rc=0)
# [Worker 2596146] Starting job Layer35Run3 at 18:14:43
# [Worker 2596148] Finished job Layer23Run1 at 18:14:43 (0.1 min, rc=0)
# [Worker 2596148] Starting job Layer36Run0 at 18:14:43
# [Worker 2596147] Finished job Layer19Run2 at 18:14:43 (0.2 min, rc=0)
# [Worker 2596147] Starting job Layer36Run1 at 18:14:43
# Completed Layer2Run3
# Completed Layer23Run1
# Completed Layer19Run2
# [Worker 2596142] Finished job Layer1Run3 at 18:14:43 (0.3 min, rc=0)
# [Worker 2596142] Starting job Layer36Run2 at 18:14:43
# [Worker 2596138] Finished job Layer0Run3 at 18:14:43 (0.3 min, rc=0)
# [Worker 2596138] Starting job Layer36Run3 at 18:14:43
# [Worker 2596175] Finished job Layer17Run2 at 18:14:43 (0.2 min, rc=0)
# [Worker 2596175] Starting job Layer37Run0 at 18:14:43
# [Worker 2596189] Finished job Layer26Run0 at 18:14:44 (0.1 min, rc=0)
# [Worker 2596189] Starting job Layer37Run1 at 18:14:44
# Completed Layer1Run3
# Completed Layer0Run3
# Completed Layer17Run2
# Completed Layer26Run0
# [Worker 2596155] Finished job Layer18Run2 at 18:14:44 (0.2 min, rc=0)
# [Worker 2596155] Starting job Layer37Run2 at 18:14:44
# [Worker 2596165] Finished job Layer27Run0 at 18:14:44 (0.1 min, rc=0)
# [Worker 2596165] Starting job Layer37Run3 at 18:14:44
# Completed Layer18Run2
# Completed Layer27Run0
# [Worker 2596191] Finished job Layer28Run0 at 18:14:45 (0.1 min, rc=0)
# [Worker 2596191] Starting job Layer38Run0 at 18:14:45
# [Worker 2596180] Finished job Layer29Run0 at 18:14:45 (0.1 min, rc=0)
# [Worker 2596180] Starting job Layer38Run1 at 18:14:45
# Completed Layer28Run0
# Completed Layer29Run0
# [Worker 2596195] Finished job Layer24Run1 at 18:14:45 (0.1 min, rc=0)
# [Worker 2596195] Starting job Layer38Run2 at 18:14:45
# Completed Layer24Run1
# [Worker 2596145] Finished job Layer30Run0 at 18:14:45 (0.1 min, rc=0)
# [Worker 2596145] Starting job Layer38Run3 at 18:14:45
# [Worker 2596172] Finished job Layer21Run2 at 18:14:45 (0.2 min, rc=0)
# [Worker 2596172] Starting job Layer39Run0 at 18:14:45
# Completed Layer30Run0
# Completed Layer21Run2
# [Worker 2596194] Finished job Layer31Run0 at 18:14:45 (0.1 min, rc=0)
# [Worker 2596194] Starting job Layer39Run1 at 18:14:45
# Completed Layer31Run0
# [Worker 2596183] Finished job Layer16Run3 at 18:14:46 (0.2 min, rc=0)
# [Worker 2596183] Starting job Layer39Run2 at 18:14:46
# [Worker 2596187] Finished job Layer17Run3 at 18:14:46 (0.2 min, rc=0)
# [Worker 2596187] Starting job Layer39Run3 at 18:14:46
# [Worker 2596186] Finished job Layer32Run0 at 18:14:46 (0.1 min, rc=0)
# [Worker 2596186] Starting job Layer40Run0 at 18:14:46
# [Worker 2596169] Finished job Layer25Run1 at 18:14:46 (0.1 min, rc=0)
# [Worker 2596169] Starting job Layer40Run1 at 18:14:46
# [Worker 2596188] Finished job Layer20Run2 at 18:14:46 (0.2 min, rc=0)
# [Worker 2596188] Starting job Layer40Run2 at 18:14:46
# Completed Layer16Run3
# Completed Layer17Run3
# Completed Layer32Run0
# Completed Layer25Run1
# Completed Layer20Run2
# [Worker 2596197] Finished job Layer26Run1 at 18:14:46 (0.1 min, rc=0)
# [Worker 2596197] Starting job Layer40Run3 at 18:14:46
# [Worker 2596178] Finished job Layer33Run0 at 18:14:46 (0.1 min, rc=0)
# [Worker 2596178] Starting job Layer41Run0 at 18:14:46
# Completed Layer26Run1
# Completed Layer33Run0
# [Worker 2596151] Finished job Layer18Run3 at 18:14:46 (0.2 min, rc=0)
# [Worker 2596151] Starting job Layer41Run1 at 18:14:46
# [Worker 2596196] Finished job Layer27Run1 at 18:14:46 (0.1 min, rc=0)
# [Worker 2596196] Starting job Layer41Run2 at 18:14:46
# [Worker 2596156] Finished job Layer22Run2 at 18:14:46 (0.2 min, rc=0)
# [Worker 2596156] Starting job Layer41Run3 at 18:14:46
# Completed Layer18Run3
# Completed Layer27Run1
# Completed Layer22Run2
# [Worker 2596135] Finished job Layer19Run3 at 18:14:47 (0.2 min, rc=0)
# [Worker 2596135] Starting job Layer42Run0 at 18:14:47
# Completed Layer19Run3
# [Worker 2596144] Finished job Layer23Run2 at 18:14:47 (0.2 min, rc=0)
# [Worker 2596144] Starting job Layer42Run1 at 18:14:47
# Completed Layer23Run2
# [Worker 2596141] Finished job Layer29Run1 at 18:14:47 (0.1 min, rc=0)
# [Worker 2596141] Starting job Layer42Run2 at 18:14:47
# [Worker 2596171] Finished job Layer28Run1 at 18:14:47 (0.1 min, rc=0)
# [Worker 2596171] Starting job Layer42Run3 at 18:14:47
# [Worker 2596184] Finished job Layer34Run0 at 18:14:47 (0.1 min, rc=0)
# [Worker 2596184] Starting job Layer43Run0 at 18:14:47
# Completed Layer29Run1
# Completed Layer28Run1
# Completed Layer34Run0
# [Worker 2596185] Finished job Layer35Run0 at 18:14:48 (0.1 min, rc=0)
# [Worker 2596185] Starting job Layer43Run1 at 18:14:48
# Completed Layer35Run0
# [Worker 2596137] Finished job Layer30Run1 at 18:14:48 (0.1 min, rc=0)
# [Worker 2596137] Starting job Layer43Run2 at 18:14:48
# [Worker 2596190] Finished job Layer31Run1 at 18:14:48 (0.1 min, rc=0)
# [Worker 2596190] Starting job Layer43Run3 at 18:14:48
# [Worker 2596175] Finished job Layer37Run0 at 18:14:48 (0.1 min, rc=0)
# [Worker 2596175] Starting job Layer44Run0 at 18:14:48
# [Worker 2596148] Finished job Layer36Run0 at 18:14:48 (0.1 min, rc=0)
# [Worker 2596148] Starting job Layer44Run1 at 18:14:48
# Completed Layer30Run1
# Completed Layer31Run1
# Completed Layer37Run0
# Completed Layer36Run0
# [Worker 2596159] Finished job Layer24Run2 at 18:14:48 (0.2 min, rc=0)
# [Worker 2596159] Starting job Layer44Run2 at 18:14:48
# [Worker 2596182] Finished job Layer32Run1 at 18:14:49 (0.1 min, rc=0)
# [Worker 2596182] Starting job Layer44Run3 at 18:14:49
# Completed Layer24Run2
# Completed Layer32Run1
# [Worker 2596152] Finished job Layer22Run3 at 18:14:49 (0.2 min, rc=0)
# [Worker 2596152] Starting job Layer45Run0 at 18:14:49
# [Worker 2596176] Finished job Layer20Run3 at 18:14:49 (0.2 min, rc=0)
# [Worker 2596176] Starting job Layer45Run1 at 18:14:49
# Completed Layer22Run3
# Completed Layer20Run3
# [Worker 2596164] Finished job Layer21Run3 at 18:14:49 (0.2 min, rc=0)
# [Worker 2596164] Starting job Layer45Run2 at 18:14:49
# [Worker 2596191] Finished job Layer38Run0 at 18:14:49 (0.1 min, rc=0)
# [Worker 2596191] Starting job Layer45Run3 at 18:14:49
# [Worker 2596166] Finished job Layer33Run1 at 18:14:49 (0.1 min, rc=0)
# [Worker 2596166] Starting job Layer46Run0 at 18:14:49
# Completed Layer21Run3
# Completed Layer38Run0
# Completed Layer33Run1
# [Worker 2596192] Finished job Layer34Run1 at 18:14:50 (0.1 min, rc=0)
# [Worker 2596192] Starting job Layer46Run1 at 18:14:50
# [Worker 2596181] Finished job Layer26Run2 at 18:14:50 (0.2 min, rc=0)
# [Worker 2596181] Starting job Layer46Run2 at 18:14:50
# Completed Layer34Run1
# Completed Layer26Run2
# [Worker 2596193] Finished job Layer25Run2 at 18:14:50 (0.2 min, rc=0)
# [Worker 2596193] Starting job Layer46Run3 at 18:14:50
# Completed Layer25Run2
# [Worker 2596172] Finished job Layer39Run0 at 18:14:50 (0.1 min, rc=0)
# [Worker 2596172] Starting job Layer47Run0 at 18:14:50
# [Worker 2596157] Finished job Layer27Run2 at 18:14:50 (0.2 min, rc=0)
# [Worker 2596157] Starting job Layer47Run1 at 18:14:50
# Completed Layer39Run0
# Completed Layer27Run2
# [Worker 2596140] Finished job Layer23Run3 at 18:14:51 (0.2 min, rc=0)
# [Worker 2596140] Starting job Layer47Run2 at 18:14:51
# [Worker 2596186] Finished job Layer40Run0 at 18:14:51 (0.1 min, rc=0)
# [Worker 2596186] Starting job Layer47Run3 at 18:14:51
# [Worker 2596167] Finished job Layer35Run1 at 18:14:51 (0.1 min, rc=0)
# [Worker 2596167] Starting job Layer48Run0 at 18:14:51
# Completed Layer23Run3
# Completed Layer40Run0
# Completed Layer35Run1
# [Worker 2596163] Finished job Layer28Run2 at 18:14:51 (0.2 min, rc=0)
# [Worker 2596163] Starting job Layer48Run1 at 18:14:51
# [Worker 2596147] Finished job Layer36Run1 at 18:14:51 (0.1 min, rc=0)
# [Worker 2596147] Starting job Layer48Run2 at 18:14:51
# [Worker 2596189] Finished job Layer37Run1 at 18:14:51 (0.1 min, rc=0)
# [Worker 2596189] Starting job Layer48Run3 at 18:14:51
# [Worker 2596178] Finished job Layer41Run0 at 18:14:51 (0.1 min, rc=0)
# [Worker 2596178] Starting job Layer49Run0 at 18:14:51
# Completed Layer28Run2
# Completed Layer36Run1
# Completed Layer37Run1
# Completed Layer41Run0
# [Worker 2596139] Finished job Layer29Run2 at 18:14:51 (0.2 min, rc=0)
# [Worker 2596139] Starting job Layer49Run1 at 18:14:51
# [Worker 2596135] Finished job Layer42Run0 at 18:14:51 (0.1 min, rc=0)
# [Worker 2596135] Starting job Layer49Run2 at 18:14:51
# Completed Layer29Run2
# Completed Layer42Run0
# [Worker 2596143] Finished job Layer24Run3 at 18:14:51 (0.2 min, rc=0)
# [Worker 2596143] Starting job Layer49Run3 at 18:14:51
# Completed Layer24Run3
# [Worker 2596149] Finished job Layer30Run2 at 18:14:52 (0.2 min, rc=0)
# [Worker 2596149] Starting job Layer50Run0 at 18:14:52
# [Worker 2596170] Finished job Layer31Run2 at 18:14:52 (0.2 min, rc=0)
# [Worker 2596170] Starting job Layer50Run1 at 18:14:52
# Completed Layer30Run2
# Completed Layer31Run2
# [Worker 2596184] Finished job Layer43Run0 at 18:14:52 (0.1 min, rc=0)
# [Worker 2596184] Starting job Layer50Run2 at 18:14:52
# [Worker 2596180] Finished job Layer38Run1 at 18:14:52 (0.1 min, rc=0)
# [Worker 2596180] Starting job Layer50Run3 at 18:14:52
# Completed Layer43Run0
# Completed Layer38Run1
# [Worker 2596177] Finished job Layer25Run3 at 18:14:52 (0.2 min, rc=0)
# [Worker 2596177] Starting job Layer51Run0 at 18:14:52
# Completed Layer25Run3
# [Worker 2596198] Finished job Layer32Run2 at 18:14:53 (0.2 min, rc=0)
# [Worker 2596198] Starting job Layer51Run1 at 18:14:53
# Completed Layer32Run2
# [Worker 2596194] Finished job Layer39Run1 at 18:14:53 (0.1 min, rc=0)
# [Worker 2596194] Starting job Layer51Run2 at 18:14:53
# [Worker 2596162] Finished job Layer33Run2 at 18:14:53 (0.2 min, rc=0)
# [Worker 2596162] Starting job Layer51Run3 at 18:14:53
# [Worker 2596173] Finished job Layer26Run3 at 18:14:53 (0.2 min, rc=0)
# [Worker 2596173] Starting job Layer52Run0 at 18:14:53
# [Worker 2596175] Finished job Layer44Run0 at 18:14:53 (0.1 min, rc=0)
# Completed Layer39Run1
# Completed Layer33Run2
# Completed Layer26Run3
# Completed Layer44Run0
# [Worker 2596175] Starting job Layer52Run1 at 18:14:53
# [Worker 2596161] Finished job Layer27Run3 at 18:14:53 (0.2 min, rc=0)
# ...
# Completed Layer112Run2
# [Worker 2596137] Finished job Layer124Run0 at 18:15:39 (0.1 min, rc=0)
# Completed Layer124Run0
# [Worker 2596174] Finished job Layer125Run0 at 18:15:39 (0.1 min, rc=0)
# [Worker 2596162] Finished job Layer113Run2 at 18:15:39 (0.2 min, rc=0)
# [Worker 2596141] Finished job Layer107Run3 at 18:15:39 (0.2 min, rc=0)
# Completed Layer125Run0
# Completed Layer113Run2
# Completed Layer107Run3
# [Worker 2596143] Finished job Layer119Run1 at 18:15:39 (0.1 min, rc=0)
# Completed Layer119Run1
# [Worker 2596186] Finished job Layer114Run2 at 18:15:39 (0.2 min, rc=0)
# [Worker 2596180] Finished job Layer120Run1 at 18:15:40 (0.1 min, rc=0)
# Completed Layer114Run2
# Completed Layer120Run1
# [Worker 2596188] Finished job Layer108Run3 at 18:15:40 (0.2 min, rc=0)
# [Worker 2596138] Finished job Layer121Run1 at 18:15:40 (0.1 min, rc=0)
# [Worker 2596142] Finished job Layer115Run2 at 18:15:40 (0.2 min, rc=0)
# Completed Layer108Run3
# Completed Layer121Run1
# Completed Layer115Run2
# [Worker 2596175] Finished job Layer126Run0 at 18:15:40 (0.1 min, rc=0)
# [Worker 2596153] Finished job Layer116Run2 at 18:15:40 (0.2 min, rc=0)
# [Worker 2596135] Finished job Layer122Run1 at 18:15:40 (0.1 min, rc=0)
# Completed Layer126Run0
# Completed Layer116Run2
# Completed Layer122Run1
# [Worker 2596196] Finished job Layer110Run3 at 18:15:40 (0.2 min, rc=0)
# [Worker 2596172] Finished job Layer123Run1 at 18:15:40 (0.1 min, rc=0)
# [Worker 2596150] Finished job Layer109Run3 at 18:15:40 (0.2 min, rc=0)
# Completed Layer110Run3
# Completed Layer123Run1
# Completed Layer109Run3
# [Worker 2596168] Finished job Layer112Run3 at 18:15:41 (0.2 min, rc=0)
# [Worker 2596156] Finished job Layer111Run3 at 18:15:41 (0.2 min, rc=0)
# [Worker 2596189] Finished job Layer124Run1 at 18:15:41 (0.1 min, rc=0)
# Completed Layer112Run3
# Completed Layer111Run3
# Completed Layer124Run1
# [Worker 2596190] Finished job Layer118Run2 at 18:15:41 (0.2 min, rc=0)
# Completed Layer118Run2
# [Worker 2596161] Finished job Layer125Run1 at 18:15:41 (0.1 min, rc=0)
# [Worker 2596187] Finished job Layer117Run2 at 18:15:42 (0.2 min, rc=0)
# [Worker 2596178] Finished job Layer119Run2 at 18:15:42 (0.2 min, rc=0)
# Completed Layer125Run1
# Completed Layer117Run2
# Completed Layer119Run2
# [Worker 2596167] Finished job Layer114Run3 at 18:15:42 (0.2 min, rc=0)
# [Worker 2596144] Finished job Layer120Run2 at 18:15:42 (0.2 min, rc=0)
# Completed Layer114Run3
# Completed Layer120Run2
# [Worker 2596145] Finished job Layer126Run1 at 18:15:43 (0.1 min, rc=0)
# [Worker 2596163] Finished job Layer115Run3 at 18:15:43 (0.2 min, rc=0)
# [Worker 2596191] Finished job Layer113Run3 at 18:15:43 (0.2 min, rc=0)
# Completed Layer126Run1
# Completed Layer115Run3
# Completed Layer113Run3
# [Worker 2596139] Finished job Layer121Run2 at 18:15:43 (0.2 min, rc=0)
# Completed Layer121Run2
# [Worker 2596177] Finished job Layer117Run3 at 18:15:44 (0.2 min, rc=0)
# [Worker 2596146] Finished job Layer122Run2 at 18:15:44 (0.2 min, rc=0)
# Completed Layer117Run3
# Completed Layer122Run2
# [Worker 2596181] Finished job Layer123Run2 at 18:15:44 (0.2 min, rc=0)
# [Worker 2596155] Finished job Layer116Run3 at 18:15:44 (0.2 min, rc=0)
# Completed Layer123Run2
# Completed Layer116Run3
# [Worker 2596171] Finished job Layer124Run2 at 18:15:44 (0.2 min, rc=0)
# Completed Layer124Run2
# [Worker 2596198] Finished job Layer119Run3 at 18:15:44 (0.2 min, rc=0)
# Completed Layer119Run3
# [Worker 2596157] Finished job Layer125Run2 at 18:15:45 (0.2 min, rc=0)
# Completed Layer125Run2
# [Worker 2596182] Finished job Layer118Run3 at 18:15:45 (0.2 min, rc=0)
# Completed Layer118Run3
# [Worker 2596185] Finished job Layer120Run3 at 18:15:45 (0.2 min, rc=0)
# Completed Layer120Run3
# [Worker 2596183] Finished job Layer126Run2 at 18:15:45 (0.2 min, rc=0)
# Completed Layer126Run2
# [Worker 2596147] Finished job Layer123Run3 at 18:15:46 (0.2 min, rc=0)
# [Worker 2596152] Finished job Layer122Run3 at 18:15:46 (0.2 min, rc=0)
# Completed Layer123Run3
# Completed Layer122Run3
# [Worker 2596140] Finished job Layer121Run3 at 18:15:46 (0.2 min, rc=0)
# Completed Layer121Run3
# [Worker 2596136] Finished job Layer124Run3 at 18:15:47 (0.2 min, rc=0)
# [Worker 2596154] Finished job Layer125Run3 at 18:15:47 (0.2 min, rc=0)
# Completed Layer124Run3
# Completed Layer125Run3
# [Worker 2596170] Finished job Layer126Run3 at 18:15:48 (0.2 min, rc=0)
# Completed Layer126Run3
# All QSEIS runs finished.
# Database generation complete
# CubeTop = -153.5CubeBot = 149.5
# itmAC = 0.0, 0.0, -1.0
# [0.    0.025 0.05  0.075 0.1  ]
# [assembleQseisRuns] saved | z=0.000 m |
# [assembleQseisRuns] saved | z=39.852 m |
# [assembleQseisRuns] saved | z=79.703 m |
# [assembleQseisRuns] saved | z=119.555 m |
# [assembleQseisRuns] saved | z=159.406 m |
# [assembleQseisRuns] saved | z=199.258 m |
# [assembleQseisRuns] saved | z=239.109 m |
# [assembleQseisRuns] saved | z=278.961 m |
# [assembleQseisRuns] saved | z=318.812 m |
# [assembleQseisRuns] saved | z=358.664 m |
# [assembleQseisRuns] saved | z=398.515 m |
# [assembleQseisRuns] saved | z=438.367 m |
# [assembleQseisRuns] saved | z=478.218 m |
# [assembleQseisRuns] saved | z=518.070 m |
# [assembleQseisRuns] saved | z=557.921 m |
# [assembleQseisRuns] saved | z=597.773 m |
# [assembleQseisRuns] saved | z=637.625 m |
# [assembleQseisRuns] saved | z=677.476 m |
# [assembleQseisRuns] saved | z=717.328 m |
# [assembleQseisRuns] saved | z=757.179 m |
# [assembleQseisRuns] saved | z=797.031 m |
# [assembleQseisRuns] saved | z=836.882 m |
# [assembleQseisRuns] saved | z=876.734 m |
# [assembleQseisRuns] saved | z=916.585 m |
# [assembleQseisRuns] saved | z=956.437 m |
# [assembleQseisRuns] saved | z=996.288 m |
# [assembleQseisRuns] saved | z=1036.140 m |
# [assembleQseisRuns] saved | z=1075.991 m |
# [assembleQseisRuns] saved | z=1115.843 m |
# [assembleQseisRuns] saved | z=1155.695 m |
# [assembleQseisRuns] saved | z=1195.546 m |
# [assembleQseisRuns] saved | z=1235.398 m |
# [assembleQseisRuns] saved | z=1275.249 m |
# [assembleQseisRuns] saved | z=1315.101 m |
# [assembleQseisRuns] saved | z=1354.952 m |
# [assembleQseisRuns] saved | z=1394.804 m |
# [assembleQseisRuns] saved | z=1434.655 m |
# [assembleQseisRuns] saved | z=1474.507 m |
# [assembleQseisRuns] saved | z=1514.358 m |
# [assembleQseisRuns] saved | z=1554.210 m |
# [assembleQseisRuns] saved | z=1594.061 m |
# [assembleQseisRuns] saved | z=1633.913 m |
# [assembleQseisRuns] saved | z=1673.764 m |
# [assembleQseisRuns] saved | z=1713.616 m |
# [assembleQseisRuns] saved | z=1753.468 m |
# [assembleQseisRuns] saved | z=1793.319 m |
# [assembleQseisRuns] saved | z=1833.171 m |
# [assembleQseisRuns] saved | z=1873.022 m |
# [assembleQseisRuns] saved | z=1912.874 m |
# [assembleQseisRuns] saved | z=1952.725 m |
# [assembleQseisRuns] saved | z=1992.577 m |
# [assembleQseisRuns] saved | z=2032.428 m |
# [assembleQseisRuns] saved | z=2072.280 m |
# [assembleQseisRuns] saved | z=2112.131 m |
# [assembleQseisRuns] saved | z=2151.983 m |
# [assembleQseisRuns] saved | z=2191.834 m |
# [assembleQseisRuns] saved | z=2231.686 m |
# [assembleQseisRuns] saved | z=2271.538 m |
# [assembleQseisRuns] saved | z=2311.389 m |
# [assembleQseisRuns] saved | z=2351.241 m |
# [assembleQseisRuns] saved | z=2391.092 m |
# [assembleQseisRuns] saved | z=2430.944 m |
# [assembleQseisRuns] saved | z=2470.795 m |
# [assembleQseisRuns] saved | z=2510.647 m |
# [assembleQseisRuns] saved | z=2550.498 m |
# [assembleQseisRuns] saved | z=2590.350 m |
# [assembleQseisRuns] saved | z=2630.201 m |
# [assembleQseisRuns] saved | z=2670.053 m |
# [assembleQseisRuns] saved | z=2709.904 m |
# [assembleQseisRuns] saved | z=2749.756 m |
# [assembleQseisRuns] saved | z=2789.607 m |
# [assembleQseisRuns] saved | z=2829.459 m |
# [assembleQseisRuns] saved | z=2869.311 m |
# [assembleQseisRuns] saved | z=2909.162 m |
# [assembleQseisRuns] saved | z=2949.014 m |
# [assembleQseisRuns] saved | z=2988.865 m |
# [assembleQseisRuns] saved | z=3028.717 m |
# [assembleQseisRuns] saved | z=3068.568 m |
# [assembleQseisRuns] saved | z=3108.420 m |
# [assembleQseisRuns] saved | z=3148.271 m |
# [assembleQseisRuns] saved | z=3188.123 m |
# [assembleQseisRuns] saved | z=3227.974 m |
# [assembleQseisRuns] saved | z=3267.826 m |
# [assembleQseisRuns] saved | z=3307.677 m |
# [assembleQseisRuns] saved | z=3347.529 m |
# [assembleQseisRuns] saved | z=3387.381 m |
# [assembleQseisRuns] saved | z=3427.232 m |
# [assembleQseisRuns] saved | z=3467.084 m |
# [assembleQseisRuns] saved | z=3506.935 m |
# [assembleQseisRuns] saved | z=3546.787 m |
# [assembleQseisRuns] saved | z=3586.638 m |
# [assembleQseisRuns] saved | z=3626.490 m |
# [assembleQseisRuns] saved | z=3666.341 m |
# [assembleQseisRuns] saved | z=3706.193 m |
# [assembleQseisRuns] saved | z=3746.044 m |
# [assembleQseisRuns] saved | z=3785.896 m |
# [assembleQseisRuns] saved | z=3825.747 m |
# [assembleQseisRuns] saved | z=3865.599 m |
# [assembleQseisRuns] saved | z=3905.450 m |
# [assembleQseisRuns] saved | z=3945.302 m |
# [assembleQseisRuns] saved | z=3985.154 m |
# [assembleQseisRuns] saved | z=4025.005 m |
# [assembleQseisRuns] saved | z=4064.857 m |
# [assembleQseisRuns] saved | z=4104.708 m |
# [assembleQseisRuns] saved | z=4144.560 m |
# [assembleQseisRuns] saved | z=4184.411 m |
# [assembleQseisRuns] saved | z=4224.263 m |
# [assembleQseisRuns] saved | z=4264.114 m |
# [assembleQseisRuns] saved | z=4303.966 m |
# [assembleQseisRuns] saved | z=4343.817 m |
# [assembleQseisRuns] saved | z=4383.669 m |
# [assembleQseisRuns] saved | z=4423.520 m |
# [assembleQseisRuns] saved | z=4463.372 m |
# [assembleQseisRuns] saved | z=4503.224 m |
# [assembleQseisRuns] saved | z=4543.075 m |
# [assembleQseisRuns] saved | z=4582.927 m |
# [assembleQseisRuns] saved | z=4622.778 m |
# [assembleQseisRuns] saved | z=4662.630 m |
# [assembleQseisRuns] saved | z=4702.481 m |
# [assembleQseisRuns] saved | z=4742.333 m |
# [assembleQseisRuns] saved | z=4782.184 m |
# [assembleQseisRuns] saved | z=4822.036 m |
# [assembleQseisRuns] saved | z=4861.887 m |
# [assembleQseisRuns] saved | z=4901.739 m |
# [assembleQseisRuns] saved | z=4941.590 m |
# [assembleQseisRuns] saved | z=4981.442 m |
# [assembleQseisRuns] saved | z=5000.000 m |
# grid size in each layer before partitioning = [39.85153559 42.19409283]
# Layer depths given by user before partitioning = [   0. 4000.] m
# New layer depths after partitioning for computationional speed = [   0.  400. 4000.] m
# New gridSize after partioning = [39.85153559 39.85153559]
# Total number of layers = 2
# Doing realization = 0
# <Layer z: 0.0-400.0, type: cut_bottom, nblocks: 10>
# <Block x:[-2000.0,-151.5], y:[-2000.0,-151.5], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 1
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[-2000.0,-151.5], y:[-151.5,151.5], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 2
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[-2000.0,-151.5], y:[151.5,2000.0], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 3
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[-151.5,151.5], y:[-2000.0,-151.5], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 4
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[-151.5,151.5], y:[-151.5,151.5], z:[0.0,149.5] spaceT:[uniform] intpType:[1] >
# Block = 5
# Integrating volume  NN block in layer0
# Uniform spacing
# [  0.4875   1.4625   2.4375   3.4125   4.3875   5.3625   6.3375   7.3125
#    8.2875   9.2625  10.2375  11.2125  12.1875  13.1625  14.1375  15.1125
#   16.0875  17.0625  18.0375  19.0125  20.5     22.5     24.5     26.5
#   28.5     30.5     32.5     34.5     36.5     38.5     42.      47.
#   52.      57.      62.      67.      72.      77.      82.      87.
#   92.      97.     102.     107.     112.     117.     122.     127.
#  132.     137.     142.     147.    ]
# Total points = 6561
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# No cavity removal
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# Uniform spacing
# <Block x:[-151.5,151.5], y:[-151.5,151.5], z:[149.5,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 6
# Integrating volume  NN block in layer0
# Integrating horizontal surface NN block in layer0
# <Block x:[-151.5,151.5], y:[151.5,2000.0], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 7
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[151.5,2000.0], y:[-2000.0,-151.5], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 8
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[151.5,2000.0], y:[-151.5,151.5], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 9
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Block x:[151.5,2000.0], y:[151.5,2000.0], z:[0.0,400.0] spaceT:[lgwt] intpType:[2] >
# Block = 10
# Integrating volume  NN block in layer0
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating vertical surface NN block in layer0
# vertical boundary face found
# Integrating horizontal surface NN block in layer0
# Horizontal face found
# I am in air
# Actually computing NN for the horizontal surface
# <Layer z: 400.0-4000.0, type: no_intersection, nblocks: 1>
# <Block x:[-2000.0,2000.0], y:[-2000.0,2000.0], z:[400.0,4000.0] spaceT:[lgwt] intpType:[1] >
# Block = 1
# Integrating volume  NN block in layer1
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating vertical surface NN block in layer1
# vertical boundary face found
# Integrating horizontal surface NN block in layer1
# Horizontal face found
# Actually computing NN for the horizontal surface
# /home/koley/pySeis1DNNCavity/modules/simDisp.py:311: RuntimeWarning: invalid value encountered in divide
#   attnAllRea = dispPointAllRea[:,:,0]/dispPointAllRea[:,:,1]

# %%
import matplotlib.pyplot as plt
import scipy.constants as const
import numpy as np
import os
from modules import configLoader
from modules import simDisp
from pysurf96 import surf96

configFile="/home/koley/CavityResults/SurfMirrorConfig/configParseHalfSpaceRayHomoStoch.ini"
config = configLoader.load_config(configFile)
thickness = config.thickness # units in meters
vs = config.vS # units in m/s
vp = config.vP # units in m/s
rho = config.rho # units in kg/m^3
G = const.G
freqOut, idxFreq, df_native = simDisp.getFreqGrid(config.tMax, config.nSamp, config.fMin, config.fMax, 
                                                  config.df)
nFreq = len(freqOut)
IblockAll = np.zeros((nFreq,3))
for i in range(0,config.nRea):
    data = np.load(os.path.join(config.outDispPathRea, "NNFullRea" + str(i) + ".npz"))

    Iblock = data["IBlockTot"]
    Ivert  = data["IVertFaceTot"]
    Ihor   = data["IHorFaceTot"]
    Itot   = data["ITot"]
    
    IblockAll += (np.abs(Iblock[:,:,0])**2)

IblockAll = np.sqrt(IblockAll/config.nRea)

thickness = config.thickness # units in meters
vs = config.vS # units in m/s
vp = config.vP # units in m/s
rho = config.rho # units in kg/m^3
G = const.G

asdZ = np.zeros((nFreq,))
asdX = np.zeros((nFreq,))
asdY = np.zeros((nFreq,))
# now get the seismic ASDs on the surface to scale
for reaNo in range(0,config.nRea):
    seisData = np.load(os.path.join(config.outDispPathRea, "surfDeepDispRea"+str(reaNo) + ".npz"))
    dispOut = seisData["dispPointFull"]
    asdX += (np.abs(dispOut[:,0,0]))**2
    asdY += (np.abs(dispOut[:,1,0]))**2
    asdZ += (np.abs(dispOut[:,2,0]))**2
asdZ = np.sqrt(asdZ/config.nRea)
asdX = np.sqrt(asdX/config.nRea)
asdY = np.sqrt(asdY/config.nRea)

asdZScale = asdZ/asdZ
asdXScale = asdX/asdZ
asdYScale = asdY/asdZ

# make the raw ASD plots
fig1,ax1 = plt.subplots(1,3,figsize=(16,4),sharey=True)
ax1[0].plot(freqOut,asdX,label='X component')
ax1[0].set_xlabel('Frequency (Hz)')
ax1[0].set_title('(a) X component')
ax1[0].set_ylabel('Raw displacement ASD at (0,0,0)')
ax1[1].plot(freqOut,asdY,label='Y component')
ax1[1].set_xlabel('Frequency (Hz)')
ax1[1].set_title('(b) Y component')
ax1[2].plot(freqOut,asdZ,label= 'Z component')
ax1[2].set_xlabel('Frequency (Hz)')
ax1[2].set_title('(c) Z component')

# make the displacement ASD plots, such that the z component is 1
fig2,ax2 = plt.subplots(1,3,figsize=(16,4),sharey=True)
ax2[0].plot(freqOut,asdXScale,label='X component')
ax2[0].set_xlabel('Frequency (Hz)')
ax2[0].set_title('(a) X component')
ax2[0].set_ylabel('Scaled Rayleigh displacement ASD at (0,0,0)')
ax2[1].plot(freqOut,asdYScale,label='Y component')
ax2[1].set_xlabel('Frequency (Hz)')
ax2[1].set_title('(b) Y component')
ax2[2].plot(freqOut,asdZScale,label= 'Z component')
ax2[2].set_xlabel('Frequency (Hz)')
ax2[2].set_title('(c) Z component')

# scale the volume contribuition such that asdZ = 1
scaleBlockAll = IblockAll/asdZ[:,None]
periods = 1/freqOut
vR = surf96(thickness,vp,vs,rho,periods,wave="rayleigh",mode=1,velocity="phase",flat_earth=True)
lR = vR/freqOut

# note for X,Y component, the sqrt of 2 division is necessary and can be derived theoretically
thRayNNX = 1/np.sqrt(2)*2*np.pi*G*0.815*rho[0]*np.exp(-2*np.pi*1/lR)
thRayNNY = 1/np.sqrt(2)*2*np.pi*G*0.815*rho[0]*np.exp(-2*np.pi*1/lR)
thRayNNZ = 2*np.pi*G*0.815*rho[0]*np.exp(-2*np.pi*1/lR)

fig3,ax3 = plt.subplots(1,3,figsize=(16,4),sharey=True)
ax3[0].plot(freqOut,scaleBlockAll[:,0],label='X component')
ax3[0].plot(freqOut,thRayNNX,'m',label='theoretical Rayleigh')
ax3[0].set_xlabel('Frequency (Hz)')
ax3[0].set_title('(a) X component')
ax3[0].set_ylabel('Scaled Newtonian acceleration ASD at (0,0,0)')
ax3[0].legend()
ax3[1].plot(freqOut,scaleBlockAll[:,1],label='Y component')
ax3[1].plot(freqOut,thRayNNY,'m',label='theoretical Rayleigh')
ax3[1].set_xlabel('Frequency (Hz)')
ax3[1].set_title('(b) Y component')
ax3[1].legend()
ax3[2].plot(freqOut,scaleBlockAll[:,2],label= 'Z component')
ax3[2].plot(freqOut,thRayNNZ,'m',label='theoretical Rayleigh')
ax3[2].set_xlabel('Frequency (Hz)')
ax3[2].set_title('(c) Z component')
ax3[2].legend()
ax3[2].set_ylim(10**-7,10**-6)
#plt.ylim(10**-8, 10**-6)
# Out:
# [0.    0.025 0.05  0.075 0.1  ]
# (1e-07, 1e-06)
